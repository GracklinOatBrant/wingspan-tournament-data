# %%
import requests
import os
from functools import cached_property
from collections import defaultdict
import json
from dotenv import load_dotenv
load_dotenv() # includes the CHALLONGE_API_KEY variable
# Out:
# True

# %% [markdown]
# # Define code to download and parse Wingspan tournaments from Challonge

# %%
def challonge_get(url, retries=3):
    try:
        return requests.get(url, {
            'api_key': os.environ['CHALLONGE_API_KEY']
        }, headers={
            'Content-Type': 'application/json',
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'
        }).json()
    except:
        print(f"failed to get {url}")
        if retries > 0:
            return challonge_get(url, retries-1)

valid_owners = {'Bargoff',
 'ChopYouUp',
 'ElsieGlen',
 'FlanHigh',
 'FloatingLakes',
 'Gtrudat',
 'Lone_Eider7',
 'ScaredofBirds',
 'deVisme'}


class Game:
    def __init__(self, scores, players, completed_at):
        self.scores = scores
        self.players = players
        self.completed_at = completed_at

    @property
    def score_dict(self):
        return { player: score for player, score in zip(self.players, self.scores) }
        
class Match:
    def __init__(self, attrs):
        self.attrs = attrs

    @property
    def scores(self):
        try:
            return [[int(s) for s in scores.split('-')]
                    for scores in self.attrs['scores_csv'].split(',')]
        except:
            import pdb; pdb.set_trace()

    @property
    def players(self): return [self.attrs['player1_id'], self.attrs['player2_id']]

    @property
    def completed_at(self): return self.attrs.get('completed_at')

    @property
    def games(self):
        return [Game(scores, self.players, self.completed_at) for scores in self.scores]
        
class Tournament:
    @classmethod
    def search(cls, max=1000):
        """Use the challonge search feature to get a list of Wingspan tournaments"""
        url = f"https://challonge.com/search/tournaments.json?filters%5Bgame_id%5D=215240&per={max}"
        results = challonge_get(url)['collection']
        results = [r for r in results if r['owner'] in valid_owners]
        tourneys = [cls.by_url(r['link']) for r in results]
        tourneys = [t for t in tourneys if not t.name.lower().startswith('test')]
        return tourneys
    
    @classmethod
    def by_url(cls, url):
        id = challonge_get(f"{url}.json")['tournament']['id']
        return cls.by_id(id)

    @classmethod
    def by_id(cls, id):
        return cls(challonge_get(f"https://api.challonge.com/v1/tournaments/{id}.json")['tournament'])

    def __init__(self, attrs):
        self.attrs = attrs

    @property
    def name(self):
        name = self.attrs['name']
        name = name.strip()
        return name

    @property
    def id(self): return self.attrs['id']

    @property
    def url(self): return f"https://challonge.com/{self.attrs['url']}"

    @property
    def date(self): return self.attrs['started_at']
        
    @cached_property
    def participants(self):
        return [p['participant'] for p in challonge_get(f"https://api.challonge.com/v1/tournaments/{self.id}/participants.json")]

    @cached_property
    def participants_by_id(self):
        by_id = {}
        for p in self.participants:
            by_id[p['id']] = p['name']
            if 'group_player_ids' in p:
                for id in p['group_player_ids']:
                    assert id not in by_id
                    by_id[id] = p['name']
        return by_id
            
    @cached_property
    def matches(self):
        return [
            Match(m['match'])
            for m in challonge_get(f"https://api.challonge.com/v1/tournaments/{self.id}/matches.json")
            if m['match']['state'] == 'complete'
        ]

    @property
    def games(self):
        return [game for match in self.matches for game in match.games]

    @cached_property
    def scores_by_participant(self):
        scores = defaultdict(list)
        for g in self.games:
            for pid, score in g.score_dict.items():
                scores[self.participants_by_id[pid]].append(score)
        return scores

    @cached_property
    def as_json(self):
        return {
              'id': self.id,
              'name': self.name,
              'url': self.url,
              'date': self.date,
              'games': [{
                  'completed_at': game.completed_at,
                  'scores': {
                      self.participants_by_id[game.players[0]]: game.scores[0],
                      self.participants_by_id[game.players[1]]: game.scores[1] 
                  } 
              } for game in self.games]
        }

# %%
t = Tournament(
    challonge_get("https://api.challonge.com/v1/tournaments/13589704.json")['tournament'])
t.name
# Out:
# 'Wingspan World Cup Regionals - Asia'

# %%
t.as_json
# Out:
# {'id': 13589704,
#  'name': 'Wingspan World Cup Regionals - Asia',
#  'url': 'https://challonge.com/7ldxp0zx',
#  'date': '2023-10-14T15:34:11.774+07:00',
#  'games': [{'completed_at': '2023-10-19T19:20:35.234+01:00',
#    'scores': {'mike316': 97, 'thebangzats': 86}},
#   {'completed_at': '2023-10-15T13:17:17.903+01:00',
#    'scores': {'MrSaber': 85, 'Zeemokung': 87}},
#   {'completed_at': '2023-11-03T11:58:38.909+00:00',
#    'scores': {'Sim17': 94, 'otsukuuyan': 85}},
#   {'completed_at': '2023-10-14T20:47:23.445+01:00',
#    'scores': {'WillyPizza': 87, 'Salmonskinroll': 93}},
#   {'completed_at': '2023-10-15T21:22:06.521+01:00',
#    'scores': {'smelly_cat (smellysmellycat)': 85, 'gdhar67 (GasLighter)': 90}},
#   {'completed_at': '2023-10-14T17:47:51.979+01:00',
#    'scores': {'Salmonskinroll': 89, 'smelly_cat (smellysmellycat)': 93}},
#   {'completed_at': '2023-10-20T23:11:54.898+01:00',
#    'scores': {'otsukuuyan': 65, 'WillyPizza': 104}},
#   {'completed_at': '2023-10-15T21:16:14.961+01:00',
#    'scores': {'Zeemokung': 77, 'Sim17': 114}},
#   {'completed_at': '2023-10-22T03:26:16.176+01:00',
#    'scores': {'thebangzats': 93, 'MrSaber': 95}},
#   {'completed_at': '2023-10-19T19:22:36.053+01:00',
#    'scores': {'Arceusisgood': 104, 'mike316': 85}},
#   {'completed_at': '2023-11-04T11:28:21.070+00:00',
#    'scores': {'MrSaber': 108, 'Arceusisgood': 110}},
#   {'completed_at': '2023-10-24T11:45:00.018+01:00',
#    'scores': {'Sim17': 86, 'thebangzats': 101}},
#   {'completed_at': '2023-10-15T13:17:53.080+01:00',
#    'scores': {'WillyPizza': 80, 'Zeemokung': 90}},
#   {'completed_at': '2023-10-28T22:47:29.385+01:00',
#    'scores': {'smelly_cat (smellysmellycat)': 74, 'otsukuuyan': 83}},
#   {'completed_at': '2023-10-30T19:31:52.193+00:00',
#    'scores': {'gdhar67 (GasLighter)': 101, 'Salmonskinroll': 85}},
#   {'completed_at': '2023-10-28T22:47:44.494+01:00',
#    'scores': {'otsukuuyan': 117, 'gdhar67 (GasLighter)': 97}},
#   {'completed_at': '2023-10-22T13:51:50.907+01:00',
#    'scores': {'Zeemokung': 89, 'smelly_cat (smellysmellycat)': 83}},
#   {'completed_at': '2023-10-19T10:55:35.200+01:00',
#    'scores': {'thebangzats': 99, 'WillyPizza': 96}},
#   {'completed_at': '2023-10-26T16:45:43.062+01:00',
#    'scores': {'Arceusisgood': 93, 'Sim17': 98}},
#   {'completed_at': '2023-10-21T09:38:12.267+01:00',
#    'scores': {'mike316': 83, 'MrSaber': 93}},
#   {'completed_at': '2023-10-26T16:45:18.553+01:00',
#    'scores': {'Sim17': 115, 'mike316': 94}},
#   {'completed_at': '2023-10-20T13:53:23.598+01:00',
#    'scores': {'WillyPizza': 90, 'Arceusisgood': 97}},
#   {'completed_at': '2023-10-23T13:39:33.597+01:00',
#    'scores': {'smelly_cat (smellysmellycat)': 99, 'thebangzats': 96}},
#   {'completed_at': '2023-10-15T13:20:34.396+01:00',
#    'scores': {'gdhar67 (GasLighter)': 92, 'Zeemokung': 88}},
#   {'completed_at': '2023-10-20T23:13:28.558+01:00',
#    'scores': {'Salmonskinroll': 104, 'otsukuuyan': 92}},
#   {'completed_at': '2023-10-15T13:19:02.350+01:00',
#    'scores': {'Zeemokung': 97, 'Salmonskinroll': 81}},
#   {'completed_at': '2023-10-19T10:55:22.046+01:00',
#    'scores': {'thebangzats': 94, 'gdhar67 (GasLighter)': 87}},
#   {'completed_at': '2023-10-20T13:52:39.435+01:00',
#    'scores': {'Arceusisgood': 92, 'smelly_cat (smellysmellycat)': 100}},
#   {'completed_at': '2023-10-16T18:45:19.030+01:00',
#    'scores': {'mike316': 90, 'WillyPizza': 103}},
#   {'completed_at': '2023-10-27T16:10:06.167+01:00',
#    'scores': {'MrSaber': 100, 'Sim17': 92}},
#   {'completed_at': '2023-10-15T13:19:59.439+01:00',
#    'scores': {'WillyPizza': 87, 'MrSaber': 80}},
#   {'completed_at': '2023-10-26T16:45:25.744+01:00',
#    'scores': {'smelly_cat (smellysmellycat)': 94, 'mike316': 112}},
#   {'completed_at': '2023-10-19T11:41:01.070+01:00',
#    'scores': {'gdhar67 (GasLighter)': 87, 'Arceusisgood': 83}},
#   {'completed_at': '2023-10-19T10:45:51.710+01:00',
#    'scores': {'Salmonskinroll': 73, 'thebangzats': 108}},
#   {'completed_at': '2023-10-22T03:16:40.574+01:00',
#    'scores': {'otsukuuyan': 90, 'Zeemokung': 90}},
#   {'completed_at': '2023-10-28T22:49:07.995+01:00',
#    'scores': {'thebangzats': 100, 'otsukuuyan': 88}},
#   {'completed_at': '2023-10-19T10:46:28.545+01:00',
#    'scores': {'Arceusisgood': 96, 'Salmonskinroll': 73}},
#   {'completed_at': '2023-10-16T10:53:05.715+01:00',
#    'scores': {'mike316': 112, 'gdhar67 (GasLighter)': 78}},
#   {'completed_at': '2023-10-22T13:51:11.241+01:00',
#    'scores': {'MrSaber': 99, 'smelly_cat (smellysmellycat)': 104}},
#   {'completed_at': '2023-10-15T21:08:22.418+01:00',
#    'scores': {'Sim17': 111, 'WillyPizza': 119}},
#   {'completed_at': '2023-10-23T19:27:17.432+01:00',
#    'scores': {'smelly_cat (smellysmellycat)': 79, 'Sim17': 101}},
#   {'completed_at': '2023-10-15T13:25:20.516+01:00',
#    'scores': {'gdhar67 (GasLighter)': 108, 'MrSaber': 112}},
#   {'completed_at': '2023-10-16T10:54:55.225+01:00',
#    'scores': {'Salmonskinroll': 77, 'mike316': 85}},
#   {'completed_at': '2023-11-03T12:00:30.907+00:00',
#    'scores': {'otsukuuyan': 99, 'Arceusisgood': 103}},
#   {'completed_at': '2023-10-19T19:20:00.513+01:00',
#    'scores': {'Zeemokung': 82, 'thebangzats': 84}},
#   {'completed_at': '2023-10-19T10:45:46.257+01:00',
#    'scores': {'Arceusisgood': 123, 'Zeemokung': 104}},
#   {'completed_at': '2023-11-04T11:30:59.462+00:00',
#    'scores': {'mike316': 112, 'otsukuuyan': 104}},
#   {'completed_at': '2023-10-15T13:21:13.107+01:00',
#    'scores': {'MrSaber': 97, 'Salmonskinroll': 88}},
#   {'completed_at': '2023-10-24T19:41:46.340+01:00',
#    'scores': {'Sim17': 107, 'gdhar67 (GasLighter)': 74}},
#   {'completed_at': '2023-10-16T18:39:27.226+01:00',
#    'scores': {'WillyPizza': 101, 'smelly_cat (smellysmellycat)': 80}},
#   {'completed_at': '2023-10-14T20:41:16.849+01:00',
#    'scores': {'gdhar67 (GasLighter)': 96, 'WillyPizza': 84}},
#   {'completed_at': '2023-10-18T14:28:26.762+01:00',
#    'scores': {'Salmonskinroll': 80, 'Sim17': 93}},
#   {'completed_at': '2023-11-04T11:32:05.007+00:00',
#    'scores': {'otsukuuyan': 132, 'MrSaber': 101}},
#   {'completed_at': '2023-10-15T13:05:55.591+01:00',
#    'scores': {'Zeemokung': 79, 'mike316': 100}},
#   {'completed_at': '2023-10-20T13:52:44.556+01:00',
#    'scores': {'thebangzats': 90, 'Arceusisgood': 77}}]}

# %% [markdown]
# # Fetch tournaments

# %%
tourneys = Tournament.search()

# %%
tourney_json = []
bad_tourneys = []
for t in tourneys:
    try:
        tourney_json.append(t.as_json)
    except:
        bad_tourneys.append(t)

# %% [markdown]
# # Normalize user names (there are a lot of near-duplicates :/)

# %%
tourney_json[0]
# Out:
# {'id': 13768744,
#  'name': 'Wandering Albatross Wrestle - Stage 2',
#  'url': 'https://challonge.com/o7vu4w07',
#  'date': '2023-11-24T11:18:31.483+01:00',
#  'games': []}

# %%
users = set()

for t in tourney_json:
    for game in t['games']:
        for user, _score in game['scores'].items():
            users.add(user)

users = list(sorted(list(users)))

# %%
import re

def normalize_name(name):
    name = name.lower().split('(')[0].split(' -')[0].split('\t')[0].split(' |')[0].split('#')[0]
    name = name.replace("_", " ")
    name = name.replace("ign: ", "")
    name = name.replace(" ", "")
    #name = re.sub(r"(^[a-z])", "", name)
    name = name.strip()
    return name

normalized_user_names = { name: normalize_name(name) for name in users }

# %%
from collections import defaultdict

user_counts = defaultdict(int)

for t in tourney_json:
    for game in t['games']:
        for user, _score in game['scores'].items():
            user_counts[normalized_user_names[user]] += 1

# %%
from difflib import get_close_matches
import numpy as np

substitutions = {}

for name in set(user_counts.keys()):
    other_names = [n for n in set(user_counts.keys()) if n != name]
    matches = get_close_matches(name, other_names, cutoff=0.75)

    if matches:
        names = [name] + matches
        counts = [user_counts[n] for n in names]
        idx = np.argmax(counts)
        for n in names:
            if n != names[idx]:
                substitutions[n] = names[idx]

# %%
substitutions2 = {'sleephead': 'sleepyhead',
 'tay-ray': 'tayray',
 #'taykay': 'tayray',
# 'rokb': 'rob',
# 'robin': 'rob',
# 'dagger': 'digger',
 'żyraf🦒': 'żyraf',
 'zyraf': 'żyraf',
 'thecomedian91': 'thec0median',
 'thec0median91': 'thec0median',
 'irek': 'ireku',
 'no-m': 'no~m',
 'nom': 'no~m',
# 'wingsplaingaming': 'wingspanner',
# 'bluethroat': 'bluethroat4life',
 'wingspanner2': 'wingspanner',
 #'eurasiannuthatch': 'corsicannuthatch',
 #'corsicannuthatch': 'eurasiannuthatch',
 #'team23': 'team20',
 #'sandro': 'andreko',
 'jeasthebeast': 'jeastthebeast',
 #'jeastthebeast+malue': 'jeastthebeast',
# 'eurasianhobby': 'eurasianjay',
# 'ltrudat': 'gtrudat',
 'elsapoguapobot': 'elsapoguapo',
 'dozo': 'dozi',
 'theflash04': 'theflash',
 #'scaredofdiamonds': 'scaredofbirds',
 #'wingsplain': 'wingspanner',
 'seechristy': 'seechristine',
 #'commonmoorhen': 'commonraven',
 #'eurasianjay': 'eurasianhobby',
 #'spartafnfan13+wayward': 'spartanfan13',
 'stormchaser20': 'stormchaser',
 #'merisabear': 'mrsaber',
 'ronster': 'ronster7',
 #'mtrooster': 'ronster',
 'ooievaar🇳🇱': 'ooievaar',
 #'avery': 'av0ry',
 'spartafnfan13': 'spartanfan13',
 #'white-backedwoodpecker': 'blackwoodpecker',
 #'groovenbeast': 'groovenstein',
 'falblingius': 'falblinger',
 #'eurasiansparrowhawk': 'eurasiantreesparrow',
 'nedmund13': 'nedmund',
 'nedmud13': 'nedmund',
 'chuck': 'chuckaus',
 'mothertucker': 'mothertuckers',
# 'eurasiannutcracker': 'eurasiannuthatch',
 'yippecahier': 'yippeecahier',
# 'team20': 'team23',
# 'eurasiantreesparrow': 'eurasiansparrowhawk'
                 }

# %%
normalized_user_names2 = { k: substitutions2.get(v, v) for k, v in normalized_user_names.items() }

# %%
names_matching_normalized = defaultdict(list)
for k, v in normalized_user_names2.items():
    names_matching_normalized[v].append(k)

# %%
from collections import Counter

overall_counts = Counter([
    user
    for t in tourney_json
    for game in t['games']
    for user, _score in game['scores'].items()
])

# %%
canonical_names = {}

for normalized_name, variants in names_matching_normalized.items():
    counts_by_variant = [overall_counts[v] for v in variants]
    canonical_names[normalized_name] = variants[np.argmax(counts_by_variant)]

# %%
normalized_tourneys = []
for t in tourney_json:
    new_tourney = dict(t)
    games = new_tourney['games']
    new_games = []
    for game in games:
        new_game = dict(game)
        new_scores = {}
        for k, v in game['scores'].items():
            new_scores[canonical_names[normalized_user_names2[k]]] = v
        new_game['scores'] = new_scores
        new_games.append(new_game)
    new_tourney['games'] = new_games
    normalized_tourneys.append(new_tourney)

# %%
normalized_tourneys[1]
# Out:
# {'id': 13718089,
#  'name': 'Xenopsaris X-Factor',
#  'url': 'https://challonge.com/wtds_xx',
#  'date': None,
#  'games': [{'completed_at': '2023-11-18T12:15:51.338+08:00',
#    'scores': {'lemon': 70, 'ChopYouUp': 133}},
#   {'completed_at': '2023-11-18T12:15:51.338+08:00',
#    'scores': {'lemon': 81, 'ChopYouUp': 114}},
#   {'completed_at': '2023-11-18T12:15:51.338+08:00',
#    'scores': {'lemon': 0, 'ChopYouUp': 0}},
#   {'completed_at': '2023-11-19T00:23:09.923+08:00',
#    'scores': {'Orcinus': 105, 'NoRavens': 107}},
#   {'completed_at': '2023-11-19T00:23:09.923+08:00',
#    'scores': {'Orcinus': 81, 'NoRavens': 103}},
#   {'completed_at': '2023-11-19T00:23:09.923+08:00',
#    'scores': {'Orcinus': 0, 'NoRavens': 0}},
#   {'completed_at': '2023-11-18T00:35:14.124+08:00',
#    'scores': {'smelly_cat': 99, 'gtrudat': 82}},
#   {'completed_at': '2023-11-18T00:35:14.124+08:00',
#    'scores': {'smelly_cat': 92, 'gtrudat': 94}},
#   {'completed_at': '2023-11-18T00:35:14.124+08:00',
#    'scores': {'smelly_cat': 108, 'gtrudat': 119}},
#   {'completed_at': '2023-11-15T09:20:19.853+08:00',
#    'scores': {'gaussiancurve': 102, 'spocpes': 75}},
#   {'completed_at': '2023-11-15T09:20:19.853+08:00',
#    'scores': {'gaussiancurve': 103, 'spocpes': 71}},
#   {'completed_at': '2023-11-15T09:20:19.853+08:00',
#    'scores': {'gaussiancurve': 0, 'spocpes': 0}},
#   {'completed_at': '2023-11-19T23:15:41.105+08:00',
#    'scores': {'gtrudat': 90, 'gaussiancurve': 91}},
#   {'completed_at': '2023-11-19T23:15:41.105+08:00',
#    'scores': {'gtrudat': 74, 'gaussiancurve': 75}},
#   {'completed_at': '2023-11-19T23:15:41.105+08:00',
#    'scores': {'gtrudat': 0, 'gaussiancurve': 0}},
#   {'completed_at': '2023-11-17T07:03:50.923+08:00',
#    'scores': {'Nico1968': 79, 'AmithA': 83}},
#   {'completed_at': '2023-11-17T07:03:50.923+08:00',
#    'scores': {'Nico1968': 61, 'AmithA': 94}},
#   {'completed_at': '2023-11-17T07:03:50.923+08:00',
#    'scores': {'Nico1968': 0, 'AmithA': 0}},
#   {'completed_at': '2023-11-19T04:50:01.440+08:00',
#    'scores': {'Stalledbird': 90, 'Palindrome': 83}},
#   {'completed_at': '2023-11-19T04:50:01.440+08:00',
#    'scores': {'Stalledbird': 81, 'Palindrome': 93}},
#   {'completed_at': '2023-11-19T04:50:01.440+08:00',
#    'scores': {'Stalledbird': 71, 'Palindrome': 68}},
#   {'completed_at': '2023-11-14T07:56:26.734+08:00',
#    'scores': {'ScaredofBirds': 109, 'DMonkey225': 54}},
#   {'completed_at': '2023-11-14T07:56:26.734+08:00',
#    'scores': {'ScaredofBirds': 83, 'DMonkey225': 56}},
#   {'completed_at': '2023-11-14T07:56:26.734+08:00',
#    'scores': {'ScaredofBirds': 0, 'DMonkey225': 0}},
#   {'completed_at': '2023-11-14T06:38:11.593+08:00',
#    'scores': {'GraDog22 (=IGN)': 96, 'Huxley3000': 84}},
#   {'completed_at': '2023-11-14T06:38:11.593+08:00',
#    'scores': {'GraDog22 (=IGN)': 86, 'Huxley3000': 102}},
#   {'completed_at': '2023-11-14T06:38:11.593+08:00',
#    'scores': {'GraDog22 (=IGN)': 101, 'Huxley3000': 113}},
#   {'completed_at': '2023-11-21T18:59:38.017+08:00',
#    'scores': {'AmithA': 76, 'Stalledbird': 77}},
#   {'completed_at': '2023-11-21T18:59:38.017+08:00',
#    'scores': {'AmithA': 91, 'Stalledbird': 107}},
#   {'completed_at': '2023-11-21T18:59:38.017+08:00',
#    'scores': {'AmithA': 0, 'Stalledbird': 0}},
#   {'completed_at': '2023-11-18T00:37:23.973+08:00',
#    'scores': {'ScaredofBirds': 98, 'Huxley3000': 83}},
#   {'completed_at': '2023-11-18T00:37:23.973+08:00',
#    'scores': {'ScaredofBirds': 111, 'Huxley3000': 91}},
#   {'completed_at': '2023-11-18T00:37:23.973+08:00',
#    'scores': {'ScaredofBirds': 0, 'Huxley3000': 0}},
#   {'completed_at': '2023-11-19T04:54:27.578+08:00',
#    'scores': {'travs': 93, 'Tiny Geese': 83}},
#   {'completed_at': '2023-11-19T04:54:27.578+08:00',
#    'scores': {'travs': 82, 'Tiny Geese': 98}},
#   {'completed_at': '2023-11-19T04:54:27.578+08:00',
#    'scores': {'travs': 88, 'Tiny Geese': 79}},
#   {'completed_at': '2023-11-16T19:10:26.849+08:00',
#    'scores': {'Merisabear': 87, 'BlackSpice28': 108}},
#   {'completed_at': '2023-11-16T19:10:26.849+08:00',
#    'scores': {'Merisabear': 75, 'BlackSpice28': 93}},
#   {'completed_at': '2023-11-16T19:10:26.849+08:00',
#    'scores': {'Merisabear': 0, 'BlackSpice28': 0}},
#   {'completed_at': '2023-11-17T11:35:07.490+08:00',
#    'scores': {'z12monkeys': 83, 'WeirdOwl': 78}},
#   {'completed_at': '2023-11-17T11:35:07.490+08:00',
#    'scores': {'z12monkeys': 88, 'WeirdOwl': 97}},
#   {'completed_at': '2023-11-17T11:35:07.490+08:00',
#    'scores': {'z12monkeys': 84, 'WeirdOwl': 85}},
#   {'completed_at': '2023-11-14T04:29:45.597+08:00',
#    'scores': {'Foxjoke': 117, 'WillyPizza': 92}},
#   {'completed_at': '2023-11-14T04:29:45.597+08:00',
#    'scores': {'Foxjoke': 88, 'WillyPizza': 113}},
#   {'completed_at': '2023-11-14T04:29:45.597+08:00',
#    'scores': {'Foxjoke': 108, 'WillyPizza': 122}},
#   {'completed_at': '2023-11-21T19:00:34.838+08:00',
#    'scores': {'travs': 85, 'BlackSpice28': 108}},
#   {'completed_at': '2023-11-21T19:00:34.838+08:00',
#    'scores': {'travs': 103, 'BlackSpice28': 129}},
#   {'completed_at': '2023-11-21T19:00:34.838+08:00',
#    'scores': {'travs': 0, 'BlackSpice28': 0}},
#   {'completed_at': '2023-11-18T00:35:58.323+08:00',
#    'scores': {'WeirdOwl': 97, 'WillyPizza': 96}},
#   {'completed_at': '2023-11-18T00:35:58.323+08:00',
#    'scores': {'WeirdOwl': 94, 'WillyPizza': 90}},
#   {'completed_at': '2023-11-18T00:35:58.323+08:00',
#    'scores': {'WeirdOwl': 0, 'WillyPizza': 0}},
#   {'completed_at': '2023-11-22T04:28:02.040+08:00',
#    'scores': {'BlackSpice28': 80, 'WeirdOwl': 76}},
#   {'completed_at': '2023-11-22T04:28:02.040+08:00',
#    'scores': {'BlackSpice28': 84, 'WeirdOwl': 91}},
#   {'completed_at': '2023-11-22T04:28:02.040+08:00',
#    'scores': {'BlackSpice28': 107, 'WeirdOwl': 82}},
#   {'completed_at': '2023-11-14T04:32:36.923+08:00',
#    'scores': {'Shepherd0': 104, 'SegalLikeTheBird': 100}},
#   {'completed_at': '2023-11-14T04:32:36.923+08:00',
#    'scores': {'Shepherd0': 95, 'SegalLikeTheBird': 101}},
#   {'completed_at': '2023-11-14T04:32:36.923+08:00',
#    'scores': {'Shepherd0': 101, 'SegalLikeTheBird': 96}},
#   {'completed_at': '2023-11-16T19:10:24.669+08:00',
#    'scores': {'MrSaber': 80, 'cgjunior': 87}},
#   {'completed_at': '2023-11-16T19:10:24.669+08:00',
#    'scores': {'MrSaber': 101, 'cgjunior': 98}},
#   {'completed_at': '2023-11-16T19:10:24.669+08:00',
#    'scores': {'MrSaber': 95, 'cgjunior': 105}},
#   {'completed_at': '2023-11-16T22:41:30.352+08:00',
#    'scores': {'_aquanaut': 99, 'Maskonur': 90}},
#   {'completed_at': '2023-11-16T22:41:30.352+08:00',
#    'scores': {'_aquanaut': 71, 'Maskonur': 97}},
#   {'completed_at': '2023-11-16T22:41:30.352+08:00',
#    'scores': {'_aquanaut': 72, 'Maskonur': 93}},
#   {'completed_at': '2023-11-19T04:45:06.627+08:00',
#    'scores': {'Jjlig2mobile2': 87, 'thehoneyeater87': 76}},
#   {'completed_at': '2023-11-19T04:45:06.627+08:00',
#    'scores': {'Jjlig2mobile2': 132, 'thehoneyeater87': 122}},
#   {'completed_at': '2023-11-19T04:45:06.627+08:00',
#    'scores': {'Jjlig2mobile2': 0, 'thehoneyeater87': 0}},
#   {'completed_at': '2023-11-19T21:59:02.089+08:00',
#    'scores': {'Shepherd0': 111, 'cgjunior': 74}},
#   {'completed_at': '2023-11-19T21:59:02.089+08:00',
#    'scores': {'Shepherd0': 106, 'cgjunior': 85}},
#   {'completed_at': '2023-11-19T21:59:02.089+08:00',
#    'scores': {'Shepherd0': 0, 'cgjunior': 0}},
#   {'completed_at': '2023-11-20T10:10:19.301+08:00',
#    'scores': {'Maskonur': 91, 'Jjlig2mobile2': 83}},
#   {'completed_at': '2023-11-20T10:10:19.301+08:00',
#    'scores': {'Maskonur': 90, 'Jjlig2mobile2': 89}},
#   {'completed_at': '2023-11-20T10:10:19.301+08:00',
#    'scores': {'Maskonur': 0, 'Jjlig2mobile2': 0}},
#   {'completed_at': '2023-11-22T20:04:35.218+08:00',
#    'scores': {'Shepherd0': 97, 'Maskonur': 96}},
#   {'completed_at': '2023-11-22T20:04:35.218+08:00',
#    'scores': {'Shepherd0': 87, 'Maskonur': 90}},
#   {'completed_at': '2023-11-22T20:04:35.218+08:00',
#    'scores': {'Shepherd0': 98, 'Maskonur': 115}},
#   {'completed_at': '2023-11-16T18:31:32.052+08:00',
#    'scores': {'Sim17': 94, 'bushNIT': 80}},
#   {'completed_at': '2023-11-16T18:31:32.052+08:00',
#    'scores': {'Sim17': 104, 'bushNIT': 106}},
#   {'completed_at': '2023-11-16T18:31:32.052+08:00',
#    'scores': {'Sim17': 103, 'bushNIT': 81}},
#   {'completed_at': '2023-11-20T10:05:42.449+08:00',
#    'scores': {'JunePaik': 105, 'vpol55': 94}},
#   {'completed_at': '2023-11-20T10:05:42.449+08:00',
#    'scores': {'JunePaik': 89, 'vpol55': 103}},
#   {'completed_at': '2023-11-20T10:05:42.449+08:00',
#    'scores': {'JunePaik': 79, 'vpol55': 101}},
#   {'completed_at': '2023-11-20T10:11:50.723+08:00',
#    'scores': {'Abiath': 78, 'Waterman': 81}},
#   {'completed_at': '2023-11-20T10:11:50.723+08:00',
#    'scores': {'Abiath': 109, 'Waterman': 98}},
#   {'completed_at': '2023-11-20T10:11:50.723+08:00',
#    'scores': {'Abiath': 93, 'Waterman': 95}},
#   {'completed_at': '2023-11-19T22:02:59.732+08:00',
#    'scores': {'SleepyHead': 101, 'KarlHungus': 95}},
#   {'completed_at': '2023-11-19T22:02:59.732+08:00',
#    'scores': {'SleepyHead': 90, 'KarlHungus': 87}},
#   {'completed_at': '2023-11-19T22:02:59.732+08:00',
#    'scores': {'SleepyHead': 0, 'KarlHungus': 0}},
#   {'completed_at': '2023-11-14T04:29:20.313+08:00',
#    'scores': {'EpicSaxGuy': 94, 'matthew9890': 104}},
#   {'completed_at': '2023-11-14T04:29:20.313+08:00',
#    'scores': {'EpicSaxGuy': 112, 'matthew9890': 104}},
#   {'completed_at': '2023-11-14T04:29:20.313+08:00',
#    'scores': {'EpicSaxGuy': 119, 'matthew9890': 122}},
#   {'completed_at': '2023-11-16T18:55:38.563+08:00',
#    'scores': {'SPAKEME': 83, 'Naketano': 89}},
#   {'completed_at': '2023-11-16T18:55:38.563+08:00',
#    'scores': {'SPAKEME': 81, 'Naketano': 86}},
#   {'completed_at': '2023-11-16T18:55:38.563+08:00',
#    'scores': {'SPAKEME': 0, 'Naketano': 0}},
#   {'completed_at': '2023-11-15T09:22:18.509+08:00',
#    'scores': {'gdhar67': 83, 'MaudlinCake': 91}},
#   {'completed_at': '2023-11-15T09:22:18.509+08:00',
#    'scores': {'gdhar67': 105, 'MaudlinCake': 94}},
#   {'completed_at': '2023-11-15T09:22:18.509+08:00',
#    'scores': {'gdhar67': 95, 'MaudlinCake': 109}},
#   {'completed_at': '2023-11-17T19:38:08.492+08:00',
#    'scores': {'Solskjaer025! (IGN Damsgaard)': 90, 'Quacky': 78}},
#   {'completed_at': '2023-11-17T19:38:08.492+08:00',
#    'scores': {'Solskjaer025! (IGN Damsgaard)': 74, 'Quacky': 86}},
#   {'completed_at': '2023-11-17T19:38:08.492+08:00',
#    'scores': {'Solskjaer025! (IGN Damsgaard)': 70, 'Quacky': 82}},
#   {'completed_at': '2023-11-18T00:35:39.827+08:00',
#    'scores': {'matthew9890': 88, 'Naketano': 74}},
#   {'completed_at': '2023-11-18T00:35:39.827+08:00',
#    'scores': {'matthew9890': 101, 'Naketano': 80}},
#   {'completed_at': '2023-11-18T00:35:39.827+08:00',
#    'scores': {'matthew9890': 0, 'Naketano': 0}},
#   {'completed_at': '2023-11-15T09:34:23.755+08:00',
#    'scores': {'Birdwatchermobile': 73, 'jeastthebeast': 80}},
#   {'completed_at': '2023-11-15T09:34:23.755+08:00',
#    'scores': {'Birdwatchermobile': 85, 'jeastthebeast': 90}},
#   {'completed_at': '2023-11-15T09:34:23.755+08:00',
#    'scores': {'Birdwatchermobile': 0, 'jeastthebeast': 0}},
#   {'completed_at': '2023-11-19T05:49:48.830+08:00',
#    'scores': {'CheeseDreams': 98, 'thedetermin8or': 92}},
#   {'completed_at': '2023-11-19T05:49:48.830+08:00',
#    'scores': {'CheeseDreams': 83, 'thedetermin8or': 97}},
#   {'completed_at': '2023-11-19T05:49:48.830+08:00',
#    'scores': {'CheeseDreams': 113, 'thedetermin8or': 123}},
#   {'completed_at': '2023-11-17T19:37:54.599+08:00',
#    'scores': {'b0romir': 76, 'RickCissel': 88}},
#   {'completed_at': '2023-11-17T19:37:54.599+08:00',
#    'scores': {'b0romir': 70, 'RickCissel': 99}},
#   {'completed_at': '2023-11-17T19:37:54.599+08:00',
#    'scores': {'b0romir': 0, 'RickCissel': 0}},
#   {'completed_at': '2023-11-15T09:25:18.838+08:00',
#    'scores': {'Flan': 112, 'Danko': 107}},
#   {'completed_at': '2023-11-15T09:25:18.838+08:00',
#    'scores': {'Flan': 84, 'Danko': 95}},
#   {'completed_at': '2023-11-15T09:25:18.838+08:00',
#    'scores': {'Flan': 91, 'Danko': 93}},
#   {'completed_at': '2023-11-21T07:12:38.011+08:00',
#    'scores': {'jeastthebeast': 102, 'thedetermin8or': 78}},
#   {'completed_at': '2023-11-21T07:12:38.011+08:00',
#    'scores': {'jeastthebeast': 106, 'thedetermin8or': 97}},
#   {'completed_at': '2023-11-21T07:12:38.011+08:00',
#    'scores': {'jeastthebeast': 0, 'thedetermin8or': 0}},
#   {'completed_at': '2023-11-19T04:51:16.163+08:00',
#    'scores': {'RickCissel': 111, 'Danko': 130}},
#   {'completed_at': '2023-11-19T04:51:16.163+08:00',
#    'scores': {'RickCissel': 109, 'Danko': 83}},
#   {'completed_at': '2023-11-19T04:51:16.163+08:00',
#    'scores': {'RickCissel': 88, 'Danko': 105}},
#   {'completed_at': '2023-11-22T04:33:23.022+08:00',
#    'scores': {'jeastthebeast': 95, 'Danko': 99}},
#   {'completed_at': '2023-11-22T04:33:23.022+08:00',
#    'scores': {'jeastthebeast': 101, 'Danko': 86}},
#   {'completed_at': '2023-11-22T04:33:23.022+08:00',
#    'scores': {'jeastthebeast': 75, 'Danko': 97}},
#   {'completed_at': '2023-11-14T04:30:26.324+08:00',
#    'scores': {'WoodpeckerJoe': 98, 'Terracotta (aLL1e)': 74}},
#   {'completed_at': '2023-11-14T04:30:26.324+08:00',
#    'scores': {'WoodpeckerJoe': 123, 'Terracotta (aLL1e)': 108}},
#   {'completed_at': '2023-11-14T04:30:26.324+08:00',
#    'scores': {'WoodpeckerJoe': 0, 'Terracotta (aLL1e)': 0}},
#   {'completed_at': '2023-11-15T10:47:56.942+08:00',
#    'scores': {'bronka': 93, 'BalletMage': 76}},
#   {'completed_at': '2023-11-15T10:47:56.942+08:00',
#    'scores': {'bronka': 95, 'BalletMage': 97}},
#   {'completed_at': '2023-11-15T10:47:56.942+08:00',
#    'scores': {'bronka': 74, 'BalletMage': 88}},
#   {'completed_at': '2023-11-17T07:03:12.057+08:00',
#    'scores': {'captain_awesome.': 81, 'Ben_fm': 96}},
#   {'completed_at': '2023-11-17T07:03:12.057+08:00',
#    'scores': {'captain_awesome.': 107, 'Ben_fm': 90}},
#   {'completed_at': '2023-11-17T07:03:12.057+08:00',
#    'scores': {'captain_awesome.': 87, 'Ben_fm': 82}},
#   {'completed_at': '2023-11-20T10:09:04.388+08:00',
#    'scores': {'Jamesvanderbeak': 70, 'Scotsword': 94}},
#   {'completed_at': '2023-11-20T10:09:04.388+08:00',
#    'scores': {'Jamesvanderbeak': 87, 'Scotsword': 95}},
#   {'completed_at': '2023-11-20T10:09:04.388+08:00',
#    'scores': {'Jamesvanderbeak': 0, 'Scotsword': 0}},
#   {'completed_at': '2023-11-17T08:49:36.242+08:00',
#    'scores': {'WoodpeckerJoe': 88, 'BalletMage': 87}},
#   {'completed_at': '2023-11-17T08:49:36.242+08:00',
#    'scores': {'WoodpeckerJoe': 81, 'BalletMage': 95}},
#   {'completed_at': '2023-11-17T08:49:36.242+08:00',
#    'scores': {'WoodpeckerJoe': 78, 'BalletMage': 79}},
#   {'completed_at': '2023-11-15T09:26:39.201+08:00',
#    'scores': {'Ireku': 95, 'gdpeck (72BirdSong)': 80}},
#   {'completed_at': '2023-11-15T09:26:39.201+08:00',
#    'scores': {'Ireku': 115, 'gdpeck (72BirdSong)': 85}},
#   {'completed_at': '2023-11-15T09:26:39.201+08:00',
#    'scores': {'Ireku': 0, 'gdpeck (72BirdSong)': 0}},
#   {'completed_at': '2023-11-19T23:30:53.993+08:00',
#    'scores': {'dagger_hashimoto_': 80, 'GeorgeV89': 95}},
#   {'completed_at': '2023-11-19T23:30:53.993+08:00',
#    'scores': {'dagger_hashimoto_': 91, 'GeorgeV89': 98}},
#   {'completed_at': '2023-11-19T23:30:53.993+08:00',
#    'scores': {'dagger_hashimoto_': 0, 'GeorgeV89': 0}},
#   {'completed_at': '2023-11-13T08:33:06.231+08:00',
#    'scores': {'duckie': 68, 'SadRick (IGN)': 88}},
#   {'completed_at': '2023-11-13T08:33:06.231+08:00',
#    'scores': {'duckie': 85, 'SadRick (IGN)': 90}},
#   {'completed_at': '2023-11-13T08:33:06.231+08:00',
#    'scores': {'duckie': 0, 'SadRick (IGN)': 0}},
#   {'completed_at': '2023-11-19T21:59:42.468+08:00',
#    'scores': {'nathanroos': 102, 'de Visme': 99}},
#   {'completed_at': '2023-11-19T21:59:42.468+08:00',
#    'scores': {'nathanroos': 90, 'de Visme': 126}},
#   {'completed_at': '2023-11-19T21:59:42.468+08:00',
#    'scores': {'nathanroos': 100, 'de Visme': 101}},
#   {'completed_at': '2023-11-21T07:13:43.572+08:00',
#    'scores': {'Ireku': 119, 'GeorgeV89': 96}},
#   {'completed_at': '2023-11-21T07:13:43.572+08:00',
#    'scores': {'Ireku': 117, 'GeorgeV89': 94}},
#   {'completed_at': '2023-11-21T07:13:43.572+08:00',
#    'scores': {'Ireku': 0, 'GeorgeV89': 0}},
#   {'completed_at': '2023-11-24T02:58:50.599+08:00',
#    'scores': {'SadRick (IGN)': 109, 'de Visme': 89}},
#   {'completed_at': '2023-11-24T02:58:50.599+08:00',
#    'scores': {'SadRick (IGN)': 102, 'de Visme': 106}},
#   {'completed_at': '2023-11-24T02:58:50.599+08:00',
#    'scores': {'SadRick (IGN)': 90, 'de Visme': 99}},
#   {'completed_at': '2023-11-15T09:27:46.536+08:00',
#    'scores': {'Rampichino': 70, 'erikaloveducks': 71}},
#   {'completed_at': '2023-11-15T09:27:46.536+08:00',
#    'scores': {'Rampichino': 76, 'erikaloveducks': 73}},
#   {'completed_at': '2023-11-15T09:27:46.536+08:00',
#    'scores': {'Rampichino': 74, 'erikaloveducks': 86}},
#   {'completed_at': '2023-11-15T09:39:30.442+08:00',
#    'scores': {'Embrifox': 88, 'sable_knight': 85}},
#   {'completed_at': '2023-11-15T09:39:30.442+08:00',
#    'scores': {'Embrifox': 76, 'sable_knight': 95}},
#   {'completed_at': '2023-11-15T09:39:30.442+08:00',
#    'scores': {'Embrifox': 79, 'sable_knight': 75}},
#   {'completed_at': '2023-11-15T10:48:43.323+08:00',
#    'scores': {'BeakMajik': 78, 'AWingandaPrayer': 55}},
#   {'completed_at': '2023-11-15T10:48:43.323+08:00',
#    'scores': {'BeakMajik': 69, 'AWingandaPrayer': 89}},
#   {'completed_at': '2023-11-15T10:48:43.323+08:00',
#    'scores': {'BeakMajik': 80, 'AWingandaPrayer': 62}},
#   {'completed_at': '2023-11-20T02:05:49.783+08:00',
#    'scores': {'jbc999': 90, 'IGN GokuMatos': 108}},
#   {'completed_at': '2023-11-20T02:05:49.783+08:00',
#    'scores': {'jbc999': 98, 'IGN GokuMatos': 113}},
#   {'completed_at': '2023-11-20T02:05:49.783+08:00',
#    'scores': {'jbc999': 0, 'IGN GokuMatos': 0}},
#   {'completed_at': '2023-11-17T11:35:42.171+08:00',
#    'scores': {'erikaloveducks': 75, 'Embrifox': 76}},
#   {'completed_at': '2023-11-17T11:35:42.171+08:00',
#    'scores': {'erikaloveducks': 103, 'Embrifox': 98}},
#   {'completed_at': '2023-11-17T11:35:42.171+08:00',
#    'scores': {'erikaloveducks': 67, 'Embrifox': 74}},
#   {'completed_at': '2023-11-22T04:36:42.042+08:00',
#    'scores': {'BeakMajik': 76, 'IGN GokuMatos': 86}},
#   {'completed_at': '2023-11-22T04:36:42.042+08:00',
#    'scores': {'BeakMajik': 100, 'IGN GokuMatos': 108}},
#   {'completed_at': '2023-11-22T04:36:42.042+08:00',
#    'scores': {'BeakMajik': 0, 'IGN GokuMatos': 0}},
#   {'completed_at': '2023-11-25T02:22:41.412+08:00',
#    'scores': {'Embrifox': 88, 'IGN GokuMatos': 99}},
#   {'completed_at': '2023-11-25T02:22:41.412+08:00',
#    'scores': {'Embrifox': 86, 'IGN GokuMatos': 99}},
#   {'completed_at': '2023-11-25T02:22:41.412+08:00',
#    'scores': {'Embrifox': 0, 'IGN GokuMatos': 0}},
#   {'completed_at': '2023-11-17T11:36:09.721+08:00',
#    'scores': {'JuliusDiamond': 90, 'DuchessOfClifton': 80}},
#   {'completed_at': '2023-11-17T11:36:09.721+08:00',
#    'scores': {'JuliusDiamond': 96, 'DuchessOfClifton': 81}},
#   {'completed_at': '2023-11-17T11:36:09.721+08:00',
#    'scores': {'JuliusDiamond': 0, 'DuchessOfClifton': 0}},
#   {'completed_at': '2023-11-20T10:13:09.897+08:00',
#    'scores': {'IV1738': 80, 'MortalWings': 78}},
#   {'completed_at': '2023-11-20T10:13:09.897+08:00',
#    'scores': {'IV1738': 72, 'MortalWings': 98}},
#   {'completed_at': '2023-11-20T10:13:09.897+08:00',
#    'scores': {'IV1738': 96, 'MortalWings': 118}},
#   {'completed_at': '2023-11-13T21:26:27.845+08:00',
#    'scores': {'slejo': 80, 'Arceusisgood': 100}},
#   {'completed_at': '2023-11-13T21:26:27.845+08:00',
#    'scores': {'slejo': 76, 'Arceusisgood': 113}},
#   {'completed_at': '2023-11-13T21:26:27.845+08:00',
#    'scores': {'slejo': 0, 'Arceusisgood': 0}},
#   {'completed_at': '2023-11-15T09:20:11.074+08:00',
#    'scores': {'taykay (IGN toznom)': 67, 'TheGreenClarinet': 94}},
#   {'completed_at': '2023-11-15T09:20:11.074+08:00',
#    'scores': {'taykay (IGN toznom)': 85, 'TheGreenClarinet': 94}},
#   {'completed_at': '2023-11-15T09:20:11.074+08:00',
#    'scores': {'taykay (IGN toznom)': 0, 'TheGreenClarinet': 0}},
#   {'completed_at': '2023-11-22T05:14:43.335+08:00',
#    'scores': {'JuliusDiamond': 86, 'MortalWings': 81}},
#   {'completed_at': '2023-11-22T05:14:43.335+08:00',
#    'scores': {'JuliusDiamond': 116, 'MortalWings': 94}},
#   {'completed_at': '2023-11-22T05:14:43.335+08:00',
#    'scores': {'JuliusDiamond': 0, 'MortalWings': 0}},
#   {'completed_at': '2023-11-19T11:43:41.280+08:00',
#    'scores': {'Arceusisgood': 104, 'TheGreenClarinet': 93}},
#   {'completed_at': '2023-11-19T11:43:41.280+08:00',
#    'scores': {'Arceusisgood': 111, 'TheGreenClarinet': 90}},
#   {'completed_at': '2023-11-19T11:43:41.280+08:00',
#    'scores': {'Arceusisgood': 0, 'TheGreenClarinet': 0}},
#   {'completed_at': '2023-11-18T20:18:03.751+08:00',
#    'scores': {'Bargoff': 87, 'mrtriggerhandz': 88}},
#   {'completed_at': '2023-11-18T20:18:03.751+08:00',
#    'scores': {'Bargoff': 77, 'mrtriggerhandz': 89}},
#   {'completed_at': '2023-11-18T20:18:03.751+08:00',
#    'scores': {'Bargoff': 0, 'mrtriggerhandz': 0}},
#   {'completed_at': '2023-11-16T18:58:20.362+08:00',
#    'scores': {'HawkLake': 109, 'FractalChess2': 122}},
#   {'completed_at': '2023-11-16T18:58:20.362+08:00',
#    'scores': {'HawkLake': 109, 'FractalChess2': 125}},
#   {'completed_at': '2023-11-16T18:58:20.362+08:00',
#    'scores': {'HawkLake': 0, 'FractalChess2': 0}},
#   {'completed_at': '2023-11-13T08:35:46.236+08:00',
#    'scores': {'MichaelTheGrackle': 94, 'corvogordo': 66}},
#   {'completed_at': '2023-11-13T08:35:46.236+08:00',
#    'scores': {'MichaelTheGrackle': 103, 'corvogordo': 86}},
#   {'completed_at': '2023-11-13T08:35:46.236+08:00',
#    'scores': {'MichaelTheGrackle': 0, 'corvogordo': 0}},
#   {'completed_at': '2023-11-19T05:50:19.035+08:00',
#    'scores': {'ineslopes98': 84, 'mike316': 100}},
#   {'completed_at': '2023-11-19T05:50:19.035+08:00',
#    'scores': {'ineslopes98': 73, 'mike316': 99}},
#   {'completed_at': '2023-11-19T05:50:19.035+08:00',
#    'scores': {'ineslopes98': 0, 'mike316': 0}},
#   {'completed_at': '2023-11-20T10:10:07.350+08:00',
#    'scores': {'mrtriggerhandz': 83, 'FractalChess2': 100}},
#   {'completed_at': '2023-11-20T10:10:07.350+08:00',
#    'scores': {'mrtriggerhandz': 97, 'FractalChess2': 122}},
#   {'completed_at': '2023-11-20T10:10:07.350+08:00',
#    'scores': {'mrtriggerhandz': 0, 'FractalChess2': 0}},
#   {'completed_at': '2023-11-19T22:02:13.821+08:00',
#    'scores': {'MichaelTheGrackle': 97, 'mike316': 83}},
#   {'completed_at': '2023-11-19T22:02:13.821+08:00',
#    'scores': {'MichaelTheGrackle': 78, 'mike316': 93}},
#   {'completed_at': '2023-11-19T22:02:13.821+08:00',
#    'scores': {'MichaelTheGrackle': 88, 'mike316': 93}},
#   {'completed_at': '2023-11-13T11:54:44.369+08:00',
#    'scores': {'DrGrainslove': 73, 'bigben1248': 74}},
#   {'completed_at': '2023-11-13T11:54:44.369+08:00',
#    'scores': {'DrGrainslove': 107, 'bigben1248': 89}},
#   {'completed_at': '2023-11-13T11:54:44.369+08:00',
#    'scores': {'DrGrainslove': 98, 'bigben1248': 96}},
#   {'completed_at': '2023-11-13T02:43:00.440+08:00',
#    'scores': {'ramtek': 77, 'Goldfinchy (ign Goldfinchy2)': 95}},
#   {'completed_at': '2023-11-13T02:43:00.440+08:00',
#    'scores': {'ramtek': 96, 'Goldfinchy (ign Goldfinchy2)': 104}},
#   {'completed_at': '2023-11-13T02:43:00.440+08:00',
#    'scores': {'ramtek': 0, 'Goldfinchy (ign Goldfinchy2)': 0}},
#   {'completed_at': '2023-11-20T10:15:36.050+08:00',
#    'scores': {'StyloPlume': 93, 'iwinatlife42': 101}},
#   {'completed_at': '2023-11-20T10:15:36.050+08:00',
#    'scores': {'StyloPlume': 1, 'iwinatlife42': 0}},
#   {'completed_at': '2023-11-20T10:15:36.050+08:00',
#    'scores': {'StyloPlume': 1, 'iwinatlife42': 0}},
#   {'completed_at': '2023-11-19T04:48:27.406+08:00',
#    'scores': {'Salmonskinroll12': 97, 'Lowfat': 89}},
#   {'completed_at': '2023-11-19T04:48:27.406+08:00',
#    'scores': {'Salmonskinroll12': 129, 'Lowfat': 115}},
#   {'completed_at': '2023-11-19T04:48:27.406+08:00',
#    'scores': {'Salmonskinroll12': 0, 'Lowfat': 0}},
#   {'completed_at': '2023-11-14T07:55:16.648+08:00',
#    'scores': {'DrGrainslove': 121, 'Goldfinchy (ign Goldfinchy2)': 97}},
#   {'completed_at': '2023-11-14T07:55:16.648+08:00',
#    'scores': {'DrGrainslove': 103, 'Goldfinchy (ign Goldfinchy2)': 77}},
#   {'completed_at': '2023-11-14T07:55:16.648+08:00',
#    'scores': {'DrGrainslove': 0, 'Goldfinchy (ign Goldfinchy2)': 0}},
#   {'completed_at': '2023-11-23T02:34:27.791+08:00',
#    'scores': {'StyloPlume': 87, 'Salmonskinroll12': 102}},
#   {'completed_at': '2023-11-23T02:34:27.791+08:00',
#    'scores': {'StyloPlume': 83, 'Salmonskinroll12': 98}},
#   {'completed_at': '2023-11-23T02:34:27.791+08:00',
#    'scores': {'StyloPlume': 0, 'Salmonskinroll12': 0}},
#   {'completed_at': '2023-11-15T09:37:46.588+08:00',
#    'scores': {'Theflash04': 109, 'Beammeup (elecTrick)': 124}},
#   {'completed_at': '2023-11-15T09:37:46.588+08:00',
#    'scores': {'Theflash04': 101, 'Beammeup (elecTrick)': 132}},
#   {'completed_at': '2023-11-15T09:37:46.588+08:00',
#    'scores': {'Theflash04': 0, 'Beammeup (elecTrick)': 0}},
#   {'completed_at': '2023-11-17T07:09:57.602+08:00',
#    'scores': {'ravenousanna': 96, 'ZoopZoop': 98}},
#   {'completed_at': '2023-11-17T07:09:57.602+08:00',
#    'scores': {'ravenousanna': 84, 'ZoopZoop': 108}},
#   {'completed_at': '2023-11-17T07:09:57.602+08:00',
#    'scores': {'ravenousanna': 0, 'ZoopZoop': 0}},
#   {'completed_at': '2023-11-13T11:56:56.654+08:00',
#    'scores': {'Cuppa': 70, 'Rube23': 86}},
#   {'completed_at': '2023-11-13T11:56:56.654+08:00',
#    'scores': {'Cuppa': 82, 'Rube23': 77}},
#   {'completed_at': '2023-11-13T11:56:56.654+08:00',
#    'scores': {'Cuppa': 72, 'Rube23': 82}},
#   {'completed_at': '2023-11-15T11:35:29.087+08:00',
#    'scores': {'Groovenstein': 104, 'Crowvid99': 92}},
#   {'completed_at': '2023-11-15T11:35:29.087+08:00',
#    'scores': {'Groovenstein': 106, 'Crowvid99': 98}},
#   {'completed_at': '2023-11-15T11:35:29.087+08:00',
#    'scores': {'Groovenstein': 0, 'Crowvid99': 0}},
#   {'completed_at': '2023-11-18T12:13:59.918+08:00',
#    'scores': {'Beammeup (elecTrick)': 89, 'ZoopZoop': 96}},
#   {'completed_at': '2023-11-18T12:13:59.918+08:00',
#    'scores': {'Beammeup (elecTrick)': 85, 'ZoopZoop': 104}},
#   {'completed_at': '2023-11-18T12:13:59.918+08:00',
#    'scores': {'Beammeup (elecTrick)': 0, 'ZoopZoop': 0}},
#   {'completed_at': '2023-11-16T18:58:29.471+08:00',
#    'scores': {'Rube23': 99, 'Groovenstein': 115}},
#   {'completed_at': '2023-11-16T18:58:29.471+08:00',
#    'scores': {'Rube23': 92, 'Groovenstein': 85}},
#   {'completed_at': '2023-11-16T18:58:29.471+08:00',
#    'scores': {'Rube23': 93, 'Groovenstein': 106}},
#   {'completed_at': '2023-11-20T10:06:13.133+08:00',
#    'scores': {'ZoopZoop': 92, 'Groovenstein': 85}},
#   {'completed_at': '2023-11-20T10:06:13.133+08:00',
#    'scores': {'ZoopZoop': 92, 'Groovenstein': 88}},
#   {'completed_at': '2023-11-20T10:06:13.133+08:00',
#    'scores': {'ZoopZoop': 0, 'Groovenstein': 0}},
#   {'completed_at': '2023-11-19T04:54:11.978+08:00',
#    'scores': {'Copewithit': 95, 'otsukuuyan': 89}},
#   {'completed_at': '2023-11-19T04:54:11.978+08:00',
#    'scores': {'Copewithit': 88, 'otsukuuyan': 106}},
#   {'completed_at': '2023-11-19T04:54:11.978+08:00',
#    'scores': {'Copewithit': 76, 'otsukuuyan': 110}},
#   {'completed_at': '2023-11-16T18:56:04.854+08:00',
#    'scores': {'MonkeyWren': 85, 'Stormchaser': 89}},
#   {'completed_at': '2023-11-16T18:56:04.854+08:00',
#    'scores': {'MonkeyWren': 108, 'Stormchaser': 85}},
#   {'completed_at': '2023-11-16T18:56:04.854+08:00',
#    'scores': {'MonkeyWren': 101, 'Stormchaser': 80}},
#   {'completed_at': '2023-11-19T11:43:09.518+08:00',
#    'scores': {'herc': 115, 'Kopdog': 124}},
#   {'completed_at': '2023-11-19T11:43:09.518+08:00',
#    'scores': {'herc': 112, 'Kopdog': 108}},
#   {'completed_at': '2023-11-19T11:43:09.518+08:00',
#    'scores': {'herc': 84, 'Kopdog': 103}},
#   {'completed_at': '2023-11-17T07:04:47.342+08:00',
#    'scores': {'dilfina': 115, 'Daniel Naumovas (Daniel)': 91}},
#   {'completed_at': '2023-11-17T07:04:47.342+08:00',
#    'scores': {'dilfina': 105, 'Daniel Naumovas (Daniel)': 99}},
#   {'completed_at': '2023-11-17T07:04:47.342+08:00',
#    'scores': {'dilfina': 0, 'Daniel Naumovas (Daniel)': 0}},
#   {'completed_at': '2023-11-22T04:32:46.441+08:00',
#    'scores': {'Kopdog': 82, 'dilfina': 95}},
#   {'completed_at': '2023-11-22T04:32:46.441+08:00',
#    'scores': {'Kopdog': 105, 'dilfina': 82}},
#   {'completed_at': '2023-11-22T04:32:46.441+08:00',
#    'scores': {'Kopdog': 86, 'dilfina': 91}},
#   {'completed_at': '2023-11-19T21:57:19.857+08:00',
#    'scores': {'thebestdaysofmyflerm': 82, 'ethmah': 106}},
#   {'completed_at': '2023-11-19T21:57:19.857+08:00',
#    'scores': {'thebestdaysofmyflerm': 100, 'ethmah': 102}},
#   {'completed_at': '2023-11-19T21:57:19.857+08:00',
#    'scores': {'thebestdaysofmyflerm': 0, 'ethmah': 0}},
#   {'completed_at': '2023-11-19T22:01:35.290+08:00',
#    'scores': {'queenfisher1': 80, 'Vrwizkid': 69}},
#   {'completed_at': '2023-11-19T22:01:35.290+08:00',
#    'scores': {'queenfisher1': 99, 'Vrwizkid': 88}},
#   {'completed_at': '2023-11-19T22:01:35.290+08:00',
#    'scores': {'queenfisher1': 0, 'Vrwizkid': 0}},
#   {'completed_at': '2023-11-13T08:35:49.260+08:00',
#    'scores': {'MTRooster': 87, 'WhatDatFrogmoufDo (GMT -5)': 76}},
#   {'completed_at': '2023-11-13T08:35:49.260+08:00',
#    'scores': {'MTRooster': 95, 'WhatDatFrogmoufDo (GMT -5)': 88}},
#   {'completed_at': '2023-11-13T08:35:49.260+08:00',
#    'scores': {'MTRooster': 0, 'WhatDatFrogmoufDo (GMT -5)': 0}},
#   {'completed_at': '2023-11-18T04:36:42.088+08:00',
#    'scores': {'alexandrawuhu': 84, 'ZobiWanKenobi': 101}},
#   {'completed_at': '2023-11-18T04:36:42.088+08:00',
#    'scores': {'alexandrawuhu': 87, 'ZobiWanKenobi': 85}},
#   {'completed_at': '2023-11-18T04:36:42.088+08:00',
#    'scores': {'alexandrawuhu': 81, 'ZobiWanKenobi': 101}},
#   {'completed_at': '2023-11-22T20:08:46.305+08:00',
#    'scores': {'ethmah': 90, 'queenfisher1': 79}},
#   {'completed_at': '2023-11-22T20:08:46.305+08:00',
#    'scores': {'ethmah': 77, 'queenfisher1': 103}},
#   {'completed_at': '2023-11-22T20:08:46.305+08:00',
#    'scores': {'ethmah': 67, 'queenfisher1': 95}},
#   {'completed_at': '2023-11-19T21:59:05.180+08:00',
#    'scores': {'MTRooster': 82, 'ZobiWanKenobi': 80}},
#   {'completed_at': '2023-11-19T21:59:05.180+08:00',
#    'scores': {'MTRooster': 80, 'ZobiWanKenobi': 96}},
#   {'completed_at': '2023-11-19T21:59:05.180+08:00',
#    'scores': {'MTRooster': 87, 'ZobiWanKenobi': 103}},
#   {'completed_at': '2023-11-15T09:25:57.679+08:00',
#    'scores': {'Ronster7': 94, 'Kestrelly': 69}},
#   {'completed_at': '2023-11-15T09:25:57.679+08:00',
#    'scores': {'Ronster7': 105, 'Kestrelly': 92}},
#   {'completed_at': '2023-11-15T09:25:57.679+08:00',
#    'scores': {'Ronster7': 0, 'Kestrelly': 0}},
#   {'completed_at': '2023-11-13T08:36:03.005+08:00',
#    'scores': {'clloud8': 82, 'ElSapoGuapo': 77}},
#   {'completed_at': '2023-11-13T08:36:03.005+08:00',
#    'scores': {'clloud8': 94, 'ElSapoGuapo': 98}},
#   {'completed_at': '2023-11-13T08:36:03.005+08:00',
#    'scores': {'clloud8': 97, 'ElSapoGuapo': 87}},
#   {'completed_at': '2023-11-14T06:36:11.411+08:00',
#    'scores': {'King Pleb': 88, 'ooievaar': 89}},
#   {'completed_at': '2023-11-14T06:36:11.411+08:00',
#    'scores': {'King Pleb': 72, 'ooievaar': 87}},
#   {'completed_at': '2023-11-14T06:36:11.411+08:00',
#    'scores': {'King Pleb': 0, 'ooievaar': 0}},
#   {'completed_at': '2023-11-17T07:06:42.940+08:00',
#    'scores': {'BlindSquirrel (fnjphone)': 98, 'Ronster7': 113}},
#   {'completed_at': '2023-11-17T07:06:42.940+08:00',
#    'scores': {'BlindSquirrel (fnjphone)': 102, 'Ronster7': 119}},
#   {'completed_at': '2023-11-17T07:06:42.940+08:00',
#    'scores': {'BlindSquirrel (fnjphone)': 0, 'Ronster7': 0}},
#   {'completed_at': '2023-11-15T09:32:20.910+08:00',
#    'scores': {'clloud8': 72, 'ooievaar': 77}},
#   {'completed_at': '2023-11-15T09:32:20.910+08:00',
#    'scores': {'clloud8': 87, 'ooievaar': 91}},
#   {'completed_at': '2023-11-15T09:32:20.910+08:00',
#    'scores': {'clloud8': 0, 'ooievaar': 0}},
#   {'completed_at': '2023-11-23T02:33:40.504+08:00',
#    'scores': {'Ronster7': 92, 'ooievaar': 110}},
#   {'completed_at': '2023-11-23T02:33:40.504+08:00',
#    'scores': {'Ronster7': 103, 'ooievaar': 83}},
#   {'completed_at': '2023-11-23T02:33:40.504+08:00',
#    'scores': {'Ronster7': 98, 'ooievaar': 100}}]}

# %% [markdown]
# # Remove tournaments that are not 2-player Wingspan

# %%
normalized_tourneys = [t for t in normalized_tourneys if 'Joint Jabiru Joust' not in t['name']
               and 'Tournament Discord Server Image Bird' not in t['name']
              and 'Toco Toucan Triple Team Tournament' not in t['name']
             and 'Birds of a Feather' not in t['name']
            and 'Diamond Firetail Foursomes' not in t['name']
            and len(t['games'])]

# %%
for t in normalized_tourneys:
    t['games'] = [g for g in t['games'] if min(g['scores'].values()) > 0]

# %% [markdown]
# # Save to JSON

# %%
with open('wingspan_tournaments.json', 'w') as f:
    json.dump(normalized_tourneys, f, indent=2)

# %% [markdown]
# # Fix more names

# %%
with open('wingspan_tournaments.json', 'r') as f:
    normalized_tourneys = json.load(f)

# %%
extra_substitutions = {
    'FlanSwitch': 'Flan',
    'Birdwatchermobile': 'Birdwatcher123',
    'Mliguori16 (Birdwatcher123)': 'Birdwatcher123',
    'Cap': 'Capitalist111#3362 (Cap)',
    'HAyAsIiI (slowPigeon)': 'slowPigeon',
    'Jjlig2mobile2': 'Jjlig2',
    'No~M l IGN: danaran': 'No~M (danaran)',
    'Rafa oakie (oakie)': 'Rafa (oakie)',
    'Shiny (ShinyEmmy)': 'ShinyEmmy',
    'Typhus / rnicolas (Typhus)': 'Typhus',
    'Wingsplain': 'Wingsplain Gaming (ShadowFox)',
    "oakie6439\t(oakie)": 'oakie',
    "nsegal14 (SegalLikeTheBird)": "SegalLikeTheBird",
    "e8v2000 (ScaredofBirds)": "ScaredofBirds",
    "eefdeaardappel (ooievaar) - The Netherlands": "ooievaar",
    "ooievaar🇳🇱 (ign moustache)": "ooievaar",
    "Johnlim": "Jlim (Johnlim)",
    "HaveAGoodOne": "Kip (ign: HaveAGoodOne)",
    "cedarwax": "maggie (cedarwax)",
    "mellymelyay": "mcdo0530 (mellymelyay)",
    "nardybux (MonkeyWren)": "MonkeyWren",
    "ScottCS (MortalWings)": "MortalWings",
    "Trung (Stalledbird)": "Stalledbird"
}

for t in normalized_tourneys:
    for g in t['games']:
        to_substitute = [user for user in g['scores'].keys() if user in extra_substitutions]
        for user in to_substitute:
            score = g['scores'][user]
            del g['scores'][user]
            g['scores'][extra_substitutions[user]] = score
                
with open('wingspan_tournaments.json', 'w') as f:
    json.dump(normalized_tourneys, f, indent=2)

# %%
normalized_tourneys[1]
# Out:
# {'id': 13698471,
#  'name': 'Wingspan World Cup 2023',
#  'url': 'https://challonge.com/mgdi6ytz',
#  'date': None,
#  'games': [{'completed_at': '2023-11-11T07:25:49.670+07:00',
#    'scores': {'Dozi': 95, 'Av0ry': 109}},
#   {'completed_at': '2023-11-10T03:18:55.254+07:00',
#    'scores': {'MTRooster': 112, 'SPAKEME': 106}},
#   {'completed_at': '2023-11-15T09:19:00.372+07:00',
#    'scores': {'corndog (corndove)': 89, 'Kestrelly': 94}},
#   {'completed_at': '2023-11-10T17:06:28.596+07:00',
#    'scores': {'tirk44': 78, 'jbc999': 101}},
#   {'completed_at': '2023-11-19T12:28:04.794+07:00',
#    'scores': {'DurdleGerg (he/him)': 91, 'ZoopZoop': 117}},
#   {'completed_at': '2023-11-15T09:42:12.078+07:00',
#    'scores': {'ZoopZoop': 85, 'MTRooster': 109}},
#   {'completed_at': '2023-11-12T01:34:06.376+07:00',
#    'scores': {'jbc999': 95, 'Dozi': 92}},
#   {'completed_at': '2023-11-13T11:01:09.397+07:00',
#    'scores': {'Kestrelly': 81, 'tirk44': 86}},
#   {'completed_at': '2023-11-18T23:41:35.571+07:00',
#    'scores': {'SPAKEME': 102, 'corndog (corndove)': 111}},
#   {'completed_at': '2023-11-13T01:49:58.407+07:00',
#    'scores': {'Av0ry': 102, 'DurdleGerg (he/him)': 81}},
#   {'completed_at': '2023-11-09T22:24:40.484+07:00',
#    'scores': {'Dozi': 89, 'Kestrelly': 68}},
#   {'completed_at': '2023-11-18T23:41:35.968+07:00',
#    'scores': {'tirk44': 87, 'SPAKEME': 99}},
#   {'completed_at': '2023-11-12T01:29:38.678+07:00',
#    'scores': {'DurdleGerg (he/him)': 100, 'MTRooster': 89}},
#   {'completed_at': '2023-11-16T16:38:42.302+07:00',
#    'scores': {'Av0ry': 104, 'jbc999': 105}},
#   {'completed_at': '2023-11-12T01:27:04.675+07:00',
#    'scores': {'SPAKEME': 109, 'Dozi': 108}},
#   {'completed_at': '2023-11-12T20:52:07.754+07:00',
#    'scores': {'Kestrelly': 98, 'Av0ry': 110}},
#   {'completed_at': '2023-11-12T01:32:39.486+07:00',
#    'scores': {'jbc999': 89, 'DurdleGerg (he/him)': 90}},
#   {'completed_at': '2023-11-15T09:37:08.413+07:00',
#    'scores': {'ZoopZoop': 90, 'tirk44': 87}},
#   {'completed_at': '2023-11-16T16:39:19.846+07:00',
#    'scores': {'MTRooster': 80, 'corndog (corndove)': 88}},
#   {'completed_at': '2023-11-09T18:15:05.322+07:00',
#    'scores': {'tirk44': 118, 'MTRooster': 99}},
#   {'completed_at': '2023-11-18T23:40:42.556+07:00',
#    'scores': {'DurdleGerg (he/him)': 87, 'corndog (corndove)': 107}},
#   {'completed_at': '2023-11-10T03:26:41.992+07:00',
#    'scores': {'Dozi': 107, 'ZoopZoop': 94}},
#   {'completed_at': '2023-11-16T16:37:34.954+07:00',
#    'scores': {'Av0ry': 98, 'SPAKEME': 89}},
#   {'completed_at': '2023-11-09T18:10:32.511+07:00',
#    'scores': {'jbc999': 81, 'Kestrelly': 84}},
#   {'completed_at': '2023-11-14T03:24:49.227+07:00',
#    'scores': {'Kestrelly': 98, 'DurdleGerg (he/him)': 101}},
#   {'completed_at': '2023-11-18T11:30:07.251+07:00',
#    'scores': {'SPAKEME': 93, 'jbc999': 110}},
#   {'completed_at': '2023-11-21T17:12:51.834+07:00',
#    'scores': {'ZoopZoop': 87, 'Av0ry': 100}},
#   {'completed_at': '2023-11-09T22:23:02.322+07:00',
#    'scores': {'MTRooster': 84, 'Dozi': 110}},
#   {'completed_at': '2023-11-12T20:47:37.284+07:00',
#    'scores': {'corndog (corndove)': 84, 'tirk44': 101}},
#   {'completed_at': '2023-11-14T07:17:56.574+07:00',
#    'scores': {'DurdleGerg (he/him)': 75, 'tirk44': 72}},
#   {'completed_at': '2023-11-12T20:49:14.181+07:00',
#    'scores': {'Av0ry': 97, 'MTRooster': 100}},
#   {'completed_at': '2023-11-21T17:14:09.810+07:00',
#    'scores': {'jbc999': 108, 'ZoopZoop': 110}},
#   {'completed_at': '2023-11-10T03:19:55.070+07:00',
#    'scores': {'Kestrelly': 90, 'SPAKEME': 92}},
#   {'completed_at': '2023-11-10T03:44:28.977+07:00',
#    'scores': {'ZoopZoop': 81, 'Kestrelly': 99}},
#   {'completed_at': '2023-11-14T03:28:00.306+07:00',
#    'scores': {'SPAKEME': 82, 'DurdleGerg (he/him)': 105}},
#   {'completed_at': '2023-11-12T01:32:54.098+07:00',
#    'scores': {'MTRooster': 99, 'jbc999': 113}},
#   {'completed_at': '2023-11-12T19:39:28.888+07:00',
#    'scores': {'corndog (corndove)': 75, 'Av0ry': 88}},
#   {'completed_at': '2023-11-19T22:24:01.500+07:00',
#    'scores': {'tirk44': 73, 'Dozi': 74}},
#   {'completed_at': '2023-11-21T17:15:00.324+07:00',
#    'scores': {'jbc999': 90, 'corndog (corndove)': 77}},
#   {'completed_at': '2023-11-12T19:41:11.686+07:00',
#    'scores': {'Av0ry': 72, 'tirk44': 83}},
#   {'completed_at': '2023-11-12T01:32:36.558+07:00',
#    'scores': {'DurdleGerg (he/him)': 87, 'Dozi': 91}},
#   {'completed_at': '2023-11-12T22:24:08.248+07:00',
#    'scores': {'Kestrelly': 97, 'MTRooster': 88}},
#   {'completed_at': '2023-11-14T03:28:10.711+07:00',
#    'scores': {'SPAKEME': 91, 'ZoopZoop': 90}},
#   {'completed_at': '2023-11-19T22:25:59.381+07:00',
#    'scores': {'blutzollfeuerball': 101, 'BalletMage': 83}},
#   {'completed_at': '2023-11-12T01:32:28.864+07:00',
#    'scores': {'Flan': 107, 'WBNuthatch93': 124}},
#   {'completed_at': '2023-11-12T20:44:25.793+07:00',
#    'scores': {'Bargoff': 109, 'ScaredofBirds': 99}},
#   {'completed_at': '2023-11-18T11:35:30.628+07:00',
#    'scores': {'devilled egg': 84, 'KarlHungus': 117}},
#   {'completed_at': '2023-11-15T09:41:21.869+07:00',
#    'scores': {'ScaredofBirds': 83, 'Jjlig2': 82}},
#   {'completed_at': '2023-11-12T20:50:15.021+07:00',
#    'scores': {'WBNuthatch93': 85, 'Bargoff': 94}},
#   {'completed_at': '2023-11-11T10:24:24.468+07:00',
#    'scores': {'BalletMage': 95, 'devilled egg': 86}},
#   {'completed_at': '2023-11-19T22:27:12.983+07:00',
#    'scores': {'blutzollfeuerball': 79, 'ScaredofBirds': 101}},
#   {'completed_at': '2023-11-22T16:58:27.998+07:00',
#    'scores': {'Bargoff': 112, 'KarlHungus': 109}},
#   {'completed_at': '2023-11-15T09:16:11.818+07:00',
#    'scores': {'WBNuthatch93': 95, 'Jjlig2': 86}},
#   {'completed_at': '2023-11-12T20:49:12.835+07:00',
#    'scores': {'devilled egg': 84, 'Flan': 102}},
#   {'completed_at': '2023-11-11T00:44:36.515+07:00',
#    'scores': {'BalletMage': 79, 'Kaienshin': 97}},
#   {'completed_at': '2023-11-16T16:35:40.393+07:00',
#    'scores': {'WBNuthatch93': 91, 'blutzollfeuerball': 80}},
#   {'completed_at': '2023-11-13T01:45:59.673+07:00',
#    'scores': {'ScaredofBirds': 116, 'BalletMage': 85}},
#   {'completed_at': '2023-11-15T10:16:38.648+07:00',
#    'scores': {'KarlHungus': 89, 'Jjlig2': 86}},
#   {'completed_at': '2023-11-12T01:34:46.073+07:00',
#    'scores': {'Flan': 100, 'Bargoff': 124}},
#   {'completed_at': '2023-11-18T11:34:06.979+07:00',
#    'scores': {'devilled egg': 102, 'Bargoff': 94}},
#   {'completed_at': '2023-11-16T21:41:02.221+07:00',
#    'scores': {'blutzollfeuerball': 96, 'KarlHungus': 82}},
#   {'completed_at': '2023-11-10T17:04:37.291+07:00',
#    'scores': {'BalletMage': 88, 'WBNuthatch93': 82}},
#   {'completed_at': '2023-11-11T02:22:55.725+07:00',
#    'scores': {'Kaienshin': 86, 'ScaredofBirds': 107}},
#   {'completed_at': '2023-11-11T07:27:56.259+07:00',
#    'scores': {'ScaredofBirds': 95, 'devilled egg': 83}},
#   {'completed_at': '2023-11-10T03:21:36.330+07:00',
#    'scores': {'WBNuthatch93': 98, 'Kaienshin': 97}},
#   {'completed_at': '2023-11-10T17:04:10.080+07:00',
#    'scores': {'KarlHungus': 98, 'BalletMage': 91}},
#   {'completed_at': '2023-11-18T11:32:02.813+07:00',
#    'scores': {'devilled egg': 88, 'Jjlig2': 100}},
#   {'completed_at': '2023-11-23T16:02:59.969+07:00',
#    'scores': {'blutzollfeuerball': 95, 'Bargoff': 105}},
#   {'completed_at': '2023-11-11T00:43:14.719+07:00',
#    'scores': {'BalletMage': 106, 'Flan': 107}},
#   {'completed_at': '2023-11-18T23:43:07.233+07:00',
#    'scores': {'Kaienshin': 113, 'KarlHungus': 109}},
#   {'completed_at': '2023-11-11T00:44:06.853+07:00',
#    'scores': {'ScaredofBirds': 113, 'WBNuthatch93': 114}},
#   {'completed_at': '2023-11-11T10:25:02.091+07:00',
#    'scores': {'KarlHungus': 91, 'ScaredofBirds': 97}},
#   {'completed_at': '2023-11-11T10:22:39.577+07:00',
#    'scores': {'WBNuthatch93': 92, 'devilled egg': 76}},
#   {'completed_at': '2023-11-09T22:28:16.614+07:00',
#    'scores': {'Flan': 94, 'Kaienshin': 89}},
#   {'completed_at': '2023-11-10T17:04:23.814+07:00',
#    'scores': {'Bargoff': 91, 'BalletMage': 75}},
#   {'completed_at': '2023-11-20T01:43:07.420+07:00',
#    'scores': {'blutzollfeuerball': 119, 'Jjlig2': 128}},
#   {'completed_at': '2023-11-18T11:34:13.595+07:00',
#    'scores': {'Kaienshin': 85, 'Bargoff': 81}},
#   {'completed_at': '2023-11-14T03:23:47.583+07:00',
#    'scores': {'BalletMage': 84, 'Jjlig2': 91}},
#   {'completed_at': '2023-11-23T04:41:57.601+07:00',
#    'scores': {'devilled egg': 86, 'blutzollfeuerball': 92}},
#   {'completed_at': '2023-11-09T18:12:41.153+07:00',
#    'scores': {'WBNuthatch93': 92, 'KarlHungus': 78}},
#   {'completed_at': '2023-11-11T17:50:19.809+07:00',
#    'scores': {'kylelovesducks': 126, 'Sim17': 92}},
#   {'completed_at': '2023-11-13T00:07:03.107+07:00',
#    'scores': {'BeansOnToast': 92, 'knocknwood': 89}},
#   {'completed_at': '2023-11-16T22:55:44.549+07:00',
#    'scores': {'thebangzats': 95, 'Stalledbird': 106}},
#   {'completed_at': '2023-11-16T16:28:13.173+07:00',
#    'scores': {'WeirdOwl': 91, 'jeastthebeast': 109}},
#   {'completed_at': '2023-11-11T05:19:17.213+07:00',
#    'scores': {'de Visme': 95, 'MasterWing': 85}},
#   {'completed_at': '2023-11-11T00:41:25.663+07:00',
#    'scores': {'MasterWing': 107, 'BeansOnToast': 109}},
#   {'completed_at': '2023-11-15T09:32:43.571+07:00',
#    'scores': {'jeastthebeast': 99, 'kylelovesducks': 64}},
#   {'completed_at': '2023-11-14T03:22:35.971+07:00',
#    'scores': {'Stalledbird': 83, 'WeirdOwl': 83}},
#   {'completed_at': '2023-11-13T07:51:56.751+07:00',
#    'scores': {'knocknwood': 95, 'thebangzats': 100}},
#   {'completed_at': '2023-11-15T09:25:02.897+07:00',
#    'scores': {'Sim17': 98, 'de Visme': 83}},
#   {'completed_at': '2023-11-15T09:37:08.623+07:00',
#    'scores': {'kylelovesducks': 101, 'Stalledbird': 88}},
#   {'completed_at': '2023-11-09T22:27:00.630+07:00',
#    'scores': {'thebangzats': 101, 'MasterWing': 112}},
#   {'completed_at': '2023-11-16T16:29:22.066+07:00',
#    'scores': {'WeirdOwl': 91, 'knocknwood': 101}},
#   {'completed_at': '2023-11-15T20:42:14.969+07:00',
#    'scores': {'de Visme': 145, 'BeansOnToast': 103}},
#   {'completed_at': '2023-11-12T01:28:42.693+07:00',
#    'scores': {'Sim17': 97, 'jeastthebeast': 76}},
#   {'completed_at': '2023-11-17T10:41:29.366+07:00',
#    'scores': {'knocknwood': 88, 'kylelovesducks': 100}},
#   {'completed_at': '2023-11-11T00:41:11.754+07:00',
#    'scores': {'Stalledbird': 85, 'Sim17': 104}},
#   {'completed_at': '2023-11-16T16:29:09.071+07:00',
#    'scores': {'jeastthebeast': 99, 'de Visme': 123}},
#   {'completed_at': '2023-11-12T01:31:13.609+07:00',
#    'scores': {'MasterWing': 102, 'WeirdOwl': 84}},
#   {'completed_at': '2023-11-16T20:24:09.617+07:00',
#    'scores': {'BeansOnToast': 104, 'thebangzats': 96}},
#   {'completed_at': '2023-11-08T23:22:03.126+07:00',
#    'scores': {'WeirdOwl': 103, 'BeansOnToast': 113}},
#   {'completed_at': '2023-11-09T22:26:28.011+07:00',
#    'scores': {'de Visme': 90, 'thebangzats': 76}},
#   {'completed_at': '2023-11-10T03:18:29.825+07:00',
#    'scores': {'kylelovesducks': 113, 'MasterWing': 115}},
#   {'completed_at': '2023-11-19T12:25:57.833+07:00',
#    'scores': {'Sim17': 108, 'knocknwood': 93}},
#   {'completed_at': '2023-11-16T16:36:04.573+07:00',
#    'scores': {'jeastthebeast': 113, 'Stalledbird': 94}},
#   {'completed_at': '2023-11-14T03:27:20.953+07:00',
#    'scores': {'Stalledbird': 75, 'de Visme': 84}},
#   {'completed_at': '2023-11-17T07:27:08.264+07:00',
#    'scores': {'knocknwood': 84, 'jeastthebeast': 80}},
#   {'completed_at': '2023-11-11T00:42:43.846+07:00',
#    'scores': {'MasterWing': 79, 'Sim17': 83}},
#   {'completed_at': '2023-11-14T03:27:40.758+07:00',
#    'scores': {'BeansOnToast': 84, 'kylelovesducks': 93}},
#   {'completed_at': '2023-11-09T22:27:48.935+07:00',
#    'scores': {'thebangzats': 106, 'WeirdOwl': 83}},
#   {'completed_at': '2023-11-14T03:27:17.681+07:00',
#    'scores': {'de Visme': 107, 'WeirdOwl': 125}},
#   {'completed_at': '2023-11-15T09:29:10.801+07:00',
#    'scores': {'kylelovesducks': 85, 'thebangzats': 89}},
#   {'completed_at': '2023-11-16T18:04:21.455+07:00',
#    'scores': {'Sim17': 94, 'BeansOnToast': 83}},
#   {'completed_at': '2023-11-15T09:34:40.633+07:00',
#    'scores': {'jeastthebeast': 78, 'MasterWing': 107}},
#   {'completed_at': '2023-11-17T07:26:53.395+07:00',
#    'scores': {'Stalledbird': 97, 'knocknwood': 110}},
#   {'completed_at': '2023-11-09T18:09:31.859+07:00',
#    'scores': {'MasterWing': 84, 'Stalledbird': 79}},
#   {'completed_at': '2023-11-12T20:45:37.203+07:00',
#    'scores': {'knocknwood': 98, 'de Visme': 98}},
#   {'completed_at': '2023-11-15T09:31:18.338+07:00',
#    'scores': {'BeansOnToast': 100, 'jeastthebeast': 87}},
#   {'completed_at': '2023-11-13T15:36:17.906+07:00',
#    'scores': {'thebangzats': 84, 'Sim17': 81}},
#   {'completed_at': '2023-11-10T03:20:03.752+07:00',
#    'scores': {'WeirdOwl': 85, 'kylelovesducks': 99}},
#   {'completed_at': '2023-11-15T09:35:31.724+07:00',
#    'scores': {'jeastthebeast': 93, 'thebangzats': 101}},
#   {'completed_at': '2023-11-12T01:29:36.716+07:00',
#    'scores': {'Sim17': 94, 'WeirdOwl': 113}},
#   {'completed_at': '2023-11-11T07:24:38.980+07:00',
#    'scores': {'de Visme': 128, 'kylelovesducks': 109}},
#   {'completed_at': '2023-11-12T19:37:12.821+07:00',
#    'scores': {'knocknwood': 112, 'MasterWing': 106}},
#   {'completed_at': '2023-11-16T16:28:45.810+07:00',
#    'scores': {'captain_awesome.': 85, 'BlackSpice28': 65}},
#   {'completed_at': '2023-11-19T22:23:14.822+07:00',
#    'scores': {'Orcinus': 101, 'Arceusisgood': 100}},
#   {'completed_at': '2023-11-19T12:27:27.487+07:00',
#    'scores': {'Lowfat711': 94, 'StyloPlume': 92}},
#   {'completed_at': '2023-11-14T07:13:08.101+07:00',
#    'scores': {'GracklinOatBrant': 92, 'FractalChess2': 100}},
#   {'completed_at': '2023-11-13T07:49:18.762+07:00',
#    'scores': {'vpol55': 100, 'Orcinus': 106}},
#   {'completed_at': '2023-11-15T09:39:24.545+07:00',
#    'scores': {'StyloPlume': 83, 'GracklinOatBrant': 110}},
#   {'completed_at': '2023-11-19T12:28:54.843+07:00',
#    'scores': {'Arceusisgood': 95, 'Lowfat711': 112}},
#   {'completed_at': '2023-11-14T07:13:33.273+07:00',
#    'scores': {'BlackSpice28': 87, 'Swagmulis (SAMULIS)': 79}},
#   {'completed_at': '2023-11-22T04:10:50.243+07:00',
#    'scores': {'captain_awesome.': 96, 'StyloPlume': 102}},
#   {'completed_at': '2023-11-20T09:23:39.432+07:00',
#    'scores': {'Lowfat711': 118, 'vpol55': 94}},
#   {'completed_at': '2023-11-09T22:25:39.328+07:00',
#    'scores': {'GracklinOatBrant': 76, 'Arceusisgood': 85}},
#   {'completed_at': '2023-11-23T04:41:40.987+07:00',
#    'scores': {'Swagmulis (SAMULIS)': 80, 'Orcinus': 100}},
#   {'completed_at': '2023-11-09T18:11:08.957+07:00',
#    'scores': {'BlackSpice28': 108, 'FractalChess2': 99}},
#   {'completed_at': '2023-11-18T11:29:34.044+07:00',
#    'scores': {'Arceusisgood': 113, 'captain_awesome.': 115}},
#   {'completed_at': '2023-11-14T03:28:37.563+07:00',
#    'scores': {'StyloPlume': 97, 'BlackSpice28': 106}},
#   {'completed_at': '2023-11-24T03:33:10.736+07:00',
#    'scores': {'FractalChess2': 116, 'Swagmulis (SAMULIS)': 101}},
#   {'completed_at': '2023-11-20T09:22:32.095+07:00',
#    'scores': {'vpol55': 104, 'GracklinOatBrant': 113}},
#   {'completed_at': '2023-11-13T07:47:47.406+07:00',
#    'scores': {'GracklinOatBrant': 88, 'Orcinus': 79}},
#   {'completed_at': '2023-11-09T22:28:11.214+07:00',
#    'scores': {'BlackSpice28': 91, 'Arceusisgood': 98}},
#   {'completed_at': '2023-11-19T12:25:57.633+07:00',
#    'scores': {'FractalChess2': 110, 'StyloPlume': 109}},
#   {'completed_at': '2023-11-18T19:13:05.368+07:00',
#    'scores': {'Arceusisgood': 85, 'FractalChess2': 82}},
#   {'completed_at': '2023-11-15T09:38:11.681+07:00',
#    'scores': {'vpol55': 104, 'BlackSpice28': 89}},
#   {'completed_at': '2023-11-19T12:26:30.481+07:00',
#    'scores': {'Orcinus': 80, 'captain_awesome.': 95}},
#   {'completed_at': '2023-11-11T04:01:40.720+07:00',
#    'scores': {'Lowfat711': 90, 'GracklinOatBrant': 109}},
#   {'completed_at': '2023-11-21T06:10:20.739+07:00',
#    'scores': {'Swagmulis (SAMULIS)': 72, 'GracklinOatBrant': 100}},
#   {'completed_at': '2023-11-09T18:15:37.171+07:00',
#    'scores': {'captain_awesome.': 92, 'Lowfat711': 101}},
#   {'completed_at': '2023-11-12T20:39:54.354+07:00',
#    'scores': {'BlackSpice28': 77, 'Orcinus': 87}},
#   {'completed_at': '2023-11-20T01:41:58.331+07:00',
#    'scores': {'StyloPlume': 84, 'Arceusisgood': 107}},
#   {'completed_at': '2023-11-13T00:06:23.393+07:00',
#    'scores': {'vpol55': 93, 'StyloPlume': 95}},
#   {'completed_at': '2023-11-18T11:34:34.068+07:00',
#    'scores': {'Arceusisgood': 105, 'Swagmulis (SAMULIS)': 87}},
#   {'completed_at': '2023-11-17T07:28:09.584+07:00',
#    'scores': {'Orcinus': 86, 'FractalChess2': 98}},
#   {'completed_at': '2023-11-11T03:16:09.141+07:00',
#    'scores': {'Lowfat711': 76, 'BlackSpice28': 99}},
#   {'completed_at': '2023-11-14T07:19:12.470+07:00',
#    'scores': {'GracklinOatBrant': 98, 'captain_awesome.': 89}},
#   {'completed_at': '2023-11-19T12:27:58.819+07:00',
#    'scores': {'FractalChess2': 84, 'Lowfat711': 93}},
#   {'completed_at': '2023-11-11T00:40:28.235+07:00',
#    'scores': {'BlackSpice28': 103, 'GracklinOatBrant': 107}},
#   {'completed_at': '2023-11-15T09:40:42.517+07:00',
#    'scores': {'Swagmulis (SAMULIS)': 102, 'captain_awesome.': 99}},
#   {'completed_at': '2023-11-24T03:32:34.067+07:00',
#    'scores': {'StyloPlume': 97, 'Orcinus': 101}},
#   {'completed_at': '2023-11-09T18:15:19.468+07:00',
#    'scores': {'Groovenstein': 101, 'yordthesword (PuffPapa)': 95}},
#   {'completed_at': '2023-11-09T22:25:02.548+07:00',
#    'scores': {'Beammeup (elecTrick)': 81, 'mike316': 103}},
#   {'completed_at': '2023-11-10T03:25:48.675+07:00',
#    'scores': {'Lepurplemartin': 111, 'CamSails': 98}},
#   {'completed_at': '2023-11-12T01:34:47.737+07:00',
#    'scores': {'Terracotta (aLL1e)': 95, 'motherlove': 98}},
#   {'completed_at': '2023-11-13T19:31:37.958+07:00',
#    'scores': {'iwinatlife42': 83, 'Maskonur': 109}},
#   {'completed_at': '2023-11-09T18:12:25.129+07:00',
#    'scores': {'Maskonur': 105, 'Beammeup (elecTrick)': 86}},
#   {'completed_at': '2023-11-10T17:07:11.850+07:00',
#    'scores': {'motherlove': 90, 'Groovenstein': 115}},
#   {'completed_at': '2023-11-09T01:34:47.505+07:00',
#    'scores': {'CamSails': 107, 'Terracotta (aLL1e)': 97}},
#   {'completed_at': '2023-11-10T03:18:19.246+07:00',
#    'scores': {'mike316': 99, 'Lepurplemartin': 87}},
#   {'completed_at': '2023-11-11T10:27:07.864+07:00',
#    'scores': {'yordthesword (PuffPapa)': 104, 'iwinatlife42': 86}},
#   {'completed_at': '2023-11-09T02:51:13.744+07:00',
#    'scores': {'Groovenstein': 88, 'CamSails': 82}},
#   {'completed_at': '2023-11-10T17:00:30.301+07:00',
#    'scores': {'Lepurplemartin': 102, 'Maskonur': 108}},
#   {'completed_at': '2023-11-15T09:31:32.895+07:00',
#    'scores': {'Terracotta (aLL1e)': 93, 'mike316': 98}},
#   {'completed_at': '2023-11-17T10:41:47.866+07:00',
#    'scores': {'iwinatlife42': 72, 'Beammeup (elecTrick)': 66}},
#   {'completed_at': '2023-11-12T01:34:39.056+07:00',
#    'scores': {'yordthesword (PuffPapa)': 103, 'motherlove': 79}},
#   {'completed_at': '2023-11-11T10:27:43.357+07:00',
#    'scores': {'mike316': 115, 'Groovenstein': 102}},
#   {'completed_at': '2023-11-09T00:33:34.878+07:00',
#    'scores': {'CamSails': 81, 'yordthesword (PuffPapa)': 100}},
#   {'completed_at': '2023-11-21T06:07:18.305+07:00',
#    'scores': {'motherlove': 88, 'iwinatlife42': 64}},
#   {'completed_at': '2023-11-10T03:26:08.235+07:00',
#    'scores': {'Maskonur': 88, 'Terracotta (aLL1e)': 87}},
#   {'completed_at': '2023-11-10T17:02:27.219+07:00',
#    'scores': {'Beammeup (elecTrick)': 117, 'Lepurplemartin': 121}},
#   {'completed_at': '2023-11-19T22:25:51.972+07:00',
#    'scores': {'Terracotta (aLL1e)': 106, 'Beammeup (elecTrick)': 84}},
#   {'completed_at': '2023-11-15T09:24:25.435+07:00',
#    'scores': {'iwinatlife42': 99, 'Lepurplemartin': 88}},
#   {'completed_at': '2023-11-14T03:25:29.786+07:00',
#    'scores': {'Groovenstein': 85, 'Maskonur': 78}},
#   {'completed_at': '2023-11-11T10:26:48.648+07:00',
#    'scores': {'yordthesword (PuffPapa)': 95, 'mike316': 109}},
#   {'completed_at': '2023-11-14T03:24:16.495+07:00',
#    'scores': {'motherlove': 116, 'CamSails': 106}},
#   {'completed_at': '2023-11-15T09:20:11.870+07:00',
#    'scores': {'CamSails': 88, 'iwinatlife42': 97}},
#   {'completed_at': '2023-11-14T03:22:16.985+07:00',
#    'scores': {'mike316': 120, 'motherlove': 124}},
#   {'completed_at': '2023-11-14T07:15:45.684+07:00',
#    'scores': {'Maskonur': 101, 'yordthesword (PuffPapa)': 110}},
#   {'completed_at': '2023-11-10T17:06:30.785+07:00',
#    'scores': {'Beammeup (elecTrick)': 92, 'Groovenstein': 95}},
#   {'completed_at': '2023-11-12T20:48:54.189+07:00',
#    'scores': {'Lepurplemartin': 92, 'Terracotta (aLL1e)': 107}},
#   {'completed_at': '2023-11-21T06:08:33.568+07:00',
#    'scores': {'iwinatlife42': 82, 'Terracotta (aLL1e)': 90}},
#   {'completed_at': '2023-11-10T03:20:42.065+07:00',
#    'scores': {'Groovenstein': 95, 'Lepurplemartin': 92}},
#   {'completed_at': '2023-11-09T18:12:43.064+07:00',
#    'scores': {'yordthesword (PuffPapa)': 117, 'Beammeup (elecTrick)': 111}},
#   {'completed_at': '2023-11-14T03:21:45.197+07:00',
#    'scores': {'motherlove': 121, 'Maskonur': 125}},
#   {'completed_at': '2023-11-11T00:41:38.416+07:00',
#    'scores': {'CamSails': 79, 'mike316': 103}},
#   {'completed_at': '2023-11-08T23:22:36.812+07:00',
#    'scores': {'Maskonur': 97, 'CamSails': 123}},
#   {'completed_at': '2023-11-13T18:46:42.024+07:00',
#    'scores': {'mike316': 110, 'iwinatlife42': 111}},
#   {'completed_at': '2023-11-19T22:23:33.841+07:00',
#    'scores': {'Beammeup (elecTrick)': 100, 'motherlove': 93}},
#   {'completed_at': '2023-11-09T18:11:35.713+07:00',
#    'scores': {'Lepurplemartin': 93, 'yordthesword (PuffPapa)': 90}},
#   {'completed_at': '2023-11-14T03:26:56.645+07:00',
#    'scores': {'Terracotta (aLL1e)': 79, 'Groovenstein': 85}},
#   {'completed_at': '2023-11-15T09:28:48.762+07:00',
#    'scores': {'motherlove': 99, 'Lepurplemartin': 81}},
#   {'completed_at': '2023-11-11T02:24:13.604+07:00',
#    'scores': {'yordthesword (PuffPapa)': 94, 'Terracotta (aLL1e)': 97}},
#   {'completed_at': '2023-11-11T10:27:17.323+07:00',
#    'scores': {'iwinatlife42': 81, 'Groovenstein': 101}},
#   {'completed_at': '2023-11-12T20:50:54.174+07:00',
#    'scores': {'CamSails': 90, 'Beammeup (elecTrick)': 87}},
#   {'completed_at': '2023-11-11T00:38:13.964+07:00',
#    'scores': {'mike316': 105, 'Maskonur': 91}},
#   {'completed_at': '2023-11-15T09:30:16.686+07:00',
#    'scores': {'Theflash04': 89, 'Dollabill (USA)': 84}},
#   {'completed_at': '2023-11-15T09:41:25.523+07:00',
#    'scores': {'Kopdog': 113, 'Merghalodon (TheAlphaQuail)': 85}},
#   {'completed_at': '2023-11-09T18:09:19.815+07:00',
#    'scores': {'Abiath': 84, 'GeorgeV89': 79}},
#   {'completed_at': '2023-11-23T16:03:30.153+07:00',
#    'scores': {'HawkLake': 91, 'Picep': 98}},
#   {'completed_at': '2023-11-17T07:28:41.520+07:00',
#    'scores': {'gaussiancurve': 83, 'Waterman': 89}},
#   {'completed_at': '2023-11-14T03:22:53.007+07:00',
#    'scores': {'Waterman': 98, 'Kopdog': 93}},
#   {'completed_at': '2023-11-10T03:45:28.385+07:00',
#    'scores': {'Picep': 95, 'Theflash04': 118}},
#   {'completed_at': '2023-11-15T09:36:50.677+07:00',
#    'scores': {'GeorgeV89': 113, 'HawkLake': 90}},
#   {'completed_at': '2023-11-14T07:15:17.177+07:00',
#    'scores': {'Merghalodon (TheAlphaQuail)': 95, 'Abiath': 122}},
#   {'completed_at': '2023-11-16T16:37:15.506+07:00',
#    'scores': {'Dollabill (USA)': 100, 'gaussiancurve': 90}},
#   {'completed_at': '2023-11-09T01:33:31.471+07:00',
#    'scores': {'Theflash04': 101, 'GeorgeV89': 92}},
#   {'completed_at': '2023-11-21T06:07:14.587+07:00',
#    'scores': {'Abiath': 93, 'Waterman': 104}},
#   {'completed_at': '2023-11-15T09:38:52.417+07:00',
#    'scores': {'HawkLake': 76, 'Merghalodon (TheAlphaQuail)': 69}},
#   {'completed_at': '2023-11-16T16:29:04.887+07:00',
#    'scores': {'gaussiancurve': 94, 'Kopdog': 89}},
#   {'completed_at': '2023-11-22T04:12:10.486+07:00',
#    'scores': {'Dollabill (USA)': 97, 'Picep': 89}},
#   {'completed_at': '2023-11-10T03:27:02.126+07:00',
#    'scores': {'Merghalodon (TheAlphaQuail)': 86, 'Theflash04': 82}},
#   {'completed_at': '2023-11-15T09:32:04.398+07:00',
#    'scores': {'GeorgeV89': 95, 'Dollabill (USA)': 90}},
#   {'completed_at': '2023-11-18T11:31:24.940+07:00',
#    'scores': {'Picep': 85, 'gaussiancurve': 85}},
#   {'completed_at': '2023-11-21T06:06:52.475+07:00',
#    'scores': {'Waterman': 85, 'HawkLake': 99}},
#   {'completed_at': '2023-11-23T01:36:00.103+07:00',
#    'scores': {'Kopdog': 110, 'Abiath': 107}},
#   {'completed_at': '2023-11-16T16:29:41.642+07:00',
#    'scores': {'HawkLake': 78, 'Kopdog': 101}},
#   {'completed_at': '2023-11-16T16:35:56.913+07:00',
#    'scores': {'gaussiancurve': 111, 'Abiath': 106}},
#   {'completed_at': '2023-11-09T18:08:40.369+07:00',
#    'scores': {'Theflash04': 105, 'Waterman': 102}},
#   {'completed_at': '2023-11-16T16:37:32.509+07:00',
#    'scores': {'Dollabill (USA)': 82, 'Merghalodon (TheAlphaQuail)': 90}},
#   {'completed_at': '2023-11-09T18:08:01.124+07:00',
#    'scores': {'Picep': 98, 'GeorgeV89': 94}},
#   {'completed_at': '2023-11-09T18:12:12.965+07:00',
#    'scores': {'GeorgeV89': 100, 'gaussiancurve': 113}},
#   {'completed_at': '2023-11-18T11:31:51.744+07:00',
#    'scores': {'Merghalodon (TheAlphaQuail)': 77, 'Picep': 118}},
#   {'completed_at': '2023-11-21T06:06:47.200+07:00',
#    'scores': {'Waterman': 76, 'Dollabill (USA)': 73}},
#   {'completed_at': '2023-11-14T03:25:14.879+07:00',
#    'scores': {'Kopdog': 92, 'Theflash04': 104}},
#   {'completed_at': '2023-11-09T18:15:17.330+07:00',
#    'scores': {'Abiath': 114, 'HawkLake': 106}},
#   {'completed_at': '2023-11-11T00:40:53.649+07:00',
#    'scores': {'gaussiancurve': 108, 'HawkLake': 101}},
#   {'completed_at': '2023-11-09T18:11:17.441+07:00',
#    'scores': {'Theflash04': 104, 'Abiath': 106}},
#   {'completed_at': '2023-11-15T09:25:04.312+07:00',
#    'scores': {'Dollabill (USA)': 79, 'Kopdog': 109}},
#   {'completed_at': '2023-11-21T06:08:57.262+07:00',
#    'scores': {'Picep': 107, 'Waterman': 122}},
#   {'completed_at': '2023-11-10T03:22:07.964+07:00',
#    'scores': {'GeorgeV89': 80, 'Merghalodon (TheAlphaQuail)': 79}},
#   {'completed_at': '2023-11-10T03:20:20.673+07:00',
#    'scores': {'Waterman': 114, 'GeorgeV89': 104}},
#   {'completed_at': '2023-11-15T08:43:41.716+07:00',
#    'scores': {'Merghalodon (TheAlphaQuail)': 80, 'gaussiancurve': 88}},
#   {'completed_at': '2023-11-20T09:23:28.170+07:00',
#    'scores': {'Kopdog': 94, 'Picep': 99}},
#   {'completed_at': '2023-11-16T16:37:46.391+07:00',
#    'scores': {'Abiath': 110, 'Dollabill (USA)': 90}},
#   {'completed_at': '2023-11-11T00:40:14.803+07:00',
#    'scores': {'HawkLake': 93, 'Theflash04': 99}},
#   {'completed_at': '2023-11-21T06:06:19.441+07:00',
#    'scores': {'Dollabill (USA)': 89, 'HawkLake': 93}},
#   {'completed_at': '2023-11-08T23:42:31.686+07:00',
#    'scores': {'gaussiancurve': 125, 'Theflash04': 128}},
#   {'completed_at': '2023-11-15T09:29:57.973+07:00',
#    'scores': {'GeorgeV89': 109, 'Kopdog': 128}},
#   {'completed_at': '2023-11-14T03:26:44.910+07:00',
#    'scores': {'Merghalodon (TheAlphaQuail)': 71, 'Waterman': 101}},
#   {'completed_at': '2023-11-13T00:05:34.178+07:00',
#    'scores': {'matthew9890': 75, 'Tayray': 92}},
#   {'completed_at': '2023-11-12T01:30:51.768+07:00',
#    'scores': {'BobPrime': 96, 'Stormchaser': 98}},
#   {'completed_at': '2023-11-08T23:42:59.851+07:00',
#    'scores': {'ComTruise': 76, 'Feast4Crows': 88}},
#   {'completed_at': '2023-11-09T18:14:57.405+07:00',
#    'scores': {'MaudlinCake': 95, 'Small FRie': 86}},
#   {'completed_at': '2023-11-18T11:31:25.015+07:00',
#    'scores': {'Small FRie': 81, 'Birdwatcher123': 86}},
#   {'completed_at': '2023-11-13T10:59:44.049+07:00',
#    'scores': {'Feast4Crows': 86, 'matthew9890': 96}},
#   {'completed_at': '2023-11-12T01:31:30.733+07:00',
#    'scores': {'Stormchaser': 97, 'ComTruise': 88}},
#   {'completed_at': '2023-11-09T18:15:43.046+07:00',
#    'scores': {'Ireku': 92, 'BobPrime': 94}},
#   {'completed_at': '2023-11-12T19:39:53.896+07:00',
#    'scores': {'Tayray': 97, 'MaudlinCake': 111}},
#   {'completed_at': '2023-11-12T22:23:14.538+07:00',
#    'scores': {'matthew9890': 92, 'Stormchaser': 102}},
#   {'completed_at': '2023-11-13T11:00:52.359+07:00',
#    'scores': {'BobPrime': 98, 'Small FRie': 104}},
#   {'completed_at': '2023-11-21T06:11:10.254+07:00',
#    'scores': {'ComTruise': 105, 'Ireku': 101}},
#   {'completed_at': '2023-11-11T17:50:48.325+07:00',
#    'scores': {'MaudlinCake': 92, 'Birdwatcher123': 78}},
#   {'completed_at': '2023-11-11T00:44:12.258+07:00',
#    'scores': {'Tayray': 99, 'Feast4Crows': 81}},
#   {'completed_at': '2023-11-15T20:43:23.839+07:00',
#    'scores': {'Ireku': 89, 'matthew9890': 91}},
#   {'completed_at': '2023-11-09T00:33:01.967+07:00',
#    'scores': {'Stormchaser': 104, 'Tayray': 81}},
#   {'completed_at': '2023-11-10T17:08:09.367+07:00',
#    'scores': {'Feast4Crows': 120, 'MaudlinCake': 112}},
#   {'completed_at': '2023-11-18T11:30:47.100+07:00',
#    'scores': {'Small FRie': 107, 'ComTruise': 107}},
#   {'completed_at': '2023-11-20T19:09:31.883+07:00',
#    'scores': {'BobPrime': 90, 'Birdwatcher123': 85}},
#   {'completed_at': '2023-11-11T04:15:32.583+07:00',
#    'scores': {'ComTruise': 85, 'Birdwatcher123': 77}},
#   {'completed_at': '2023-11-11T17:50:34.517+07:00',
#    'scores': {'MaudlinCake': 90, 'BobPrime': 79}},
#   {'completed_at': '2023-11-13T00:05:58.691+07:00',
#    'scores': {'matthew9890': 100, 'Small FRie': 104}},
#   {'completed_at': '2023-11-13T07:50:29.167+07:00',
#    'scores': {'Tayray': 87, 'Ireku': 77}},
#   {'completed_at': '2023-11-10T03:17:46.361+07:00',
#    'scores': {'Feast4Crows': 89, 'Stormchaser': 78}},
#   {'completed_at': '2023-11-10T17:01:25.904+07:00',
#    'scores': {'Stormchaser': 93, 'MaudlinCake': 103}},
#   {'completed_at': '2023-11-09T18:13:10.819+07:00',
#    'scores': {'Small FRie': 91, 'Tayray': 104}},
#   {'completed_at': '2023-11-13T15:37:36.318+07:00',
#    'scores': {'matthew9890': 92, 'Birdwatcher123': 88}},
#   {'completed_at': '2023-11-14T07:17:43.948+07:00',
#    'scores': {'BobPrime': 91, 'ComTruise': 91}},
#   {'completed_at': '2023-11-11T07:28:08.919+07:00',
#    'scores': {'MaudlinCake': 84, 'ComTruise': 98}},
#   {'completed_at': '2023-11-13T10:59:11.584+07:00',
#    'scores': {'matthew9890': 93, 'BobPrime': 99}},
#   {'completed_at': '2023-11-09T18:13:43.629+07:00',
#    'scores': {'Tayray': 92, 'Birdwatcher123': 100}},
#   {'completed_at': '2023-11-15T09:20:36.989+07:00',
#    'scores': {'Feast4Crows': 92, 'Small FRie': 106}},
#   {'completed_at': '2023-11-15T09:34:31.565+07:00',
#    'scores': {'Stormchaser': 100, 'Ireku': 82}},
#   {'completed_at': '2023-11-09T18:08:58.390+07:00',
#    'scores': {'Small FRie': 105, 'Stormchaser': 92}},
#   {'completed_at': '2023-11-13T07:49:15.819+07:00',
#    'scores': {'Ireku': 108, 'MaudlinCake': 97}},
#   {'completed_at': '2023-11-16T16:37:58.481+07:00',
#    'scores': {'Feast4Crows': 79, 'Birdwatcher123': 86}},
#   {'completed_at': '2023-11-13T07:49:59.484+07:00',
#    'scores': {'BobPrime': 86, 'Tayray': 74}},
#   {'completed_at': '2023-11-15T09:26:07.570+07:00',
#    'scores': {'ComTruise': 93, 'matthew9890': 108}},
#   {'completed_at': '2023-11-13T15:36:22.214+07:00',
#    'scores': {'Feast4Crows': 87, 'BobPrime': 102}},
#   {'completed_at': '2023-11-12T01:34:29.050+07:00',
#    'scores': {'Tayray': 85, 'ComTruise': 98}},
#   {'completed_at': '2023-11-13T11:01:03.683+07:00',
#    'scores': {'MaudlinCake': 90, 'matthew9890': 90}},
#   {'completed_at': '2023-11-17T07:29:27.231+07:00',
#    'scores': {'Stormchaser': 102, 'Birdwatcher123': 111}},
#   {'completed_at': '2023-11-13T00:05:38.856+07:00',
#    'scores': {'nastasiko (Norway)': 100, 'oakie': 92}},
#   {'completed_at': '2023-11-17T18:13:06.674+07:00',
#    'scores': {'CheeseDreams': 83, 'queenfisher1': 88}},
#   {'completed_at': '2023-11-23T04:41:48.688+07:00',
#    'scores': {'NoRavens': 89, 'ooievaar': 99}},
#   {'completed_at': '2023-11-09T18:11:47.932+07:00',
#    'scores': {'Foxjoke': 104, 'IGN GokuMatos': 116}},
#   {'completed_at': '2023-11-12T20:51:23.506+07:00',
#    'scores': {'RokB': 90, 'EpicSaxGuy': 104}},
#   {'completed_at': '2023-11-10T17:03:00.753+07:00',
#    'scores': {'EpicSaxGuy': 121, 'CheeseDreams': 116}},
#   {'completed_at': '2023-11-12T01:28:54.452+07:00',
#    'scores': {'IGN GokuMatos': 112, 'nastasiko (Norway)': 92}},
#   {'completed_at': '2023-11-10T03:22:36.090+07:00',
#    'scores': {'ooievaar': 106, 'Foxjoke': 90}},
#   {'completed_at': '2023-11-23T16:02:04.626+07:00',
#    'scores': {'queenfisher1': 95, 'NoRavens': 78}},
#   {'completed_at': '2023-11-20T09:22:55.950+07:00',
#    'scores': {'oakie': 113, 'RokB': 98}},
#   {'completed_at': '2023-11-11T18:02:57.252+07:00',
#    'scores': {'nastasiko (Norway)': 108, 'ooievaar': 120}},
#   {'completed_at': '2023-11-14T07:20:58.437+07:00',
#    'scores': {'NoRavens': 103, 'EpicSaxGuy': 83}},
#   {'completed_at': '2023-11-14T03:26:51.264+07:00',
#    'scores': {'Foxjoke': 101, 'queenfisher1': 106}},
#   {'completed_at': '2023-11-21T06:39:29.609+07:00',
#    'scores': {'RokB': 82, 'CheeseDreams': 100}},
#   {'completed_at': '2023-11-19T22:26:59.464+07:00',
#    'scores': {'oakie': 86, 'IGN GokuMatos': 115}},
#   {'completed_at': '2023-11-11T00:37:49.090+07:00',
#    'scores': {'queenfisher1': 116, 'nastasiko (Norway)': 104}},
#   {'completed_at': '2023-11-13T20:17:52.569+07:00',
#    'scores': {'ooievaar': 101, 'oakie': 111}},
#   {'completed_at': '2023-11-13T01:50:35.448+07:00',
#    'scores': {'IGN GokuMatos': 95, 'RokB': 101}},
#   {'completed_at': '2023-11-09T18:09:26.144+07:00',
#    'scores': {'EpicSaxGuy': 118, 'Foxjoke': 106}},
#   {'completed_at': '2023-11-14T07:18:22.545+07:00',
#    'scores': {'CheeseDreams': 96, 'NoRavens': 85}},
#   {'completed_at': '2023-11-10T17:00:52.245+07:00',
#    'scores': {'Foxjoke': 80, 'CheeseDreams': 93}},
#   {'completed_at': '2023-11-21T17:13:18.546+07:00',
#    'scores': {'RokB': 105, 'NoRavens': 107}},
#   {'completed_at': '2023-11-13T07:47:22.610+07:00',
#    'scores': {'nastasiko (Norway)': 66, 'EpicSaxGuy': 83}},
#   {'completed_at': '2023-11-14T03:22:22.411+07:00',
#    'scores': {'oakie': 101, 'queenfisher1': 80}},
#   {'completed_at': '2023-11-09T22:23:34.148+07:00',
#    'scores': {'IGN GokuMatos': 100, 'ooievaar': 91}},
#   {'completed_at': '2023-11-21T06:09:50.120+07:00',
#    'scores': {'ooievaar': 93, 'RokB': 87}},
#   {'completed_at': '2023-11-10T17:59:25.521+07:00',
#    'scores': {'queenfisher1': 99, 'IGN GokuMatos': 92}},
#   {'completed_at': '2023-11-13T07:52:13.949+07:00',
#    'scores': {'EpicSaxGuy': 116, 'oakie': 93}},
#   {'completed_at': '2023-11-16T16:36:52.748+07:00',
#    'scores': {'CheeseDreams': 107, 'nastasiko (Norway)': 99}},
#   {'completed_at': '2023-11-18T11:33:33.990+07:00',
#    'scores': {'NoRavens': 107, 'Foxjoke': 98}},
#   {'completed_at': '2023-11-14T07:12:53.174+07:00',
#    'scores': {'RokB': 86, 'Foxjoke': 95}},
#   {'completed_at': '2023-11-22T16:58:03.689+07:00',
#    'scores': {'nastasiko (Norway)': 79, 'NoRavens': 92}},
#   {'completed_at': '2023-11-09T18:11:56.157+07:00',
#    'scores': {'IGN GokuMatos': 89, 'EpicSaxGuy': 87}},
#   {'completed_at': '2023-11-09T18:16:22.118+07:00',
#    'scores': {'ooievaar': 108, 'queenfisher1': 85}},
#   {'completed_at': '2023-11-11T00:39:54.741+07:00',
#    'scores': {'EpicSaxGuy': 109, 'ooievaar': 97}},
#   {'completed_at': '2023-11-22T16:57:58.909+07:00',
#    'scores': {'queenfisher1': 87, 'RokB': 81}},
#   {'completed_at': '2023-11-10T17:04:48.334+07:00',
#    'scores': {'CheeseDreams': 91, 'IGN GokuMatos': 107}},
#   {'completed_at': '2023-11-12T01:32:20.239+07:00',
#    'scores': {'NoRavens': 83, 'oakie': 100}},
#   {'completed_at': '2023-11-14T03:25:22.390+07:00',
#    'scores': {'Foxjoke': 102, 'nastasiko (Norway)': 98}},
#   {'completed_at': '2023-11-12T01:32:01.508+07:00',
#    'scores': {'IGN GokuMatos': 105, 'NoRavens': 105}},
#   {'completed_at': '2023-11-14T07:22:07.967+07:00',
#    'scores': {'oakie': 81, 'Foxjoke': 84}},
#   {'completed_at': '2023-11-12T20:47:36.580+07:00',
#    'scores': {'RokB': 90, 'nastasiko (Norway)': 96}},
#   {'completed_at': '2023-11-22T19:45:40.929+07:00',
#    'scores': {'ooievaar': 98, 'CheeseDreams': 100}},
#   {'completed_at': '2023-11-09T22:28:49.013+07:00',
#    'scores': {'queenfisher1': 105, 'EpicSaxGuy': 115}}]}
