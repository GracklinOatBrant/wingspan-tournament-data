# %%
import requests
import os
from functools import cached_property
from collections import defaultdict
import json
from dotenv import load_dotenv
load_dotenv() # includes the CHALLONGE_API_KEY variable
# Out:
# True

# %% [markdown]
# # Define code to download and parse Wingspan tournaments from Challonge

# %%
def challonge_get(url, retries=3):
    try:
        return requests.get(url, {
            'api_key': os.environ['CHALLONGE_API_KEY']
        }, headers={
            'Content-Type': 'application/json',
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'
        }).json()
    except:
        print(f"failed to get {url}")
        if retries > 0:
            return challonge_get(url, retries-1)

valid_owners = {'Bargoff',
 'ChopYouUp',
 'ElsieGlen',
 'FlanHigh',
 'FloatingLakes',
 'Gtrudat',
 'Lone_Eider7',
 'ScaredofBirds',
 'deVisme'}


class Game:
    def __init__(self, scores, players, completed_at, winner):
        self.scores = scores
        self.players = players
        self.completed_at = completed_at
        self.winner = winner

    @property
    def score_dict(self):
        return { player: score for player, score in zip(self.players, self.scores) }
        
class Match:
    def __init__(self, attrs):
        self.attrs = attrs

    @property
    def scores(self):
        try:
            return [[int(s) for s in scores.split('-')]
                    for scores in self.attrs['scores_csv'].split(',')]
        except:
            import pdb; pdb.set_trace()

    @property
    def players(self): return [self.attrs['player1_id'], self.attrs['player2_id']]

    @property
    def completed_at(self): return self.attrs.get('completed_at')

    @property
    def winner(self): return self.attrs.get('winner_id')

    @property
    def games(self):
        return [Game(scores, self.players, self.completed_at, self.winner) for scores in self.scores]
        
class Tournament:
    @classmethod
    def search(cls, max=1000):
        """Use the challonge search feature to get a list of Wingspan tournaments"""
        url = f"https://challonge.com/search/tournaments.json?filters%5Bgame_id%5D=215240&per={max}"
        results = challonge_get(url)['collection']
        results = [r for r in results if r['owner'] in valid_owners]
        tourneys = [cls.by_url(r['link']) for r in results]
        tourneys = [t for t in tourneys if not t.name.lower().startswith('test')]
        return tourneys
    
    @classmethod
    def by_url(cls, url):
        id = challonge_get(f"{url}.json")['tournament']['id']
        return cls.by_id(id)

    @classmethod
    def by_id(cls, id):
        return cls(challonge_get(f"https://api.challonge.com/v1/tournaments/{id}.json")['tournament'])

    def __init__(self, attrs):
        self.attrs = attrs

    @property
    def name(self):
        name = self.attrs['name']
        name = name.strip()
        return name

    @property
    def id(self): return self.attrs['id']

    @property
    def url(self): return f"https://challonge.com/{self.attrs['url']}"

    @property
    def date(self): return self.attrs['started_at']
        
    @cached_property
    def participants(self):
        return [p['participant'] for p in challonge_get(f"https://api.challonge.com/v1/tournaments/{self.id}/participants.json")]

    @cached_property
    def participants_by_id(self):
        by_id = {}
        for p in self.participants:
            by_id[p['id']] = p['name']
            if 'group_player_ids' in p:
                for id in p['group_player_ids']:
                    assert id not in by_id
                    by_id[id] = p['name']
        return by_id
            
    @cached_property
    def matches(self):
        return [
            Match(m['match'])
            for m in challonge_get(f"https://api.challonge.com/v1/tournaments/{self.id}/matches.json")
            if m['match']['state'] == 'complete'
        ]

    @property
    def games(self):
        return [game for match in self.matches for game in match.games]

    @cached_property
    def scores_by_participant(self):
        scores = defaultdict(list)
        for g in self.games:
            for pid, score in g.score_dict.items():
                scores[self.participants_by_id[pid]].append(score)
        return scores

    @cached_property
    def as_json(self):
        return {
              'id': self.id,
              'name': self.name,
              'url': self.url,
              'date': self.date,
              'games': [{
                  'completed_at': game.completed_at,
                  'winner': self.participants_by_id[game.winner],
                  'scores': {
                      self.participants_by_id[game.players[0]]: game.scores[0],
                      self.participants_by_id[game.players[1]]: game.scores[1] 
                  } 
              } for game in self.games]
        }

# %%
t = Tournament(
    challonge_get("https://api.challonge.com/v1/tournaments/13589704.json")['tournament'])
t.name
# Out:
# 'Wingspan World Cup Regionals - Asia'

# %%
t.as_json
# Out:
# {'id': 13589704,
#  'name': 'Wingspan World Cup Regionals - Asia',
#  'url': 'https://challonge.com/7ldxp0zx',
#  'date': '2023-10-14T01:34:11.774-07:00',
#  'games': [{'completed_at': '2023-10-19T14:20:35.234-04:00',
#    'winner': 'mike316',
#    'scores': {'mike316': 97, 'thebangzats': 86}},
#   {'completed_at': '2023-10-15T08:17:17.903-04:00',
#    'winner': 'Zeemokung',
#    'scores': {'MrSaber': 85, 'Zeemokung': 87}},
#   {'completed_at': '2023-11-03T07:58:38.909-04:00',
#    'winner': 'Sim17',
#    'scores': {'Sim17': 94, 'otsukuuyan': 85}},
#   {'completed_at': '2023-10-14T15:47:23.445-04:00',
#    'winner': 'Salmonskinroll',
#    'scores': {'WillyPizza': 87, 'Salmonskinroll': 93}},
#   {'completed_at': '2023-10-15T16:22:06.521-04:00',
#    'winner': 'gdhar67 (GasLighter)',
#    'scores': {'smelly_cat (smellysmellycat)': 85, 'gdhar67 (GasLighter)': 90}},
#   {'completed_at': '2023-10-14T12:47:51.979-04:00',
#    'winner': 'smelly_cat (smellysmellycat)',
#    'scores': {'Salmonskinroll': 89, 'smelly_cat (smellysmellycat)': 93}},
#   {'completed_at': '2023-10-20T18:11:54.898-04:00',
#    'winner': 'WillyPizza',
#    'scores': {'otsukuuyan': 65, 'WillyPizza': 104}},
#   {'completed_at': '2023-10-15T16:16:14.961-04:00',
#    'winner': 'Sim17',
#    'scores': {'Zeemokung': 77, 'Sim17': 114}},
#   {'completed_at': '2023-10-21T22:26:16.176-04:00',
#    'winner': 'MrSaber',
#    'scores': {'thebangzats': 93, 'MrSaber': 95}},
#   {'completed_at': '2023-10-19T14:22:36.053-04:00',
#    'winner': 'Arceusisgood',
#    'scores': {'Arceusisgood': 104, 'mike316': 85}},
#   {'completed_at': '2023-11-04T07:28:21.070-04:00',
#    'winner': 'Arceusisgood',
#    'scores': {'MrSaber': 108, 'Arceusisgood': 110}},
#   {'completed_at': '2023-10-24T06:45:00.018-04:00',
#    'winner': 'thebangzats',
#    'scores': {'Sim17': 86, 'thebangzats': 101}},
#   {'completed_at': '2023-10-15T08:17:53.080-04:00',
#    'winner': 'Zeemokung',
#    'scores': {'WillyPizza': 80, 'Zeemokung': 90}},
#   {'completed_at': '2023-10-28T17:47:29.385-04:00',
#    'winner': 'otsukuuyan',
#    'scores': {'smelly_cat (smellysmellycat)': 74, 'otsukuuyan': 83}},
#   {'completed_at': '2023-10-30T15:31:52.193-04:00',
#    'winner': 'gdhar67 (GasLighter)',
#    'scores': {'gdhar67 (GasLighter)': 101, 'Salmonskinroll': 85}},
#   {'completed_at': '2023-10-28T17:47:44.494-04:00',
#    'winner': 'otsukuuyan',
#    'scores': {'otsukuuyan': 117, 'gdhar67 (GasLighter)': 97}},
#   {'completed_at': '2023-10-22T08:51:50.907-04:00',
#    'winner': 'Zeemokung',
#    'scores': {'Zeemokung': 89, 'smelly_cat (smellysmellycat)': 83}},
#   {'completed_at': '2023-10-19T05:55:35.200-04:00',
#    'winner': 'thebangzats',
#    'scores': {'thebangzats': 99, 'WillyPizza': 96}},
#   {'completed_at': '2023-10-26T11:45:43.062-04:00',
#    'winner': 'Sim17',
#    'scores': {'Arceusisgood': 93, 'Sim17': 98}},
#   {'completed_at': '2023-10-21T04:38:12.267-04:00',
#    'winner': 'MrSaber',
#    'scores': {'mike316': 83, 'MrSaber': 93}},
#   {'completed_at': '2023-10-26T11:45:18.553-04:00',
#    'winner': 'Sim17',
#    'scores': {'Sim17': 115, 'mike316': 94}},
#   {'completed_at': '2023-10-20T08:53:23.598-04:00',
#    'winner': 'Arceusisgood',
#    'scores': {'WillyPizza': 90, 'Arceusisgood': 97}},
#   {'completed_at': '2023-10-23T08:39:33.597-04:00',
#    'winner': 'smelly_cat (smellysmellycat)',
#    'scores': {'smelly_cat (smellysmellycat)': 99, 'thebangzats': 96}},
#   {'completed_at': '2023-10-15T08:20:34.396-04:00',
#    'winner': 'gdhar67 (GasLighter)',
#    'scores': {'gdhar67 (GasLighter)': 92, 'Zeemokung': 88}},
#   {'completed_at': '2023-10-20T18:13:28.558-04:00',
#    'winner': 'Salmonskinroll',
#    'scores': {'Salmonskinroll': 104, 'otsukuuyan': 92}},
#   {'completed_at': '2023-10-15T08:19:02.350-04:00',
#    'winner': 'Zeemokung',
#    'scores': {'Zeemokung': 97, 'Salmonskinroll': 81}},
#   {'completed_at': '2023-10-19T05:55:22.046-04:00',
#    'winner': 'thebangzats',
#    'scores': {'thebangzats': 94, 'gdhar67 (GasLighter)': 87}},
#   {'completed_at': '2023-10-20T08:52:39.435-04:00',
#    'winner': 'smelly_cat (smellysmellycat)',
#    'scores': {'Arceusisgood': 92, 'smelly_cat (smellysmellycat)': 100}},
#   {'completed_at': '2023-10-16T13:45:19.030-04:00',
#    'winner': 'WillyPizza',
#    'scores': {'mike316': 90, 'WillyPizza': 103}},
#   {'completed_at': '2023-10-27T11:10:06.167-04:00',
#    'winner': 'MrSaber',
#    'scores': {'MrSaber': 100, 'Sim17': 92}},
#   {'completed_at': '2023-10-15T08:19:59.439-04:00',
#    'winner': 'WillyPizza',
#    'scores': {'WillyPizza': 87, 'MrSaber': 80}},
#   {'completed_at': '2023-10-26T11:45:25.744-04:00',
#    'winner': 'mike316',
#    'scores': {'smelly_cat (smellysmellycat)': 94, 'mike316': 112}},
#   {'completed_at': '2023-10-19T06:41:01.070-04:00',
#    'winner': 'gdhar67 (GasLighter)',
#    'scores': {'gdhar67 (GasLighter)': 87, 'Arceusisgood': 83}},
#   {'completed_at': '2023-10-19T05:45:51.710-04:00',
#    'winner': 'thebangzats',
#    'scores': {'Salmonskinroll': 73, 'thebangzats': 108}},
#   {'completed_at': '2023-10-21T22:16:40.574-04:00',
#    'winner': 'Zeemokung',
#    'scores': {'otsukuuyan': 90, 'Zeemokung': 90}},
#   {'completed_at': '2023-10-28T17:49:07.995-04:00',
#    'winner': 'thebangzats',
#    'scores': {'thebangzats': 100, 'otsukuuyan': 88}},
#   {'completed_at': '2023-10-19T05:46:28.545-04:00',
#    'winner': 'Arceusisgood',
#    'scores': {'Arceusisgood': 96, 'Salmonskinroll': 73}},
#   {'completed_at': '2023-10-16T05:53:05.715-04:00',
#    'winner': 'mike316',
#    'scores': {'mike316': 112, 'gdhar67 (GasLighter)': 78}},
#   {'completed_at': '2023-10-22T08:51:11.241-04:00',
#    'winner': 'smelly_cat (smellysmellycat)',
#    'scores': {'MrSaber': 99, 'smelly_cat (smellysmellycat)': 104}},
#   {'completed_at': '2023-10-15T16:08:22.418-04:00',
#    'winner': 'WillyPizza',
#    'scores': {'Sim17': 111, 'WillyPizza': 119}},
#   {'completed_at': '2023-10-23T14:27:17.432-04:00',
#    'winner': 'Sim17',
#    'scores': {'smelly_cat (smellysmellycat)': 79, 'Sim17': 101}},
#   {'completed_at': '2023-10-15T08:25:20.516-04:00',
#    'winner': 'MrSaber',
#    'scores': {'gdhar67 (GasLighter)': 108, 'MrSaber': 112}},
#   {'completed_at': '2023-10-16T05:54:55.225-04:00',
#    'winner': 'mike316',
#    'scores': {'Salmonskinroll': 77, 'mike316': 85}},
#   {'completed_at': '2023-11-03T08:00:30.907-04:00',
#    'winner': 'Arceusisgood',
#    'scores': {'otsukuuyan': 99, 'Arceusisgood': 103}},
#   {'completed_at': '2023-10-19T14:20:00.513-04:00',
#    'winner': 'thebangzats',
#    'scores': {'Zeemokung': 82, 'thebangzats': 84}},
#   {'completed_at': '2023-10-19T05:45:46.257-04:00',
#    'winner': 'Arceusisgood',
#    'scores': {'Arceusisgood': 123, 'Zeemokung': 104}},
#   {'completed_at': '2023-11-04T07:30:59.462-04:00',
#    'winner': 'mike316',
#    'scores': {'mike316': 112, 'otsukuuyan': 104}},
#   {'completed_at': '2023-10-15T08:21:13.107-04:00',
#    'winner': 'MrSaber',
#    'scores': {'MrSaber': 97, 'Salmonskinroll': 88}},
#   {'completed_at': '2023-10-24T14:41:46.340-04:00',
#    'winner': 'Sim17',
#    'scores': {'Sim17': 107, 'gdhar67 (GasLighter)': 74}},
#   {'completed_at': '2023-10-16T13:39:27.226-04:00',
#    'winner': 'WillyPizza',
#    'scores': {'WillyPizza': 101, 'smelly_cat (smellysmellycat)': 80}},
#   {'completed_at': '2023-10-14T15:41:16.849-04:00',
#    'winner': 'gdhar67 (GasLighter)',
#    'scores': {'gdhar67 (GasLighter)': 96, 'WillyPizza': 84}},
#   {'completed_at': '2023-10-18T09:28:26.762-04:00',
#    'winner': 'Sim17',
#    'scores': {'Salmonskinroll': 80, 'Sim17': 93}},
#   {'completed_at': '2023-11-04T07:32:05.007-04:00',
#    'winner': 'otsukuuyan',
#    'scores': {'otsukuuyan': 132, 'MrSaber': 101}},
#   {'completed_at': '2023-10-15T08:05:55.591-04:00',
#    'winner': 'mike316',
#    'scores': {'Zeemokung': 79, 'mike316': 100}},
#   {'completed_at': '2023-10-20T08:52:44.556-04:00',
#    'winner': 'thebangzats',
#    'scores': {'thebangzats': 90, 'Arceusisgood': 77}}]}

# %% [markdown]
# # Fetch tournaments

# %%
tourneys = Tournament.search()

# %%
tourney_json = []
bad_tourneys = []
for t in tourneys:
    try:
        tourney_json.append(t.as_json)
    except:
        bad_tourneys.append(t)

# %%
tourneys[1].matches[0].__dict__
# Out:
# {'attrs': {'id': 343585905,
#   'tournament_id': 13718089,
#   'state': 'complete',
#   'player1_id': 26013359,
#   'player2_id': 26013366,
#   'player1_prereq_match_id': None,
#   'player2_prereq_match_id': None,
#   'player1_is_prereq_match_loser': False,
#   'player2_is_prereq_match_loser': False,
#   'winner_id': 26013366,
#   'loser_id': 26013359,
#   'started_at': '2023-11-12T10:08:48.380-06:00',
#   'created_at': '2023-11-12T10:08:47.486-06:00',
#   'updated_at': '2023-11-17T22:15:51.316-06:00',
#   'identifier': 'A',
#   'has_attachment': False,
#   'round': 1,
#   'player1_votes': None,
#   'player2_votes': None,
#   'group_id': 4875707,
#   'attachment_count': None,
#   'scheduled_time': None,
#   'location': None,
#   'underway_at': None,
#   'optional': False,
#   'rushb_id': None,
#   'completed_at': '2023-11-17T22:15:51.338-06:00',
#   'suggested_play_order': 1,
#   'forfeited': None,
#   'open_graph_image_file_name': None,
#   'open_graph_image_content_type': None,
#   'open_graph_image_file_size': None,
#   'prerequisite_match_ids_csv': '',
#   'scores_csv': '70-133,81-114,0-0'}}

# %% [markdown]
# # Normalize user names (there are a lot of near-duplicates :/)

# %%
users = set()

for t in tourney_json:
    for game in t['games']:
        for user, _score in game['scores'].items():
            users.add(user)

users = list(sorted(list(users)))

# %%
import re

def normalize_name(name):
    name = name.lower().split('(')[0].split(' -')[0].split('\t')[0].split(' |')[0].split('#')[0]
    name = name.replace("_", " ")
    name = name.replace("ign: ", "")
    name = name.replace(" ", "")
    #name = re.sub(r"(^[a-z])", "", name)
    name = name.strip()
    return name

normalized_user_names = { name: normalize_name(name) for name in users }

# %%
from collections import defaultdict

user_counts = defaultdict(int)

for t in tourney_json:
    for game in t['games']:
        for user, _score in game['scores'].items():
            user_counts[normalized_user_names[user]] += 1

# %%
from difflib import get_close_matches
import numpy as np

substitutions = {}

for name in set(user_counts.keys()):
    other_names = [n for n in set(user_counts.keys()) if n != name]
    matches = get_close_matches(name, other_names, cutoff=0.75)

    if matches:
        names = [name] + matches
        counts = [user_counts[n] for n in names]
        idx = np.argmax(counts)
        for n in names:
            if n != names[idx]:
                substitutions[n] = names[idx]

# %%
substitutions2 = {'sleephead': 'sleepyhead',
 'tay-ray': 'tayray',
 #'taykay': 'tayray',
# 'rokb': 'rob',
# 'robin': 'rob',
# 'dagger': 'digger',
 'żyraf🦒': 'żyraf',
 'zyraf': 'żyraf',
 'thecomedian91': 'thec0median',
 'thec0median91': 'thec0median',
 'irek': 'ireku',
 'no-m': 'no~m',
 'nom': 'no~m',
# 'wingsplaingaming': 'wingspanner',
# 'bluethroat': 'bluethroat4life',
 'wingspanner2': 'wingspanner',
 #'eurasiannuthatch': 'corsicannuthatch',
 #'corsicannuthatch': 'eurasiannuthatch',
 #'team23': 'team20',
 #'sandro': 'andreko',
 'jeasthebeast': 'jeastthebeast',
 #'jeastthebeast+malue': 'jeastthebeast',
# 'eurasianhobby': 'eurasianjay',
# 'ltrudat': 'gtrudat',
 'elsapoguapobot': 'elsapoguapo',
 'dozo': 'dozi',
 'theflash04': 'theflash',
 #'scaredofdiamonds': 'scaredofbirds',
 #'wingsplain': 'wingspanner',
 'seechristy': 'seechristine',
 #'commonmoorhen': 'commonraven',
 #'eurasianjay': 'eurasianhobby',
 #'spartafnfan13+wayward': 'spartanfan13',
 'stormchaser20': 'stormchaser',
 #'merisabear': 'mrsaber',
 'ronster': 'ronster7',
 #'mtrooster': 'ronster',
 'ooievaar🇳🇱': 'ooievaar',
 #'avery': 'av0ry',
 'spartafnfan13': 'spartanfan13',
 #'white-backedwoodpecker': 'blackwoodpecker',
 #'groovenbeast': 'groovenstein',
 'falblingius': 'falblinger',
 #'eurasiansparrowhawk': 'eurasiantreesparrow',
 'nedmund13': 'nedmund',
 'nedmud13': 'nedmund',
 'chuck': 'chuckaus',
 'mothertucker': 'mothertuckers',
# 'eurasiannutcracker': 'eurasiannuthatch',
 'yippecahier': 'yippeecahier',
# 'team20': 'team23',
# 'eurasiantreesparrow': 'eurasiansparrowhawk'
                 }

# %%
normalized_user_names2 = { k: substitutions2.get(v, v) for k, v in normalized_user_names.items() }

# %%
names_matching_normalized = defaultdict(list)
for k, v in normalized_user_names2.items():
    names_matching_normalized[v].append(k)

# %%
from collections import Counter

overall_counts = Counter([
    user
    for t in tourney_json
    for game in t['games']
    for user, _score in game['scores'].items()
])

# %%
canonical_names = {}

for normalized_name, variants in names_matching_normalized.items():
    counts_by_variant = [overall_counts[v] for v in variants]
    canonical_names[normalized_name] = variants[np.argmax(counts_by_variant)]

# %%
normalized_tourneys = []
for t in tourney_json:
    new_tourney = dict(t)
    games = new_tourney['games']
    new_games = []
    for game in games:
        new_game = dict(game)
        new_scores = {}
        for k, v in game['scores'].items():
            new_scores[canonical_names[normalized_user_names2[k]]] = v
        new_game['scores'] = new_scores
        new_games.append(new_game)
    new_tourney['games'] = new_games
    normalized_tourneys.append(new_tourney)

# %%
normalized_tourneys[1]
# Out:
# {'id': 13718089,
#  'name': 'Xenopsaris X-Factor',
#  'url': 'https://challonge.com/wtds_xx',
#  'date': None,
#  'games': [{'completed_at': '2023-11-17T22:15:51.338-06:00',
#    'winner': 'ChopYouUp',
#    'scores': {'lemon': 70, 'ChopYouUp': 133}},
#   {'completed_at': '2023-11-17T22:15:51.338-06:00',
#    'winner': 'ChopYouUp',
#    'scores': {'lemon': 81, 'ChopYouUp': 114}},
#   {'completed_at': '2023-11-17T22:15:51.338-06:00',
#    'winner': 'ChopYouUp',
#    'scores': {'lemon': 0, 'ChopYouUp': 0}},
#   {'completed_at': '2023-11-18T10:23:09.923-06:00',
#    'winner': 'noravens',
#    'scores': {'Orcinus': 105, 'noravens': 107}},
#   {'completed_at': '2023-11-18T10:23:09.923-06:00',
#    'winner': 'noravens',
#    'scores': {'Orcinus': 81, 'noravens': 103}},
#   {'completed_at': '2023-11-18T10:23:09.923-06:00',
#    'winner': 'noravens',
#    'scores': {'Orcinus': 0, 'noravens': 0}},
#   {'completed_at': '2023-11-17T10:35:14.124-06:00',
#    'winner': 'gtrudat',
#    'scores': {'smelly_cat': 99, 'gtrudat': 82}},
#   {'completed_at': '2023-11-17T10:35:14.124-06:00',
#    'winner': 'gtrudat',
#    'scores': {'smelly_cat': 92, 'gtrudat': 94}},
#   {'completed_at': '2023-11-17T10:35:14.124-06:00',
#    'winner': 'gtrudat',
#    'scores': {'smelly_cat': 108, 'gtrudat': 119}},
#   {'completed_at': '2023-11-14T19:20:19.853-06:00',
#    'winner': 'gaussiancurve',
#    'scores': {'gaussiancurve': 102, 'spocpes': 75}},
#   {'completed_at': '2023-11-14T19:20:19.853-06:00',
#    'winner': 'gaussiancurve',
#    'scores': {'gaussiancurve': 103, 'spocpes': 71}},
#   {'completed_at': '2023-11-14T19:20:19.853-06:00',
#    'winner': 'gaussiancurve',
#    'scores': {'gaussiancurve': 0, 'spocpes': 0}},
#   {'completed_at': '2023-11-26T08:25:01.855-06:00',
#    'winner': 'noravens',
#    'scores': {'ChopYouUp': 91, 'noravens': 95}},
#   {'completed_at': '2023-11-26T08:25:01.855-06:00',
#    'winner': 'noravens',
#    'scores': {'ChopYouUp': 91, 'noravens': 87}},
#   {'completed_at': '2023-11-26T08:25:01.855-06:00',
#    'winner': 'noravens',
#    'scores': {'ChopYouUp': 93, 'noravens': 115}},
#   {'completed_at': '2023-11-19T09:15:41.105-06:00',
#    'winner': 'gaussiancurve',
#    'scores': {'gtrudat': 90, 'gaussiancurve': 91}},
#   {'completed_at': '2023-11-19T09:15:41.105-06:00',
#    'winner': 'gaussiancurve',
#    'scores': {'gtrudat': 74, 'gaussiancurve': 75}},
#   {'completed_at': '2023-11-19T09:15:41.105-06:00',
#    'winner': 'gaussiancurve',
#    'scores': {'gtrudat': 0, 'gaussiancurve': 0}},
#   {'completed_at': '2023-11-16T17:03:50.923-06:00',
#    'winner': 'AmithA',
#    'scores': {'Nico1968': 79, 'AmithA': 83}},
#   {'completed_at': '2023-11-16T17:03:50.923-06:00',
#    'winner': 'AmithA',
#    'scores': {'Nico1968': 61, 'AmithA': 94}},
#   {'completed_at': '2023-11-16T17:03:50.923-06:00',
#    'winner': 'AmithA',
#    'scores': {'Nico1968': 0, 'AmithA': 0}},
#   {'completed_at': '2023-11-18T14:50:01.440-06:00',
#    'winner': 'stalledbird',
#    'scores': {'Stalledbird': 90, 'Palindrome': 83}},
#   {'completed_at': '2023-11-18T14:50:01.440-06:00',
#    'winner': 'stalledbird',
#    'scores': {'Stalledbird': 81, 'Palindrome': 93}},
#   {'completed_at': '2023-11-18T14:50:01.440-06:00',
#    'winner': 'stalledbird',
#    'scores': {'Stalledbird': 71, 'Palindrome': 68}},
#   {'completed_at': '2023-11-13T17:56:26.734-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'ScaredofBirds': 109, 'DMonkey225': 54}},
#   {'completed_at': '2023-11-13T17:56:26.734-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'ScaredofBirds': 83, 'DMonkey225': 56}},
#   {'completed_at': '2023-11-13T17:56:26.734-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'ScaredofBirds': 0, 'DMonkey225': 0}},
#   {'completed_at': '2023-11-13T16:38:11.593-06:00',
#    'winner': 'Huxley3000',
#    'scores': {'GraDog22': 96, 'Huxley3000': 84}},
#   {'completed_at': '2023-11-13T16:38:11.593-06:00',
#    'winner': 'Huxley3000',
#    'scores': {'GraDog22': 86, 'Huxley3000': 102}},
#   {'completed_at': '2023-11-13T16:38:11.593-06:00',
#    'winner': 'Huxley3000',
#    'scores': {'GraDog22': 101, 'Huxley3000': 113}},
#   {'completed_at': '2023-11-21T04:59:38.017-06:00',
#    'winner': 'stalledbird',
#    'scores': {'AmithA': 76, 'Stalledbird': 77}},
#   {'completed_at': '2023-11-21T04:59:38.017-06:00',
#    'winner': 'stalledbird',
#    'scores': {'AmithA': 91, 'Stalledbird': 107}},
#   {'completed_at': '2023-11-21T04:59:38.017-06:00',
#    'winner': 'stalledbird',
#    'scores': {'AmithA': 0, 'Stalledbird': 0}},
#   {'completed_at': '2023-11-17T10:37:23.973-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'ScaredofBirds': 98, 'Huxley3000': 83}},
#   {'completed_at': '2023-11-17T10:37:23.973-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'ScaredofBirds': 111, 'Huxley3000': 91}},
#   {'completed_at': '2023-11-17T10:37:23.973-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'ScaredofBirds': 0, 'Huxley3000': 0}},
#   {'completed_at': '2023-11-26T21:36:54.634-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'Stalledbird': 85, 'ScaredofBirds': 107}},
#   {'completed_at': '2023-11-26T21:36:54.634-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'Stalledbird': 107, 'ScaredofBirds': 118}},
#   {'completed_at': '2023-11-26T21:36:54.634-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'Stalledbird': 0, 'ScaredofBirds': 0}},
#   {'completed_at': '2023-11-18T14:54:27.578-06:00',
#    'winner': 'travs',
#    'scores': {'travs': 93, 'Tiny Geese': 83}},
#   {'completed_at': '2023-11-18T14:54:27.578-06:00',
#    'winner': 'travs',
#    'scores': {'travs': 82, 'Tiny Geese': 98}},
#   {'completed_at': '2023-11-18T14:54:27.578-06:00',
#    'winner': 'travs',
#    'scores': {'travs': 88, 'Tiny Geese': 79}},
#   {'completed_at': '2023-11-16T05:10:26.849-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'Merisabear': 87, 'BlackSpice28': 108}},
#   {'completed_at': '2023-11-16T05:10:26.849-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'Merisabear': 75, 'BlackSpice28': 93}},
#   {'completed_at': '2023-11-16T05:10:26.849-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'Merisabear': 0, 'BlackSpice28': 0}},
#   {'completed_at': '2023-11-16T21:35:07.490-06:00',
#    'winner': 'WeirdOwl',
#    'scores': {'z12monkeys': 83, 'Weirdowl': 78}},
#   {'completed_at': '2023-11-16T21:35:07.490-06:00',
#    'winner': 'WeirdOwl',
#    'scores': {'z12monkeys': 88, 'Weirdowl': 97}},
#   {'completed_at': '2023-11-16T21:35:07.490-06:00',
#    'winner': 'WeirdOwl',
#    'scores': {'z12monkeys': 84, 'Weirdowl': 85}},
#   {'completed_at': '2023-11-13T14:29:45.597-06:00',
#    'winner': 'WillyPizza',
#    'scores': {'Foxjoke': 117, 'WillyPizza': 92}},
#   {'completed_at': '2023-11-13T14:29:45.597-06:00',
#    'winner': 'WillyPizza',
#    'scores': {'Foxjoke': 88, 'WillyPizza': 113}},
#   {'completed_at': '2023-11-13T14:29:45.597-06:00',
#    'winner': 'WillyPizza',
#    'scores': {'Foxjoke': 108, 'WillyPizza': 122}},
#   {'completed_at': '2023-11-21T05:00:34.838-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'travs': 85, 'BlackSpice28': 108}},
#   {'completed_at': '2023-11-21T05:00:34.838-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'travs': 103, 'BlackSpice28': 129}},
#   {'completed_at': '2023-11-21T05:00:34.838-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'travs': 0, 'BlackSpice28': 0}},
#   {'completed_at': '2023-11-17T10:35:58.323-06:00',
#    'winner': 'WeirdOwl',
#    'scores': {'Weirdowl': 97, 'WillyPizza': 96}},
#   {'completed_at': '2023-11-17T10:35:58.323-06:00',
#    'winner': 'WeirdOwl',
#    'scores': {'Weirdowl': 94, 'WillyPizza': 90}},
#   {'completed_at': '2023-11-17T10:35:58.323-06:00',
#    'winner': 'WeirdOwl',
#    'scores': {'Weirdowl': 0, 'WillyPizza': 0}},
#   {'completed_at': '2023-11-21T14:28:02.040-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'BlackSpice28': 80, 'Weirdowl': 76}},
#   {'completed_at': '2023-11-21T14:28:02.040-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'BlackSpice28': 84, 'Weirdowl': 91}},
#   {'completed_at': '2023-11-21T14:28:02.040-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'BlackSpice28': 107, 'Weirdowl': 82}},
#   {'completed_at': '2023-11-13T14:32:36.923-06:00',
#    'winner': 'Shepherd0',
#    'scores': {'Shepherd0': 104, 'SegalLikeTheBird': 100}},
#   {'completed_at': '2023-11-13T14:32:36.923-06:00',
#    'winner': 'Shepherd0',
#    'scores': {'Shepherd0': 95, 'SegalLikeTheBird': 101}},
#   {'completed_at': '2023-11-13T14:32:36.923-06:00',
#    'winner': 'Shepherd0',
#    'scores': {'Shepherd0': 101, 'SegalLikeTheBird': 96}},
#   {'completed_at': '2023-11-16T05:10:24.669-06:00',
#    'winner': 'cgjunior',
#    'scores': {'MrSaber': 80, 'cgjunior': 87}},
#   {'completed_at': '2023-11-16T05:10:24.669-06:00',
#    'winner': 'cgjunior',
#    'scores': {'MrSaber': 101, 'cgjunior': 98}},
#   {'completed_at': '2023-11-16T05:10:24.669-06:00',
#    'winner': 'cgjunior',
#    'scores': {'MrSaber': 95, 'cgjunior': 105}},
#   {'completed_at': '2023-11-16T08:41:30.352-06:00',
#    'winner': 'Maskonur',
#    'scores': {'_aquanaut': 99, 'Maskonur': 90}},
#   {'completed_at': '2023-11-16T08:41:30.352-06:00',
#    'winner': 'Maskonur',
#    'scores': {'_aquanaut': 71, 'Maskonur': 97}},
#   {'completed_at': '2023-11-16T08:41:30.352-06:00',
#    'winner': 'Maskonur',
#    'scores': {'_aquanaut': 72, 'Maskonur': 93}},
#   {'completed_at': '2023-11-18T14:45:06.627-06:00',
#    'winner': 'Jjlig2mobile2',
#    'scores': {'Jjlig2mobile2': 87, 'thehoneyeater87': 76}},
#   {'completed_at': '2023-11-18T14:45:06.627-06:00',
#    'winner': 'Jjlig2mobile2',
#    'scores': {'Jjlig2mobile2': 132, 'thehoneyeater87': 122}},
#   {'completed_at': '2023-11-18T14:45:06.627-06:00',
#    'winner': 'Jjlig2mobile2',
#    'scores': {'Jjlig2mobile2': 0, 'thehoneyeater87': 0}},
#   {'completed_at': '2023-11-19T07:59:02.089-06:00',
#    'winner': 'Shepherd0',
#    'scores': {'Shepherd0': 111, 'cgjunior': 74}},
#   {'completed_at': '2023-11-19T07:59:02.089-06:00',
#    'winner': 'Shepherd0',
#    'scores': {'Shepherd0': 106, 'cgjunior': 85}},
#   {'completed_at': '2023-11-19T07:59:02.089-06:00',
#    'winner': 'Shepherd0',
#    'scores': {'Shepherd0': 0, 'cgjunior': 0}},
#   {'completed_at': '2023-11-19T20:10:19.301-06:00',
#    'winner': 'Maskonur',
#    'scores': {'Maskonur': 91, 'Jjlig2mobile2': 83}},
#   {'completed_at': '2023-11-19T20:10:19.301-06:00',
#    'winner': 'Maskonur',
#    'scores': {'Maskonur': 90, 'Jjlig2mobile2': 89}},
#   {'completed_at': '2023-11-19T20:10:19.301-06:00',
#    'winner': 'Maskonur',
#    'scores': {'Maskonur': 0, 'Jjlig2mobile2': 0}},
#   {'completed_at': '2023-11-22T06:04:35.218-06:00',
#    'winner': 'Maskonur',
#    'scores': {'Shepherd0': 97, 'Maskonur': 96}},
#   {'completed_at': '2023-11-22T06:04:35.218-06:00',
#    'winner': 'Maskonur',
#    'scores': {'Shepherd0': 87, 'Maskonur': 90}},
#   {'completed_at': '2023-11-22T06:04:35.218-06:00',
#    'winner': 'Maskonur',
#    'scores': {'Shepherd0': 98, 'Maskonur': 115}},
#   {'completed_at': '2023-11-16T04:31:32.052-06:00',
#    'winner': 'Sim17',
#    'scores': {'Sim17': 94, 'bushNIT': 80}},
#   {'completed_at': '2023-11-16T04:31:32.052-06:00',
#    'winner': 'Sim17',
#    'scores': {'Sim17': 104, 'bushNIT': 106}},
#   {'completed_at': '2023-11-16T04:31:32.052-06:00',
#    'winner': 'Sim17',
#    'scores': {'Sim17': 103, 'bushNIT': 81}},
#   {'completed_at': '2023-11-19T20:05:42.449-06:00',
#    'winner': 'vpol55',
#    'scores': {'JunePaik': 105, 'vpol55': 94}},
#   {'completed_at': '2023-11-19T20:05:42.449-06:00',
#    'winner': 'vpol55',
#    'scores': {'JunePaik': 89, 'vpol55': 103}},
#   {'completed_at': '2023-11-19T20:05:42.449-06:00',
#    'winner': 'vpol55',
#    'scores': {'JunePaik': 79, 'vpol55': 101}},
#   {'completed_at': '2023-11-19T20:11:50.723-06:00',
#    'winner': 'Waterman',
#    'scores': {'Abiath': 78, 'Waterman': 81}},
#   {'completed_at': '2023-11-19T20:11:50.723-06:00',
#    'winner': 'Waterman',
#    'scores': {'Abiath': 109, 'Waterman': 98}},
#   {'completed_at': '2023-11-19T20:11:50.723-06:00',
#    'winner': 'Waterman',
#    'scores': {'Abiath': 93, 'Waterman': 95}},
#   {'completed_at': '2023-11-19T08:02:59.732-06:00',
#    'winner': 'SleepyHead',
#    'scores': {'Sleepyhead': 101, 'KarlHungus': 95}},
#   {'completed_at': '2023-11-19T08:02:59.732-06:00',
#    'winner': 'SleepyHead',
#    'scores': {'Sleepyhead': 90, 'KarlHungus': 87}},
#   {'completed_at': '2023-11-19T08:02:59.732-06:00',
#    'winner': 'SleepyHead',
#    'scores': {'Sleepyhead': 0, 'KarlHungus': 0}},
#   {'completed_at': '2023-11-25T18:08:24.623-06:00',
#    'winner': 'vpol55',
#    'scores': {'Sim17': 96, 'vpol55': 97}},
#   {'completed_at': '2023-11-25T18:08:24.623-06:00',
#    'winner': 'vpol55',
#    'scores': {'Sim17': 79, 'vpol55': 90}},
#   {'completed_at': '2023-11-25T18:08:24.623-06:00',
#    'winner': 'vpol55',
#    'scores': {'Sim17': 0, 'vpol55': 0}},
#   {'completed_at': '2023-11-25T18:08:40.615-06:00',
#    'winner': 'SleepyHead',
#    'scores': {'Waterman': 92, 'Sleepyhead': 101}},
#   {'completed_at': '2023-11-25T18:08:40.615-06:00',
#    'winner': 'SleepyHead',
#    'scores': {'Waterman': 124, 'Sleepyhead': 101}},
#   {'completed_at': '2023-11-25T18:08:40.615-06:00',
#    'winner': 'SleepyHead',
#    'scores': {'Waterman': 88, 'Sleepyhead': 96}},
#   {'completed_at': '2023-11-13T14:29:20.313-06:00',
#    'winner': 'matthew9890',
#    'scores': {'EpicSaxGuy': 94, 'matthew9890': 104}},
#   {'completed_at': '2023-11-13T14:29:20.313-06:00',
#    'winner': 'matthew9890',
#    'scores': {'EpicSaxGuy': 112, 'matthew9890': 104}},
#   {'completed_at': '2023-11-13T14:29:20.313-06:00',
#    'winner': 'matthew9890',
#    'scores': {'EpicSaxGuy': 119, 'matthew9890': 122}},
#   {'completed_at': '2023-11-16T04:55:38.563-06:00',
#    'winner': 'Naketano',
#    'scores': {'SPAKEME': 83, 'Naketano': 89}},
#   {'completed_at': '2023-11-16T04:55:38.563-06:00',
#    'winner': 'Naketano',
#    'scores': {'SPAKEME': 81, 'Naketano': 86}},
#   {'completed_at': '2023-11-16T04:55:38.563-06:00',
#    'winner': 'Naketano',
#    'scores': {'SPAKEME': 0, 'Naketano': 0}},
#   {'completed_at': '2023-11-14T19:22:18.509-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'gdhar67 (GasLighter)': 83, 'MaudlinCake': 91}},
#   {'completed_at': '2023-11-14T19:22:18.509-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'gdhar67 (GasLighter)': 105, 'MaudlinCake': 94}},
#   {'completed_at': '2023-11-14T19:22:18.509-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'gdhar67 (GasLighter)': 95, 'MaudlinCake': 109}},
#   {'completed_at': '2023-11-17T05:38:08.492-06:00',
#    'winner': 'Quacky',
#    'scores': {'Solskjaer025! (IGN Damsgaard)': 90, 'quacky': 78}},
#   {'completed_at': '2023-11-17T05:38:08.492-06:00',
#    'winner': 'Quacky',
#    'scores': {'Solskjaer025! (IGN Damsgaard)': 74, 'quacky': 86}},
#   {'completed_at': '2023-11-17T05:38:08.492-06:00',
#    'winner': 'Quacky',
#    'scores': {'Solskjaer025! (IGN Damsgaard)': 70, 'quacky': 82}},
#   {'completed_at': '2023-11-17T10:35:39.827-06:00',
#    'winner': 'matthew9890',
#    'scores': {'matthew9890': 88, 'Naketano': 74}},
#   {'completed_at': '2023-11-17T10:35:39.827-06:00',
#    'winner': 'matthew9890',
#    'scores': {'matthew9890': 101, 'Naketano': 80}},
#   {'completed_at': '2023-11-17T10:35:39.827-06:00',
#    'winner': 'matthew9890',
#    'scores': {'matthew9890': 0, 'Naketano': 0}},
#   {'completed_at': '2023-11-25T18:05:44.531-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'MaudlinCake': 75, 'quacky': 91}},
#   {'completed_at': '2023-11-25T18:05:44.531-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'MaudlinCake': 106, 'quacky': 101}},
#   {'completed_at': '2023-11-25T18:05:44.531-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'MaudlinCake': 110, 'quacky': 91}},
#   {'completed_at': '2023-11-26T20:33:42.587-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'matthew9890': 79, 'MaudlinCake': 90}},
#   {'completed_at': '2023-11-26T20:33:42.587-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'matthew9890': 101, 'MaudlinCake': 126}},
#   {'completed_at': '2023-11-26T20:33:42.587-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'matthew9890': 0, 'MaudlinCake': 0}},
#   {'completed_at': '2023-11-14T19:34:23.755-06:00',
#    'winner': 'jeastthebeast',
#    'scores': {'birdwatchermobile': 73, 'jeastthebeast': 80}},
#   {'completed_at': '2023-11-14T19:34:23.755-06:00',
#    'winner': 'jeastthebeast',
#    'scores': {'birdwatchermobile': 85, 'jeastthebeast': 90}},
#   {'completed_at': '2023-11-14T19:34:23.755-06:00',
#    'winner': 'jeastthebeast',
#    'scores': {'birdwatchermobile': 0, 'jeastthebeast': 0}},
#   {'completed_at': '2023-11-18T15:49:48.830-06:00',
#    'winner': 'thedetermin8or',
#    'scores': {'CheeseDreams': 98, 'thedetermin8or': 92}},
#   {'completed_at': '2023-11-18T15:49:48.830-06:00',
#    'winner': 'thedetermin8or',
#    'scores': {'CheeseDreams': 83, 'thedetermin8or': 97}},
#   {'completed_at': '2023-11-18T15:49:48.830-06:00',
#    'winner': 'thedetermin8or',
#    'scores': {'CheeseDreams': 113, 'thedetermin8or': 123}},
#   {'completed_at': '2023-11-17T05:37:54.599-06:00',
#    'winner': 'RickCissel',
#    'scores': {'b0romir': 76, 'RickCissel': 88}},
#   {'completed_at': '2023-11-17T05:37:54.599-06:00',
#    'winner': 'RickCissel',
#    'scores': {'b0romir': 70, 'RickCissel': 99}},
#   {'completed_at': '2023-11-17T05:37:54.599-06:00',
#    'winner': 'RickCissel',
#    'scores': {'b0romir': 0, 'RickCissel': 0}},
#   {'completed_at': '2023-11-14T19:25:18.838-06:00',
#    'winner': 'Danko',
#    'scores': {'Flan': 112, 'Danko': 107}},
#   {'completed_at': '2023-11-14T19:25:18.838-06:00',
#    'winner': 'Danko',
#    'scores': {'Flan': 84, 'Danko': 95}},
#   {'completed_at': '2023-11-14T19:25:18.838-06:00',
#    'winner': 'Danko',
#    'scores': {'Flan': 91, 'Danko': 93}},
#   {'completed_at': '2023-11-20T17:12:38.011-06:00',
#    'winner': 'jeastthebeast',
#    'scores': {'jeastthebeast': 102, 'thedetermin8or': 78}},
#   {'completed_at': '2023-11-20T17:12:38.011-06:00',
#    'winner': 'jeastthebeast',
#    'scores': {'jeastthebeast': 106, 'thedetermin8or': 97}},
#   {'completed_at': '2023-11-20T17:12:38.011-06:00',
#    'winner': 'jeastthebeast',
#    'scores': {'jeastthebeast': 0, 'thedetermin8or': 0}},
#   {'completed_at': '2023-11-18T14:51:16.163-06:00',
#    'winner': 'Danko',
#    'scores': {'RickCissel': 111, 'Danko': 130}},
#   {'completed_at': '2023-11-18T14:51:16.163-06:00',
#    'winner': 'Danko',
#    'scores': {'RickCissel': 109, 'Danko': 83}},
#   {'completed_at': '2023-11-18T14:51:16.163-06:00',
#    'winner': 'Danko',
#    'scores': {'RickCissel': 88, 'Danko': 105}},
#   {'completed_at': '2023-11-21T14:33:23.022-06:00',
#    'winner': 'Danko',
#    'scores': {'jeastthebeast': 95, 'Danko': 99}},
#   {'completed_at': '2023-11-21T14:33:23.022-06:00',
#    'winner': 'Danko',
#    'scores': {'jeastthebeast': 101, 'Danko': 86}},
#   {'completed_at': '2023-11-21T14:33:23.022-06:00',
#    'winner': 'Danko',
#    'scores': {'jeastthebeast': 75, 'Danko': 97}},
#   {'completed_at': '2023-11-13T14:30:26.324-06:00',
#    'winner': 'WoodpeckerJoe',
#    'scores': {'WoodpeckerJoe': 98, 'Terracotta (aLL1e)': 74}},
#   {'completed_at': '2023-11-13T14:30:26.324-06:00',
#    'winner': 'WoodpeckerJoe',
#    'scores': {'WoodpeckerJoe': 123, 'Terracotta (aLL1e)': 108}},
#   {'completed_at': '2023-11-13T14:30:26.324-06:00',
#    'winner': 'WoodpeckerJoe',
#    'scores': {'WoodpeckerJoe': 0, 'Terracotta (aLL1e)': 0}},
#   {'completed_at': '2023-11-14T20:47:56.942-06:00',
#    'winner': 'BalletMage',
#    'scores': {'bronka': 93, 'BalletMage': 76}},
#   {'completed_at': '2023-11-14T20:47:56.942-06:00',
#    'winner': 'BalletMage',
#    'scores': {'bronka': 95, 'BalletMage': 97}},
#   {'completed_at': '2023-11-14T20:47:56.942-06:00',
#    'winner': 'BalletMage',
#    'scores': {'bronka': 74, 'BalletMage': 88}},
#   {'completed_at': '2023-11-16T17:03:12.057-06:00',
#    'winner': 'captain_awesome.',
#    'scores': {'captain_awesome.': 81, 'Ben_fm': 96}},
#   {'completed_at': '2023-11-16T17:03:12.057-06:00',
#    'winner': 'captain_awesome.',
#    'scores': {'captain_awesome.': 107, 'Ben_fm': 90}},
#   {'completed_at': '2023-11-16T17:03:12.057-06:00',
#    'winner': 'captain_awesome.',
#    'scores': {'captain_awesome.': 87, 'Ben_fm': 82}},
#   {'completed_at': '2023-11-19T20:09:04.388-06:00',
#    'winner': 'Scotsword',
#    'scores': {'Jamesvanderbeak': 70, 'Scotsword': 94}},
#   {'completed_at': '2023-11-19T20:09:04.388-06:00',
#    'winner': 'Scotsword',
#    'scores': {'Jamesvanderbeak': 87, 'Scotsword': 95}},
#   {'completed_at': '2023-11-19T20:09:04.388-06:00',
#    'winner': 'Scotsword',
#    'scores': {'Jamesvanderbeak': 0, 'Scotsword': 0}},
#   {'completed_at': '2023-11-16T18:49:36.242-06:00',
#    'winner': 'BalletMage',
#    'scores': {'WoodpeckerJoe': 88, 'BalletMage': 87}},
#   {'completed_at': '2023-11-16T18:49:36.242-06:00',
#    'winner': 'BalletMage',
#    'scores': {'WoodpeckerJoe': 81, 'BalletMage': 95}},
#   {'completed_at': '2023-11-16T18:49:36.242-06:00',
#    'winner': 'BalletMage',
#    'scores': {'WoodpeckerJoe': 78, 'BalletMage': 79}},
#   {'completed_at': '2023-11-25T18:03:50.557-06:00',
#    'winner': 'captain_awesome.',
#    'scores': {'captain_awesome.': 85, 'Scotsword': 101}},
#   {'completed_at': '2023-11-25T18:03:50.557-06:00',
#    'winner': 'captain_awesome.',
#    'scores': {'captain_awesome.': 97, 'Scotsword': 85}},
#   {'completed_at': '2023-11-25T18:03:50.557-06:00',
#    'winner': 'captain_awesome.',
#    'scores': {'captain_awesome.': 96, 'Scotsword': 71}},
#   {'completed_at': '2023-11-27T13:37:15.818-06:00',
#    'winner': 'BalletMage',
#    'scores': {'BalletMage': 98, 'captain_awesome.': 106}},
#   {'completed_at': '2023-11-27T13:37:15.818-06:00',
#    'winner': 'BalletMage',
#    'scores': {'BalletMage': 124, 'captain_awesome.': 94}},
#   {'completed_at': '2023-11-27T13:37:15.818-06:00',
#    'winner': 'BalletMage',
#    'scores': {'BalletMage': 100, 'captain_awesome.': 80}},
#   {'completed_at': '2023-11-14T19:26:39.201-06:00',
#    'winner': 'Irek',
#    'scores': {'Irek': 95, 'gdpeck (72BirdSong)': 80}},
#   {'completed_at': '2023-11-14T19:26:39.201-06:00',
#    'winner': 'Irek',
#    'scores': {'Irek': 115, 'gdpeck (72BirdSong)': 85}},
#   {'completed_at': '2023-11-14T19:26:39.201-06:00',
#    'winner': 'Irek',
#    'scores': {'Irek': 0, 'gdpeck (72BirdSong)': 0}},
#   {'completed_at': '2023-11-19T09:30:53.993-06:00',
#    'winner': 'GeorgeV89',
#    'scores': {'dagger_hashimoto_': 80, 'GeorgeV89': 95}},
#   {'completed_at': '2023-11-19T09:30:53.993-06:00',
#    'winner': 'GeorgeV89',
#    'scores': {'dagger_hashimoto_': 91, 'GeorgeV89': 98}},
#   {'completed_at': '2023-11-19T09:30:53.993-06:00',
#    'winner': 'GeorgeV89',
#    'scores': {'dagger_hashimoto_': 0, 'GeorgeV89': 0}},
#   {'completed_at': '2023-11-12T18:33:06.231-06:00',
#    'winner': 'SadRick (IGN)',
#    'scores': {'duckie': 68, 'SadRick (IGN)': 88}},
#   {'completed_at': '2023-11-12T18:33:06.231-06:00',
#    'winner': 'SadRick (IGN)',
#    'scores': {'duckie': 85, 'SadRick (IGN)': 90}},
#   {'completed_at': '2023-11-12T18:33:06.231-06:00',
#    'winner': 'SadRick (IGN)',
#    'scores': {'duckie': 0, 'SadRick (IGN)': 0}},
#   {'completed_at': '2023-11-19T07:59:42.468-06:00',
#    'winner': 'de Visme',
#    'scores': {'nathanroos': 102, 'de Visme': 99}},
#   {'completed_at': '2023-11-19T07:59:42.468-06:00',
#    'winner': 'de Visme',
#    'scores': {'nathanroos': 90, 'de Visme': 126}},
#   {'completed_at': '2023-11-19T07:59:42.468-06:00',
#    'winner': 'de Visme',
#    'scores': {'nathanroos': 100, 'de Visme': 101}},
#   {'completed_at': '2023-11-20T17:13:43.572-06:00',
#    'winner': 'Irek',
#    'scores': {'Irek': 119, 'GeorgeV89': 96}},
#   {'completed_at': '2023-11-20T17:13:43.572-06:00',
#    'winner': 'Irek',
#    'scores': {'Irek': 117, 'GeorgeV89': 94}},
#   {'completed_at': '2023-11-20T17:13:43.572-06:00',
#    'winner': 'Irek',
#    'scores': {'Irek': 0, 'GeorgeV89': 0}},
#   {'completed_at': '2023-11-23T12:58:50.599-06:00',
#    'winner': 'de Visme',
#    'scores': {'SadRick (IGN)': 109, 'de Visme': 89}},
#   {'completed_at': '2023-11-23T12:58:50.599-06:00',
#    'winner': 'de Visme',
#    'scores': {'SadRick (IGN)': 102, 'de Visme': 106}},
#   {'completed_at': '2023-11-23T12:58:50.599-06:00',
#    'winner': 'de Visme',
#    'scores': {'SadRick (IGN)': 90, 'de Visme': 99}},
#   {'completed_at': '2023-11-26T13:19:34.910-06:00',
#    'winner': 'de Visme',
#    'scores': {'Irek': 84, 'de Visme': 87}},
#   {'completed_at': '2023-11-26T13:19:34.910-06:00',
#    'winner': 'de Visme',
#    'scores': {'Irek': 83, 'de Visme': 84}},
#   {'completed_at': '2023-11-26T13:19:34.910-06:00',
#    'winner': 'de Visme',
#    'scores': {'Irek': 0, 'de Visme': 0}},
#   {'completed_at': '2023-11-14T19:27:46.536-06:00',
#    'winner': 'erikaloveducks',
#    'scores': {'Rampichino': 70, 'erikaloveducks': 71}},
#   {'completed_at': '2023-11-14T19:27:46.536-06:00',
#    'winner': 'erikaloveducks',
#    'scores': {'Rampichino': 76, 'erikaloveducks': 73}},
#   {'completed_at': '2023-11-14T19:27:46.536-06:00',
#    'winner': 'erikaloveducks',
#    'scores': {'Rampichino': 74, 'erikaloveducks': 86}},
#   {'completed_at': '2023-11-14T19:39:30.442-06:00',
#    'winner': 'Embrifox',
#    'scores': {'Embrifox': 88, 'sable_knight': 85}},
#   {'completed_at': '2023-11-14T19:39:30.442-06:00',
#    'winner': 'Embrifox',
#    'scores': {'Embrifox': 76, 'sable_knight': 95}},
#   {'completed_at': '2023-11-14T19:39:30.442-06:00',
#    'winner': 'Embrifox',
#    'scores': {'Embrifox': 79, 'sable_knight': 75}},
#   {'completed_at': '2023-11-14T20:48:43.323-06:00',
#    'winner': 'BeakMajik',
#    'scores': {'BeakMajik': 78, 'AWingandaPrayer': 55}},
#   {'completed_at': '2023-11-14T20:48:43.323-06:00',
#    'winner': 'BeakMajik',
#    'scores': {'BeakMajik': 69, 'AWingandaPrayer': 89}},
#   {'completed_at': '2023-11-14T20:48:43.323-06:00',
#    'winner': 'BeakMajik',
#    'scores': {'BeakMajik': 80, 'AWingandaPrayer': 62}},
#   {'completed_at': '2023-11-19T12:05:49.783-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'jbc999': 90, 'IGN GokuMatos': 108}},
#   {'completed_at': '2023-11-19T12:05:49.783-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'jbc999': 98, 'IGN GokuMatos': 113}},
#   {'completed_at': '2023-11-19T12:05:49.783-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'jbc999': 0, 'IGN GokuMatos': 0}},
#   {'completed_at': '2023-11-16T21:35:42.171-06:00',
#    'winner': 'Embrifox',
#    'scores': {'erikaloveducks': 75, 'Embrifox': 76}},
#   {'completed_at': '2023-11-16T21:35:42.171-06:00',
#    'winner': 'Embrifox',
#    'scores': {'erikaloveducks': 103, 'Embrifox': 98}},
#   {'completed_at': '2023-11-16T21:35:42.171-06:00',
#    'winner': 'Embrifox',
#    'scores': {'erikaloveducks': 67, 'Embrifox': 74}},
#   {'completed_at': '2023-11-21T14:36:42.042-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'BeakMajik': 76, 'IGN GokuMatos': 86}},
#   {'completed_at': '2023-11-21T14:36:42.042-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'BeakMajik': 100, 'IGN GokuMatos': 108}},
#   {'completed_at': '2023-11-21T14:36:42.042-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'BeakMajik': 0, 'IGN GokuMatos': 0}},
#   {'completed_at': '2023-11-24T12:22:41.412-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'Embrifox': 88, 'IGN GokuMatos': 99}},
#   {'completed_at': '2023-11-24T12:22:41.412-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'Embrifox': 86, 'IGN GokuMatos': 99}},
#   {'completed_at': '2023-11-24T12:22:41.412-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'Embrifox': 0, 'IGN GokuMatos': 0}},
#   {'completed_at': '2023-11-16T21:36:09.721-06:00',
#    'winner': 'JuliusDiamond',
#    'scores': {'JuliusDiamond': 90, 'DuchessOfClifton': 80}},
#   {'completed_at': '2023-11-16T21:36:09.721-06:00',
#    'winner': 'JuliusDiamond',
#    'scores': {'JuliusDiamond': 96, 'DuchessOfClifton': 81}},
#   {'completed_at': '2023-11-16T21:36:09.721-06:00',
#    'winner': 'JuliusDiamond',
#    'scores': {'JuliusDiamond': 0, 'DuchessOfClifton': 0}},
#   {'completed_at': '2023-11-19T20:13:09.897-06:00',
#    'winner': 'Mortal_Wings',
#    'scores': {'IV1738': 80, 'Mortal_Wings': 78}},
#   {'completed_at': '2023-11-19T20:13:09.897-06:00',
#    'winner': 'Mortal_Wings',
#    'scores': {'IV1738': 72, 'Mortal_Wings': 98}},
#   {'completed_at': '2023-11-19T20:13:09.897-06:00',
#    'winner': 'Mortal_Wings',
#    'scores': {'IV1738': 96, 'Mortal_Wings': 118}},
#   {'completed_at': '2023-11-13T07:26:27.845-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'slejo': 80, 'Arceusisgood': 100}},
#   {'completed_at': '2023-11-13T07:26:27.845-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'slejo': 76, 'Arceusisgood': 113}},
#   {'completed_at': '2023-11-13T07:26:27.845-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'slejo': 0, 'Arceusisgood': 0}},
#   {'completed_at': '2023-11-14T19:20:11.074-06:00',
#    'winner': 'TheGreenClarinet',
#    'scores': {'Taykay (ign toznom)': 67, 'TheGreenClarinet': 94}},
#   {'completed_at': '2023-11-14T19:20:11.074-06:00',
#    'winner': 'TheGreenClarinet',
#    'scores': {'Taykay (ign toznom)': 85, 'TheGreenClarinet': 94}},
#   {'completed_at': '2023-11-14T19:20:11.074-06:00',
#    'winner': 'TheGreenClarinet',
#    'scores': {'Taykay (ign toznom)': 0, 'TheGreenClarinet': 0}},
#   {'completed_at': '2023-11-21T15:14:43.335-06:00',
#    'winner': 'JuliusDiamond',
#    'scores': {'JuliusDiamond': 86, 'Mortal_Wings': 81}},
#   {'completed_at': '2023-11-21T15:14:43.335-06:00',
#    'winner': 'JuliusDiamond',
#    'scores': {'JuliusDiamond': 116, 'Mortal_Wings': 94}},
#   {'completed_at': '2023-11-21T15:14:43.335-06:00',
#    'winner': 'JuliusDiamond',
#    'scores': {'JuliusDiamond': 0, 'Mortal_Wings': 0}},
#   {'completed_at': '2023-11-18T21:43:41.280-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'Arceusisgood': 104, 'TheGreenClarinet': 93}},
#   {'completed_at': '2023-11-18T21:43:41.280-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'Arceusisgood': 111, 'TheGreenClarinet': 90}},
#   {'completed_at': '2023-11-18T21:43:41.280-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'Arceusisgood': 0, 'TheGreenClarinet': 0}},
#   {'completed_at': '2023-11-25T18:06:27.516-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'JuliusDiamond': 98, 'Arceusisgood': 95}},
#   {'completed_at': '2023-11-25T18:06:27.516-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'JuliusDiamond': 76, 'Arceusisgood': 84}},
#   {'completed_at': '2023-11-25T18:06:27.516-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'JuliusDiamond': 91, 'Arceusisgood': 99}},
#   {'completed_at': '2023-11-18T06:18:03.751-06:00',
#    'winner': 'mrtriggerhandz',
#    'scores': {'Bargoff': 87, 'mrtriggerhandz': 88}},
#   {'completed_at': '2023-11-18T06:18:03.751-06:00',
#    'winner': 'mrtriggerhandz',
#    'scores': {'Bargoff': 77, 'mrtriggerhandz': 89}},
#   {'completed_at': '2023-11-18T06:18:03.751-06:00',
#    'winner': 'mrtriggerhandz',
#    'scores': {'Bargoff': 0, 'mrtriggerhandz': 0}},
#   {'completed_at': '2023-11-16T04:58:20.362-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'HawkLake': 109, 'FractalChess2': 122}},
#   {'completed_at': '2023-11-16T04:58:20.362-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'HawkLake': 109, 'FractalChess2': 125}},
#   {'completed_at': '2023-11-16T04:58:20.362-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'HawkLake': 0, 'FractalChess2': 0}},
#   {'completed_at': '2023-11-12T18:35:46.236-06:00',
#    'winner': 'MichaelTheGrackle',
#    'scores': {'MichaelTheGrackle': 94, 'corvogordo': 66}},
#   {'completed_at': '2023-11-12T18:35:46.236-06:00',
#    'winner': 'MichaelTheGrackle',
#    'scores': {'MichaelTheGrackle': 103, 'corvogordo': 86}},
#   {'completed_at': '2023-11-12T18:35:46.236-06:00',
#    'winner': 'MichaelTheGrackle',
#    'scores': {'MichaelTheGrackle': 0, 'corvogordo': 0}},
#   {'completed_at': '2023-11-18T15:50:19.035-06:00',
#    'winner': 'mike316',
#    'scores': {'Ineslopes98': 84, 'mike316': 100}},
#   {'completed_at': '2023-11-18T15:50:19.035-06:00',
#    'winner': 'mike316',
#    'scores': {'Ineslopes98': 73, 'mike316': 99}},
#   {'completed_at': '2023-11-18T15:50:19.035-06:00',
#    'winner': 'mike316',
#    'scores': {'Ineslopes98': 0, 'mike316': 0}},
#   {'completed_at': '2023-11-19T20:10:07.350-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'mrtriggerhandz': 83, 'FractalChess2': 100}},
#   {'completed_at': '2023-11-19T20:10:07.350-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'mrtriggerhandz': 97, 'FractalChess2': 122}},
#   {'completed_at': '2023-11-19T20:10:07.350-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'mrtriggerhandz': 0, 'FractalChess2': 0}},
#   {'completed_at': '2023-11-19T08:02:13.821-06:00',
#    'winner': 'mike316',
#    'scores': {'MichaelTheGrackle': 97, 'mike316': 83}},
#   {'completed_at': '2023-11-19T08:02:13.821-06:00',
#    'winner': 'mike316',
#    'scores': {'MichaelTheGrackle': 78, 'mike316': 93}},
#   {'completed_at': '2023-11-19T08:02:13.821-06:00',
#    'winner': 'mike316',
#    'scores': {'MichaelTheGrackle': 88, 'mike316': 93}},
#   {'completed_at': '2023-11-26T09:24:33.070-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'FractalChess2': 91, 'mike316': 81}},
#   {'completed_at': '2023-11-26T09:24:33.070-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'FractalChess2': 89, 'mike316': 100}},
#   {'completed_at': '2023-11-26T09:24:33.070-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'FractalChess2': 111, 'mike316': 84}},
#   {'completed_at': '2023-11-12T21:54:44.369-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 73, 'bigben1248 (Dashua)': 74}},
#   {'completed_at': '2023-11-12T21:54:44.369-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 107, 'bigben1248 (Dashua)': 89}},
#   {'completed_at': '2023-11-12T21:54:44.369-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 98, 'bigben1248 (Dashua)': 96}},
#   {'completed_at': '2023-11-12T12:43:00.440-06:00',
#    'winner': 'goldfinchy',
#    'scores': {'ramtek': 77, 'Goldfinchy': 95}},
#   {'completed_at': '2023-11-12T12:43:00.440-06:00',
#    'winner': 'goldfinchy',
#    'scores': {'ramtek': 96, 'Goldfinchy': 104}},
#   {'completed_at': '2023-11-12T12:43:00.440-06:00',
#    'winner': 'goldfinchy',
#    'scores': {'ramtek': 0, 'Goldfinchy': 0}},
#   {'completed_at': '2023-11-19T20:15:36.050-06:00',
#    'winner': 'StyloPlume',
#    'scores': {'StyloPlume': 93, 'iwinatlife42': 101}},
#   {'completed_at': '2023-11-19T20:15:36.050-06:00',
#    'winner': 'StyloPlume',
#    'scores': {'StyloPlume': 1, 'iwinatlife42': 0}},
#   {'completed_at': '2023-11-19T20:15:36.050-06:00',
#    'winner': 'StyloPlume',
#    'scores': {'StyloPlume': 1, 'iwinatlife42': 0}},
#   {'completed_at': '2023-11-18T14:48:27.406-06:00',
#    'winner': 'Salmonskinroll12',
#    'scores': {'Salmonskinroll12': 97, 'Lowfat': 89}},
#   {'completed_at': '2023-11-18T14:48:27.406-06:00',
#    'winner': 'Salmonskinroll12',
#    'scores': {'Salmonskinroll12': 129, 'Lowfat': 115}},
#   {'completed_at': '2023-11-18T14:48:27.406-06:00',
#    'winner': 'Salmonskinroll12',
#    'scores': {'Salmonskinroll12': 0, 'Lowfat': 0}},
#   {'completed_at': '2023-11-13T17:55:16.648-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 121, 'Goldfinchy': 97}},
#   {'completed_at': '2023-11-13T17:55:16.648-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 103, 'Goldfinchy': 77}},
#   {'completed_at': '2023-11-13T17:55:16.648-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 0, 'Goldfinchy': 0}},
#   {'completed_at': '2023-11-22T12:34:27.791-06:00',
#    'winner': 'Salmonskinroll12',
#    'scores': {'StyloPlume': 87, 'Salmonskinroll12': 102}},
#   {'completed_at': '2023-11-22T12:34:27.791-06:00',
#    'winner': 'Salmonskinroll12',
#    'scores': {'StyloPlume': 83, 'Salmonskinroll12': 98}},
#   {'completed_at': '2023-11-22T12:34:27.791-06:00',
#    'winner': 'Salmonskinroll12',
#    'scores': {'StyloPlume': 0, 'Salmonskinroll12': 0}},
#   {'completed_at': '2023-11-25T18:07:48.873-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 98, 'Salmonskinroll12': 79}},
#   {'completed_at': '2023-11-25T18:07:48.873-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 103, 'Salmonskinroll12': 79}},
#   {'completed_at': '2023-11-25T18:07:48.873-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 0, 'Salmonskinroll12': 0}},
#   {'completed_at': '2023-11-14T19:37:46.588-06:00',
#    'winner': 'Beammeup (elekTrick)',
#    'scores': {'Theflash04': 109, 'Beammeup (elekTrick)': 124}},
#   {'completed_at': '2023-11-14T19:37:46.588-06:00',
#    'winner': 'Beammeup (elekTrick)',
#    'scores': {'Theflash04': 101, 'Beammeup (elekTrick)': 132}},
#   {'completed_at': '2023-11-14T19:37:46.588-06:00',
#    'winner': 'Beammeup (elekTrick)',
#    'scores': {'Theflash04': 0, 'Beammeup (elekTrick)': 0}},
#   {'completed_at': '2023-11-16T17:09:57.602-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'ravenousanna': 96, 'ZoopZoop': 98}},
#   {'completed_at': '2023-11-16T17:09:57.602-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'ravenousanna': 84, 'ZoopZoop': 108}},
#   {'completed_at': '2023-11-16T17:09:57.602-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'ravenousanna': 0, 'ZoopZoop': 0}},
#   {'completed_at': '2023-11-12T21:56:56.654-06:00',
#    'winner': 'Rube23',
#    'scores': {'Cuppa': 70, 'Rube23': 86}},
#   {'completed_at': '2023-11-12T21:56:56.654-06:00',
#    'winner': 'Rube23',
#    'scores': {'Cuppa': 82, 'Rube23': 77}},
#   {'completed_at': '2023-11-12T21:56:56.654-06:00',
#    'winner': 'Rube23',
#    'scores': {'Cuppa': 72, 'Rube23': 82}},
#   {'completed_at': '2023-11-14T21:35:29.087-06:00',
#    'winner': 'Groovenstein',
#    'scores': {'Groovenstein': 104, 'Crowvid99': 92}},
#   {'completed_at': '2023-11-14T21:35:29.087-06:00',
#    'winner': 'Groovenstein',
#    'scores': {'Groovenstein': 106, 'Crowvid99': 98}},
#   {'completed_at': '2023-11-14T21:35:29.087-06:00',
#    'winner': 'Groovenstein',
#    'scores': {'Groovenstein': 0, 'Crowvid99': 0}},
#   {'completed_at': '2023-11-17T22:13:59.918-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'Beammeup (elekTrick)': 89, 'ZoopZoop': 96}},
#   {'completed_at': '2023-11-17T22:13:59.918-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'Beammeup (elekTrick)': 85, 'ZoopZoop': 104}},
#   {'completed_at': '2023-11-17T22:13:59.918-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'Beammeup (elekTrick)': 0, 'ZoopZoop': 0}},
#   {'completed_at': '2023-11-16T04:58:29.471-06:00',
#    'winner': 'Groovenstein',
#    'scores': {'Rube23': 99, 'Groovenstein': 115}},
#   {'completed_at': '2023-11-16T04:58:29.471-06:00',
#    'winner': 'Groovenstein',
#    'scores': {'Rube23': 92, 'Groovenstein': 85}},
#   {'completed_at': '2023-11-16T04:58:29.471-06:00',
#    'winner': 'Groovenstein',
#    'scores': {'Rube23': 93, 'Groovenstein': 106}},
#   {'completed_at': '2023-11-19T20:06:13.133-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'ZoopZoop': 92, 'Groovenstein': 85}},
#   {'completed_at': '2023-11-19T20:06:13.133-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'ZoopZoop': 92, 'Groovenstein': 88}},
#   {'completed_at': '2023-11-19T20:06:13.133-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'ZoopZoop': 0, 'Groovenstein': 0}},
#   {'completed_at': '2023-11-18T14:54:11.978-06:00',
#    'winner': 'otsukuuyan',
#    'scores': {'Copewithit': 95, 'otsukuuyan': 89}},
#   {'completed_at': '2023-11-18T14:54:11.978-06:00',
#    'winner': 'otsukuuyan',
#    'scores': {'Copewithit': 88, 'otsukuuyan': 106}},
#   {'completed_at': '2023-11-18T14:54:11.978-06:00',
#    'winner': 'otsukuuyan',
#    'scores': {'Copewithit': 76, 'otsukuuyan': 110}},
#   {'completed_at': '2023-11-16T04:56:04.854-06:00',
#    'winner': 'MonkeyWren',
#    'scores': {'MonkeyWren': 85, 'Stormchaser': 89}},
#   {'completed_at': '2023-11-16T04:56:04.854-06:00',
#    'winner': 'MonkeyWren',
#    'scores': {'MonkeyWren': 108, 'Stormchaser': 85}},
#   {'completed_at': '2023-11-16T04:56:04.854-06:00',
#    'winner': 'MonkeyWren',
#    'scores': {'MonkeyWren': 101, 'Stormchaser': 80}},
#   {'completed_at': '2023-11-18T21:43:09.518-06:00',
#    'winner': 'kopdog',
#    'scores': {'Herc': 115, 'Kopdog': 124}},
#   {'completed_at': '2023-11-18T21:43:09.518-06:00',
#    'winner': 'kopdog',
#    'scores': {'Herc': 112, 'Kopdog': 108}},
#   {'completed_at': '2023-11-18T21:43:09.518-06:00',
#    'winner': 'kopdog',
#    'scores': {'Herc': 84, 'Kopdog': 103}},
#   {'completed_at': '2023-11-16T17:04:47.342-06:00',
#    'winner': 'dilfina',
#    'scores': {'dilfina': 115, 'Daniel Naumovas (Daniel)': 91}},
#   {'completed_at': '2023-11-16T17:04:47.342-06:00',
#    'winner': 'dilfina',
#    'scores': {'dilfina': 105, 'Daniel Naumovas (Daniel)': 99}},
#   {'completed_at': '2023-11-16T17:04:47.342-06:00',
#    'winner': 'dilfina',
#    'scores': {'dilfina': 0, 'Daniel Naumovas (Daniel)': 0}},
#   {'completed_at': '2023-11-26T20:33:06.151-06:00',
#    'winner': 'MonkeyWren',
#    'scores': {'otsukuuyan': 82, 'MonkeyWren': 84}},
#   {'completed_at': '2023-11-26T20:33:06.151-06:00',
#    'winner': 'MonkeyWren',
#    'scores': {'otsukuuyan': 82, 'MonkeyWren': 91}},
#   {'completed_at': '2023-11-26T20:33:06.151-06:00',
#    'winner': 'MonkeyWren',
#    'scores': {'otsukuuyan': 0, 'MonkeyWren': 0}},
#   {'completed_at': '2023-11-21T14:32:46.441-06:00',
#    'winner': 'dilfina',
#    'scores': {'Kopdog': 82, 'dilfina': 95}},
#   {'completed_at': '2023-11-21T14:32:46.441-06:00',
#    'winner': 'dilfina',
#    'scores': {'Kopdog': 105, 'dilfina': 82}},
#   {'completed_at': '2023-11-21T14:32:46.441-06:00',
#    'winner': 'dilfina',
#    'scores': {'Kopdog': 86, 'dilfina': 91}},
#   {'completed_at': '2023-11-19T07:57:19.857-06:00',
#    'winner': 'ethmah',
#    'scores': {'thebestdaysofmyflerm': 82, 'ethmah': 106}},
#   {'completed_at': '2023-11-19T07:57:19.857-06:00',
#    'winner': 'ethmah',
#    'scores': {'thebestdaysofmyflerm': 100, 'ethmah': 102}},
#   {'completed_at': '2023-11-19T07:57:19.857-06:00',
#    'winner': 'ethmah',
#    'scores': {'thebestdaysofmyflerm': 0, 'ethmah': 0}},
#   {'completed_at': '2023-11-19T08:01:35.290-06:00',
#    'winner': 'queenfisher1',
#    'scores': {'queenfisher1': 80, 'Vrwizkid': 69}},
#   {'completed_at': '2023-11-19T08:01:35.290-06:00',
#    'winner': 'queenfisher1',
#    'scores': {'queenfisher1': 99, 'Vrwizkid': 88}},
#   {'completed_at': '2023-11-19T08:01:35.290-06:00',
#    'winner': 'queenfisher1',
#    'scores': {'queenfisher1': 0, 'Vrwizkid': 0}},
#   {'completed_at': '2023-11-12T18:35:49.260-06:00',
#    'winner': 'MTRooster',
#    'scores': {'MTRooster': 87, 'WhatDatFrogmoufDo': 76}},
#   {'completed_at': '2023-11-12T18:35:49.260-06:00',
#    'winner': 'MTRooster',
#    'scores': {'MTRooster': 95, 'WhatDatFrogmoufDo': 88}},
#   {'completed_at': '2023-11-12T18:35:49.260-06:00',
#    'winner': 'MTRooster',
#    'scores': {'MTRooster': 0, 'WhatDatFrogmoufDo': 0}},
#   {'completed_at': '2023-11-17T14:36:42.088-06:00',
#    'winner': 'ZobiWanKenobi',
#    'scores': {'alexandrawuhu': 84, 'ZobiWanKenobi': 101}},
#   {'completed_at': '2023-11-17T14:36:42.088-06:00',
#    'winner': 'ZobiWanKenobi',
#    'scores': {'alexandrawuhu': 87, 'ZobiWanKenobi': 85}},
#   {'completed_at': '2023-11-17T14:36:42.088-06:00',
#    'winner': 'ZobiWanKenobi',
#    'scores': {'alexandrawuhu': 81, 'ZobiWanKenobi': 101}},
#   {'completed_at': '2023-11-22T06:08:46.305-06:00',
#    'winner': 'queenfisher1',
#    'scores': {'ethmah': 90, 'queenfisher1': 79}},
#   {'completed_at': '2023-11-22T06:08:46.305-06:00',
#    'winner': 'queenfisher1',
#    'scores': {'ethmah': 77, 'queenfisher1': 103}},
#   {'completed_at': '2023-11-22T06:08:46.305-06:00',
#    'winner': 'queenfisher1',
#    'scores': {'ethmah': 67, 'queenfisher1': 95}},
#   {'completed_at': '2023-11-19T07:59:05.180-06:00',
#    'winner': 'ZobiWanKenobi',
#    'scores': {'MTRooster': 82, 'ZobiWanKenobi': 80}},
#   {'completed_at': '2023-11-19T07:59:05.180-06:00',
#    'winner': 'ZobiWanKenobi',
#    'scores': {'MTRooster': 80, 'ZobiWanKenobi': 96}},
#   {'completed_at': '2023-11-19T07:59:05.180-06:00',
#    'winner': 'ZobiWanKenobi',
#    'scores': {'MTRooster': 87, 'ZobiWanKenobi': 103}},
#   {'completed_at': '2023-11-14T19:25:57.679-06:00',
#    'winner': 'ronster',
#    'scores': {'Ronster7': 94, 'Kestrelly': 69}},
#   {'completed_at': '2023-11-14T19:25:57.679-06:00',
#    'winner': 'ronster',
#    'scores': {'Ronster7': 105, 'Kestrelly': 92}},
#   {'completed_at': '2023-11-14T19:25:57.679-06:00',
#    'winner': 'ronster',
#    'scores': {'Ronster7': 0, 'Kestrelly': 0}},
#   {'completed_at': '2023-11-12T18:36:03.005-06:00',
#    'winner': 'clloud8',
#    'scores': {'Clloud8': 82, 'ElSapoGuapo': 77}},
#   {'completed_at': '2023-11-12T18:36:03.005-06:00',
#    'winner': 'clloud8',
#    'scores': {'Clloud8': 94, 'ElSapoGuapo': 98}},
#   {'completed_at': '2023-11-12T18:36:03.005-06:00',
#    'winner': 'clloud8',
#    'scores': {'Clloud8': 97, 'ElSapoGuapo': 87}},
#   {'completed_at': '2023-11-13T16:36:11.411-06:00',
#    'winner': 'ooievaar',
#    'scores': {'KingPleb': 88, 'ooievaar': 89}},
#   {'completed_at': '2023-11-13T16:36:11.411-06:00',
#    'winner': 'ooievaar',
#    'scores': {'KingPleb': 72, 'ooievaar': 87}},
#   {'completed_at': '2023-11-13T16:36:11.411-06:00',
#    'winner': 'ooievaar',
#    'scores': {'KingPleb': 0, 'ooievaar': 0}},
#   {'completed_at': '2023-11-16T17:06:42.940-06:00',
#    'winner': 'ronster',
#    'scores': {'blind squirrel (fnjphone)': 98, 'Ronster7': 113}},
#   {'completed_at': '2023-11-16T17:06:42.940-06:00',
#    'winner': 'ronster',
#    'scores': {'blind squirrel (fnjphone)': 102, 'Ronster7': 119}},
#   {'completed_at': '2023-11-16T17:06:42.940-06:00',
#    'winner': 'ronster',
#    'scores': {'blind squirrel (fnjphone)': 0, 'Ronster7': 0}},
#   {'completed_at': '2023-11-14T19:32:20.910-06:00',
#    'winner': 'ooievaar',
#    'scores': {'Clloud8': 72, 'ooievaar': 77}},
#   {'completed_at': '2023-11-14T19:32:20.910-06:00',
#    'winner': 'ooievaar',
#    'scores': {'Clloud8': 87, 'ooievaar': 91}},
#   {'completed_at': '2023-11-14T19:32:20.910-06:00',
#    'winner': 'ooievaar',
#    'scores': {'Clloud8': 0, 'ooievaar': 0}},
#   {'completed_at': '2023-11-22T12:33:40.504-06:00',
#    'winner': 'ooievaar',
#    'scores': {'Ronster7': 92, 'ooievaar': 110}},
#   {'completed_at': '2023-11-22T12:33:40.504-06:00',
#    'winner': 'ooievaar',
#    'scores': {'Ronster7': 103, 'ooievaar': 83}},
#   {'completed_at': '2023-11-22T12:33:40.504-06:00',
#    'winner': 'ooievaar',
#    'scores': {'Ronster7': 98, 'ooievaar': 100}}]}

# %% [markdown]
# # Remove tournaments that are not 2-player Wingspan

# %%
normalized_tourneys = [t for t in normalized_tourneys if 'Joint Jabiru Joust' not in t['name']
               and 'Tournament Discord Server Image Bird' not in t['name']
              and 'Toco Toucan Triple Team Tournament' not in t['name']
             and 'Birds of a Feather' not in t['name']
            and 'Diamond Firetail Foursomes' not in t['name']
            and len(t['games'])]

# %%
for t in normalized_tourneys:
    t['games'] = [g for g in t['games'] if min(g['scores'].values()) > 0]

# %% [markdown]
# # Save to JSON

# %%
with open('wingspan_tournaments.json', 'w') as f:
    json.dump(normalized_tourneys, f, indent=2)

# %% [markdown]
# # Fix more names

# %%
with open('wingspan_tournaments.json', 'r') as f:
    normalized_tourneys = json.load(f)

# %%
extra_substitutions = {
    'FlanSwitch': 'Flan',
    'Birdwatchermobile': 'Birdwatcher123',
    'Mliguori16 (Birdwatcher123)': 'Birdwatcher123',
    'Cap': 'Capitalist111#3362 (Cap)',
    'HAyAsIiI (slowPigeon)': 'slowPigeon',
    'Jjlig2mobile2': 'Jjlig2',
    'No~M l IGN: danaran': 'No~M (danaran)',
    'Rafa oakie (oakie)': 'Rafa (oakie)',
    'Shiny (ShinyEmmy)': 'ShinyEmmy',
    'Typhus / rnicolas (Typhus)': 'Typhus',
    'Wingsplain': 'Wingsplain Gaming (ShadowFox)',
    "oakie6439\t(oakie)": 'oakie',
    "nsegal14 (SegalLikeTheBird)": "SegalLikeTheBird",
    "e8v2000 (ScaredofBirds)": "ScaredofBirds",
    "eefdeaardappel (ooievaar) - The Netherlands": "ooievaar",
    "ooievaar🇳🇱 (ign moustache)": "ooievaar",
    "Johnlim": "Jlim (Johnlim)",
    "HaveAGoodOne": "Kip (ign: HaveAGoodOne)",
    "cedarwax": "maggie (cedarwax)",
    "mellymelyay": "mcdo0530 (mellymelyay)",
    "nardybux (MonkeyWren)": "MonkeyWren",
    "ScottCS (MortalWings)": "MortalWings",
    "Trung (Stalledbird)": "Stalledbird"
}

for t in normalized_tourneys:
    for g in t['games']:
        to_substitute = [user for user in g['scores'].keys() if user in extra_substitutions]
        for user in to_substitute:
            score = g['scores'][user]
            del g['scores'][user]
            g['scores'][extra_substitutions[user]] = score
                
with open('wingspan_tournaments.json', 'w') as f:
    json.dump(normalized_tourneys, f, indent=2)

# %%
normalized_tourneys[1]
# Out:
# {'id': 13718089,
#  'name': 'Xenopsaris X-Factor',
#  'url': 'https://challonge.com/wtds_xx',
#  'date': None,
#  'games': [{'completed_at': '2023-11-17T22:15:51.338-06:00',
#    'winner': 'ChopYouUp',
#    'scores': {'lemon': 70, 'ChopYouUp': 133}},
#   {'completed_at': '2023-11-17T22:15:51.338-06:00',
#    'winner': 'ChopYouUp',
#    'scores': {'lemon': 81, 'ChopYouUp': 114}},
#   {'completed_at': '2023-11-18T10:23:09.923-06:00',
#    'winner': 'noravens',
#    'scores': {'Orcinus': 105, 'noravens': 107}},
#   {'completed_at': '2023-11-18T10:23:09.923-06:00',
#    'winner': 'noravens',
#    'scores': {'Orcinus': 81, 'noravens': 103}},
#   {'completed_at': '2023-11-17T10:35:14.124-06:00',
#    'winner': 'gtrudat',
#    'scores': {'smelly_cat': 99, 'gtrudat': 82}},
#   {'completed_at': '2023-11-17T10:35:14.124-06:00',
#    'winner': 'gtrudat',
#    'scores': {'smelly_cat': 92, 'gtrudat': 94}},
#   {'completed_at': '2023-11-17T10:35:14.124-06:00',
#    'winner': 'gtrudat',
#    'scores': {'smelly_cat': 108, 'gtrudat': 119}},
#   {'completed_at': '2023-11-14T19:20:19.853-06:00',
#    'winner': 'gaussiancurve',
#    'scores': {'gaussiancurve': 102, 'spocpes': 75}},
#   {'completed_at': '2023-11-14T19:20:19.853-06:00',
#    'winner': 'gaussiancurve',
#    'scores': {'gaussiancurve': 103, 'spocpes': 71}},
#   {'completed_at': '2023-11-26T08:25:01.855-06:00',
#    'winner': 'noravens',
#    'scores': {'ChopYouUp': 91, 'noravens': 95}},
#   {'completed_at': '2023-11-26T08:25:01.855-06:00',
#    'winner': 'noravens',
#    'scores': {'ChopYouUp': 91, 'noravens': 87}},
#   {'completed_at': '2023-11-26T08:25:01.855-06:00',
#    'winner': 'noravens',
#    'scores': {'ChopYouUp': 93, 'noravens': 115}},
#   {'completed_at': '2023-11-19T09:15:41.105-06:00',
#    'winner': 'gaussiancurve',
#    'scores': {'gtrudat': 90, 'gaussiancurve': 91}},
#   {'completed_at': '2023-11-19T09:15:41.105-06:00',
#    'winner': 'gaussiancurve',
#    'scores': {'gtrudat': 74, 'gaussiancurve': 75}},
#   {'completed_at': '2023-11-16T17:03:50.923-06:00',
#    'winner': 'AmithA',
#    'scores': {'Nico1968': 79, 'AmithA': 83}},
#   {'completed_at': '2023-11-16T17:03:50.923-06:00',
#    'winner': 'AmithA',
#    'scores': {'Nico1968': 61, 'AmithA': 94}},
#   {'completed_at': '2023-11-18T14:50:01.440-06:00',
#    'winner': 'stalledbird',
#    'scores': {'Stalledbird': 90, 'Palindrome': 83}},
#   {'completed_at': '2023-11-18T14:50:01.440-06:00',
#    'winner': 'stalledbird',
#    'scores': {'Stalledbird': 81, 'Palindrome': 93}},
#   {'completed_at': '2023-11-18T14:50:01.440-06:00',
#    'winner': 'stalledbird',
#    'scores': {'Stalledbird': 71, 'Palindrome': 68}},
#   {'completed_at': '2023-11-13T17:56:26.734-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'ScaredofBirds': 109, 'DMonkey225': 54}},
#   {'completed_at': '2023-11-13T17:56:26.734-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'ScaredofBirds': 83, 'DMonkey225': 56}},
#   {'completed_at': '2023-11-13T16:38:11.593-06:00',
#    'winner': 'Huxley3000',
#    'scores': {'GraDog22': 96, 'Huxley3000': 84}},
#   {'completed_at': '2023-11-13T16:38:11.593-06:00',
#    'winner': 'Huxley3000',
#    'scores': {'GraDog22': 86, 'Huxley3000': 102}},
#   {'completed_at': '2023-11-13T16:38:11.593-06:00',
#    'winner': 'Huxley3000',
#    'scores': {'GraDog22': 101, 'Huxley3000': 113}},
#   {'completed_at': '2023-11-21T04:59:38.017-06:00',
#    'winner': 'stalledbird',
#    'scores': {'AmithA': 76, 'Stalledbird': 77}},
#   {'completed_at': '2023-11-21T04:59:38.017-06:00',
#    'winner': 'stalledbird',
#    'scores': {'AmithA': 91, 'Stalledbird': 107}},
#   {'completed_at': '2023-11-17T10:37:23.973-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'ScaredofBirds': 98, 'Huxley3000': 83}},
#   {'completed_at': '2023-11-17T10:37:23.973-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'ScaredofBirds': 111, 'Huxley3000': 91}},
#   {'completed_at': '2023-11-26T21:36:54.634-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'Stalledbird': 85, 'ScaredofBirds': 107}},
#   {'completed_at': '2023-11-26T21:36:54.634-06:00',
#    'winner': 'ScaredofBirds',
#    'scores': {'Stalledbird': 107, 'ScaredofBirds': 118}},
#   {'completed_at': '2023-11-18T14:54:27.578-06:00',
#    'winner': 'travs',
#    'scores': {'travs': 93, 'Tiny Geese': 83}},
#   {'completed_at': '2023-11-18T14:54:27.578-06:00',
#    'winner': 'travs',
#    'scores': {'travs': 82, 'Tiny Geese': 98}},
#   {'completed_at': '2023-11-18T14:54:27.578-06:00',
#    'winner': 'travs',
#    'scores': {'travs': 88, 'Tiny Geese': 79}},
#   {'completed_at': '2023-11-16T05:10:26.849-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'Merisabear': 87, 'BlackSpice28': 108}},
#   {'completed_at': '2023-11-16T05:10:26.849-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'Merisabear': 75, 'BlackSpice28': 93}},
#   {'completed_at': '2023-11-16T21:35:07.490-06:00',
#    'winner': 'WeirdOwl',
#    'scores': {'z12monkeys': 83, 'Weirdowl': 78}},
#   {'completed_at': '2023-11-16T21:35:07.490-06:00',
#    'winner': 'WeirdOwl',
#    'scores': {'z12monkeys': 88, 'Weirdowl': 97}},
#   {'completed_at': '2023-11-16T21:35:07.490-06:00',
#    'winner': 'WeirdOwl',
#    'scores': {'z12monkeys': 84, 'Weirdowl': 85}},
#   {'completed_at': '2023-11-13T14:29:45.597-06:00',
#    'winner': 'WillyPizza',
#    'scores': {'Foxjoke': 117, 'WillyPizza': 92}},
#   {'completed_at': '2023-11-13T14:29:45.597-06:00',
#    'winner': 'WillyPizza',
#    'scores': {'Foxjoke': 88, 'WillyPizza': 113}},
#   {'completed_at': '2023-11-13T14:29:45.597-06:00',
#    'winner': 'WillyPizza',
#    'scores': {'Foxjoke': 108, 'WillyPizza': 122}},
#   {'completed_at': '2023-11-21T05:00:34.838-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'travs': 85, 'BlackSpice28': 108}},
#   {'completed_at': '2023-11-21T05:00:34.838-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'travs': 103, 'BlackSpice28': 129}},
#   {'completed_at': '2023-11-17T10:35:58.323-06:00',
#    'winner': 'WeirdOwl',
#    'scores': {'Weirdowl': 97, 'WillyPizza': 96}},
#   {'completed_at': '2023-11-17T10:35:58.323-06:00',
#    'winner': 'WeirdOwl',
#    'scores': {'Weirdowl': 94, 'WillyPizza': 90}},
#   {'completed_at': '2023-11-21T14:28:02.040-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'BlackSpice28': 80, 'Weirdowl': 76}},
#   {'completed_at': '2023-11-21T14:28:02.040-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'BlackSpice28': 84, 'Weirdowl': 91}},
#   {'completed_at': '2023-11-21T14:28:02.040-06:00',
#    'winner': 'BlackSpice28',
#    'scores': {'BlackSpice28': 107, 'Weirdowl': 82}},
#   {'completed_at': '2023-11-13T14:32:36.923-06:00',
#    'winner': 'Shepherd0',
#    'scores': {'Shepherd0': 104, 'SegalLikeTheBird': 100}},
#   {'completed_at': '2023-11-13T14:32:36.923-06:00',
#    'winner': 'Shepherd0',
#    'scores': {'Shepherd0': 95, 'SegalLikeTheBird': 101}},
#   {'completed_at': '2023-11-13T14:32:36.923-06:00',
#    'winner': 'Shepherd0',
#    'scores': {'Shepherd0': 101, 'SegalLikeTheBird': 96}},
#   {'completed_at': '2023-11-16T05:10:24.669-06:00',
#    'winner': 'cgjunior',
#    'scores': {'MrSaber': 80, 'cgjunior': 87}},
#   {'completed_at': '2023-11-16T05:10:24.669-06:00',
#    'winner': 'cgjunior',
#    'scores': {'MrSaber': 101, 'cgjunior': 98}},
#   {'completed_at': '2023-11-16T05:10:24.669-06:00',
#    'winner': 'cgjunior',
#    'scores': {'MrSaber': 95, 'cgjunior': 105}},
#   {'completed_at': '2023-11-16T08:41:30.352-06:00',
#    'winner': 'Maskonur',
#    'scores': {'_aquanaut': 99, 'Maskonur': 90}},
#   {'completed_at': '2023-11-16T08:41:30.352-06:00',
#    'winner': 'Maskonur',
#    'scores': {'_aquanaut': 71, 'Maskonur': 97}},
#   {'completed_at': '2023-11-16T08:41:30.352-06:00',
#    'winner': 'Maskonur',
#    'scores': {'_aquanaut': 72, 'Maskonur': 93}},
#   {'completed_at': '2023-11-18T14:45:06.627-06:00',
#    'winner': 'Jjlig2mobile2',
#    'scores': {'thehoneyeater87': 76, 'Jjlig2': 87}},
#   {'completed_at': '2023-11-18T14:45:06.627-06:00',
#    'winner': 'Jjlig2mobile2',
#    'scores': {'thehoneyeater87': 122, 'Jjlig2': 132}},
#   {'completed_at': '2023-11-19T07:59:02.089-06:00',
#    'winner': 'Shepherd0',
#    'scores': {'Shepherd0': 111, 'cgjunior': 74}},
#   {'completed_at': '2023-11-19T07:59:02.089-06:00',
#    'winner': 'Shepherd0',
#    'scores': {'Shepherd0': 106, 'cgjunior': 85}},
#   {'completed_at': '2023-11-19T20:10:19.301-06:00',
#    'winner': 'Maskonur',
#    'scores': {'Maskonur': 91, 'Jjlig2': 83}},
#   {'completed_at': '2023-11-19T20:10:19.301-06:00',
#    'winner': 'Maskonur',
#    'scores': {'Maskonur': 90, 'Jjlig2': 89}},
#   {'completed_at': '2023-11-22T06:04:35.218-06:00',
#    'winner': 'Maskonur',
#    'scores': {'Shepherd0': 97, 'Maskonur': 96}},
#   {'completed_at': '2023-11-22T06:04:35.218-06:00',
#    'winner': 'Maskonur',
#    'scores': {'Shepherd0': 87, 'Maskonur': 90}},
#   {'completed_at': '2023-11-22T06:04:35.218-06:00',
#    'winner': 'Maskonur',
#    'scores': {'Shepherd0': 98, 'Maskonur': 115}},
#   {'completed_at': '2023-11-16T04:31:32.052-06:00',
#    'winner': 'Sim17',
#    'scores': {'Sim17': 94, 'bushNIT': 80}},
#   {'completed_at': '2023-11-16T04:31:32.052-06:00',
#    'winner': 'Sim17',
#    'scores': {'Sim17': 104, 'bushNIT': 106}},
#   {'completed_at': '2023-11-16T04:31:32.052-06:00',
#    'winner': 'Sim17',
#    'scores': {'Sim17': 103, 'bushNIT': 81}},
#   {'completed_at': '2023-11-19T20:05:42.449-06:00',
#    'winner': 'vpol55',
#    'scores': {'JunePaik': 105, 'vpol55': 94}},
#   {'completed_at': '2023-11-19T20:05:42.449-06:00',
#    'winner': 'vpol55',
#    'scores': {'JunePaik': 89, 'vpol55': 103}},
#   {'completed_at': '2023-11-19T20:05:42.449-06:00',
#    'winner': 'vpol55',
#    'scores': {'JunePaik': 79, 'vpol55': 101}},
#   {'completed_at': '2023-11-19T20:11:50.723-06:00',
#    'winner': 'Waterman',
#    'scores': {'Abiath': 78, 'Waterman': 81}},
#   {'completed_at': '2023-11-19T20:11:50.723-06:00',
#    'winner': 'Waterman',
#    'scores': {'Abiath': 109, 'Waterman': 98}},
#   {'completed_at': '2023-11-19T20:11:50.723-06:00',
#    'winner': 'Waterman',
#    'scores': {'Abiath': 93, 'Waterman': 95}},
#   {'completed_at': '2023-11-19T08:02:59.732-06:00',
#    'winner': 'SleepyHead',
#    'scores': {'Sleepyhead': 101, 'KarlHungus': 95}},
#   {'completed_at': '2023-11-19T08:02:59.732-06:00',
#    'winner': 'SleepyHead',
#    'scores': {'Sleepyhead': 90, 'KarlHungus': 87}},
#   {'completed_at': '2023-11-25T18:08:24.623-06:00',
#    'winner': 'vpol55',
#    'scores': {'Sim17': 96, 'vpol55': 97}},
#   {'completed_at': '2023-11-25T18:08:24.623-06:00',
#    'winner': 'vpol55',
#    'scores': {'Sim17': 79, 'vpol55': 90}},
#   {'completed_at': '2023-11-25T18:08:40.615-06:00',
#    'winner': 'SleepyHead',
#    'scores': {'Waterman': 92, 'Sleepyhead': 101}},
#   {'completed_at': '2023-11-25T18:08:40.615-06:00',
#    'winner': 'SleepyHead',
#    'scores': {'Waterman': 124, 'Sleepyhead': 101}},
#   {'completed_at': '2023-11-25T18:08:40.615-06:00',
#    'winner': 'SleepyHead',
#    'scores': {'Waterman': 88, 'Sleepyhead': 96}},
#   {'completed_at': '2023-11-13T14:29:20.313-06:00',
#    'winner': 'matthew9890',
#    'scores': {'EpicSaxGuy': 94, 'matthew9890': 104}},
#   {'completed_at': '2023-11-13T14:29:20.313-06:00',
#    'winner': 'matthew9890',
#    'scores': {'EpicSaxGuy': 112, 'matthew9890': 104}},
#   {'completed_at': '2023-11-13T14:29:20.313-06:00',
#    'winner': 'matthew9890',
#    'scores': {'EpicSaxGuy': 119, 'matthew9890': 122}},
#   {'completed_at': '2023-11-16T04:55:38.563-06:00',
#    'winner': 'Naketano',
#    'scores': {'SPAKEME': 83, 'Naketano': 89}},
#   {'completed_at': '2023-11-16T04:55:38.563-06:00',
#    'winner': 'Naketano',
#    'scores': {'SPAKEME': 81, 'Naketano': 86}},
#   {'completed_at': '2023-11-14T19:22:18.509-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'gdhar67 (GasLighter)': 83, 'MaudlinCake': 91}},
#   {'completed_at': '2023-11-14T19:22:18.509-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'gdhar67 (GasLighter)': 105, 'MaudlinCake': 94}},
#   {'completed_at': '2023-11-14T19:22:18.509-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'gdhar67 (GasLighter)': 95, 'MaudlinCake': 109}},
#   {'completed_at': '2023-11-17T05:38:08.492-06:00',
#    'winner': 'Quacky',
#    'scores': {'Solskjaer025! (IGN Damsgaard)': 90, 'quacky': 78}},
#   {'completed_at': '2023-11-17T05:38:08.492-06:00',
#    'winner': 'Quacky',
#    'scores': {'Solskjaer025! (IGN Damsgaard)': 74, 'quacky': 86}},
#   {'completed_at': '2023-11-17T05:38:08.492-06:00',
#    'winner': 'Quacky',
#    'scores': {'Solskjaer025! (IGN Damsgaard)': 70, 'quacky': 82}},
#   {'completed_at': '2023-11-17T10:35:39.827-06:00',
#    'winner': 'matthew9890',
#    'scores': {'matthew9890': 88, 'Naketano': 74}},
#   {'completed_at': '2023-11-17T10:35:39.827-06:00',
#    'winner': 'matthew9890',
#    'scores': {'matthew9890': 101, 'Naketano': 80}},
#   {'completed_at': '2023-11-25T18:05:44.531-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'MaudlinCake': 75, 'quacky': 91}},
#   {'completed_at': '2023-11-25T18:05:44.531-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'MaudlinCake': 106, 'quacky': 101}},
#   {'completed_at': '2023-11-25T18:05:44.531-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'MaudlinCake': 110, 'quacky': 91}},
#   {'completed_at': '2023-11-26T20:33:42.587-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'matthew9890': 79, 'MaudlinCake': 90}},
#   {'completed_at': '2023-11-26T20:33:42.587-06:00',
#    'winner': 'maudlinCake',
#    'scores': {'matthew9890': 101, 'MaudlinCake': 126}},
#   {'completed_at': '2023-11-14T19:34:23.755-06:00',
#    'winner': 'jeastthebeast',
#    'scores': {'birdwatchermobile': 73, 'jeastthebeast': 80}},
#   {'completed_at': '2023-11-14T19:34:23.755-06:00',
#    'winner': 'jeastthebeast',
#    'scores': {'birdwatchermobile': 85, 'jeastthebeast': 90}},
#   {'completed_at': '2023-11-18T15:49:48.830-06:00',
#    'winner': 'thedetermin8or',
#    'scores': {'CheeseDreams': 98, 'thedetermin8or': 92}},
#   {'completed_at': '2023-11-18T15:49:48.830-06:00',
#    'winner': 'thedetermin8or',
#    'scores': {'CheeseDreams': 83, 'thedetermin8or': 97}},
#   {'completed_at': '2023-11-18T15:49:48.830-06:00',
#    'winner': 'thedetermin8or',
#    'scores': {'CheeseDreams': 113, 'thedetermin8or': 123}},
#   {'completed_at': '2023-11-17T05:37:54.599-06:00',
#    'winner': 'RickCissel',
#    'scores': {'b0romir': 76, 'RickCissel': 88}},
#   {'completed_at': '2023-11-17T05:37:54.599-06:00',
#    'winner': 'RickCissel',
#    'scores': {'b0romir': 70, 'RickCissel': 99}},
#   {'completed_at': '2023-11-14T19:25:18.838-06:00',
#    'winner': 'Danko',
#    'scores': {'Flan': 112, 'Danko': 107}},
#   {'completed_at': '2023-11-14T19:25:18.838-06:00',
#    'winner': 'Danko',
#    'scores': {'Flan': 84, 'Danko': 95}},
#   {'completed_at': '2023-11-14T19:25:18.838-06:00',
#    'winner': 'Danko',
#    'scores': {'Flan': 91, 'Danko': 93}},
#   {'completed_at': '2023-11-20T17:12:38.011-06:00',
#    'winner': 'jeastthebeast',
#    'scores': {'jeastthebeast': 102, 'thedetermin8or': 78}},
#   {'completed_at': '2023-11-20T17:12:38.011-06:00',
#    'winner': 'jeastthebeast',
#    'scores': {'jeastthebeast': 106, 'thedetermin8or': 97}},
#   {'completed_at': '2023-11-18T14:51:16.163-06:00',
#    'winner': 'Danko',
#    'scores': {'RickCissel': 111, 'Danko': 130}},
#   {'completed_at': '2023-11-18T14:51:16.163-06:00',
#    'winner': 'Danko',
#    'scores': {'RickCissel': 109, 'Danko': 83}},
#   {'completed_at': '2023-11-18T14:51:16.163-06:00',
#    'winner': 'Danko',
#    'scores': {'RickCissel': 88, 'Danko': 105}},
#   {'completed_at': '2023-11-21T14:33:23.022-06:00',
#    'winner': 'Danko',
#    'scores': {'jeastthebeast': 95, 'Danko': 99}},
#   {'completed_at': '2023-11-21T14:33:23.022-06:00',
#    'winner': 'Danko',
#    'scores': {'jeastthebeast': 101, 'Danko': 86}},
#   {'completed_at': '2023-11-21T14:33:23.022-06:00',
#    'winner': 'Danko',
#    'scores': {'jeastthebeast': 75, 'Danko': 97}},
#   {'completed_at': '2023-11-13T14:30:26.324-06:00',
#    'winner': 'WoodpeckerJoe',
#    'scores': {'WoodpeckerJoe': 98, 'Terracotta (aLL1e)': 74}},
#   {'completed_at': '2023-11-13T14:30:26.324-06:00',
#    'winner': 'WoodpeckerJoe',
#    'scores': {'WoodpeckerJoe': 123, 'Terracotta (aLL1e)': 108}},
#   {'completed_at': '2023-11-14T20:47:56.942-06:00',
#    'winner': 'BalletMage',
#    'scores': {'bronka': 93, 'BalletMage': 76}},
#   {'completed_at': '2023-11-14T20:47:56.942-06:00',
#    'winner': 'BalletMage',
#    'scores': {'bronka': 95, 'BalletMage': 97}},
#   {'completed_at': '2023-11-14T20:47:56.942-06:00',
#    'winner': 'BalletMage',
#    'scores': {'bronka': 74, 'BalletMage': 88}},
#   {'completed_at': '2023-11-16T17:03:12.057-06:00',
#    'winner': 'captain_awesome.',
#    'scores': {'captain_awesome.': 81, 'Ben_fm': 96}},
#   {'completed_at': '2023-11-16T17:03:12.057-06:00',
#    'winner': 'captain_awesome.',
#    'scores': {'captain_awesome.': 107, 'Ben_fm': 90}},
#   {'completed_at': '2023-11-16T17:03:12.057-06:00',
#    'winner': 'captain_awesome.',
#    'scores': {'captain_awesome.': 87, 'Ben_fm': 82}},
#   {'completed_at': '2023-11-19T20:09:04.388-06:00',
#    'winner': 'Scotsword',
#    'scores': {'Jamesvanderbeak': 70, 'Scotsword': 94}},
#   {'completed_at': '2023-11-19T20:09:04.388-06:00',
#    'winner': 'Scotsword',
#    'scores': {'Jamesvanderbeak': 87, 'Scotsword': 95}},
#   {'completed_at': '2023-11-16T18:49:36.242-06:00',
#    'winner': 'BalletMage',
#    'scores': {'WoodpeckerJoe': 88, 'BalletMage': 87}},
#   {'completed_at': '2023-11-16T18:49:36.242-06:00',
#    'winner': 'BalletMage',
#    'scores': {'WoodpeckerJoe': 81, 'BalletMage': 95}},
#   {'completed_at': '2023-11-16T18:49:36.242-06:00',
#    'winner': 'BalletMage',
#    'scores': {'WoodpeckerJoe': 78, 'BalletMage': 79}},
#   {'completed_at': '2023-11-25T18:03:50.557-06:00',
#    'winner': 'captain_awesome.',
#    'scores': {'captain_awesome.': 85, 'Scotsword': 101}},
#   {'completed_at': '2023-11-25T18:03:50.557-06:00',
#    'winner': 'captain_awesome.',
#    'scores': {'captain_awesome.': 97, 'Scotsword': 85}},
#   {'completed_at': '2023-11-25T18:03:50.557-06:00',
#    'winner': 'captain_awesome.',
#    'scores': {'captain_awesome.': 96, 'Scotsword': 71}},
#   {'completed_at': '2023-11-27T13:37:15.818-06:00',
#    'winner': 'BalletMage',
#    'scores': {'BalletMage': 98, 'captain_awesome.': 106}},
#   {'completed_at': '2023-11-27T13:37:15.818-06:00',
#    'winner': 'BalletMage',
#    'scores': {'BalletMage': 124, 'captain_awesome.': 94}},
#   {'completed_at': '2023-11-27T13:37:15.818-06:00',
#    'winner': 'BalletMage',
#    'scores': {'BalletMage': 100, 'captain_awesome.': 80}},
#   {'completed_at': '2023-11-14T19:26:39.201-06:00',
#    'winner': 'Irek',
#    'scores': {'Irek': 95, 'gdpeck (72BirdSong)': 80}},
#   {'completed_at': '2023-11-14T19:26:39.201-06:00',
#    'winner': 'Irek',
#    'scores': {'Irek': 115, 'gdpeck (72BirdSong)': 85}},
#   {'completed_at': '2023-11-19T09:30:53.993-06:00',
#    'winner': 'GeorgeV89',
#    'scores': {'dagger_hashimoto_': 80, 'GeorgeV89': 95}},
#   {'completed_at': '2023-11-19T09:30:53.993-06:00',
#    'winner': 'GeorgeV89',
#    'scores': {'dagger_hashimoto_': 91, 'GeorgeV89': 98}},
#   {'completed_at': '2023-11-12T18:33:06.231-06:00',
#    'winner': 'SadRick (IGN)',
#    'scores': {'duckie': 68, 'SadRick (IGN)': 88}},
#   {'completed_at': '2023-11-12T18:33:06.231-06:00',
#    'winner': 'SadRick (IGN)',
#    'scores': {'duckie': 85, 'SadRick (IGN)': 90}},
#   {'completed_at': '2023-11-19T07:59:42.468-06:00',
#    'winner': 'de Visme',
#    'scores': {'nathanroos': 102, 'de Visme': 99}},
#   {'completed_at': '2023-11-19T07:59:42.468-06:00',
#    'winner': 'de Visme',
#    'scores': {'nathanroos': 90, 'de Visme': 126}},
#   {'completed_at': '2023-11-19T07:59:42.468-06:00',
#    'winner': 'de Visme',
#    'scores': {'nathanroos': 100, 'de Visme': 101}},
#   {'completed_at': '2023-11-20T17:13:43.572-06:00',
#    'winner': 'Irek',
#    'scores': {'Irek': 119, 'GeorgeV89': 96}},
#   {'completed_at': '2023-11-20T17:13:43.572-06:00',
#    'winner': 'Irek',
#    'scores': {'Irek': 117, 'GeorgeV89': 94}},
#   {'completed_at': '2023-11-23T12:58:50.599-06:00',
#    'winner': 'de Visme',
#    'scores': {'SadRick (IGN)': 109, 'de Visme': 89}},
#   {'completed_at': '2023-11-23T12:58:50.599-06:00',
#    'winner': 'de Visme',
#    'scores': {'SadRick (IGN)': 102, 'de Visme': 106}},
#   {'completed_at': '2023-11-23T12:58:50.599-06:00',
#    'winner': 'de Visme',
#    'scores': {'SadRick (IGN)': 90, 'de Visme': 99}},
#   {'completed_at': '2023-11-26T13:19:34.910-06:00',
#    'winner': 'de Visme',
#    'scores': {'Irek': 84, 'de Visme': 87}},
#   {'completed_at': '2023-11-26T13:19:34.910-06:00',
#    'winner': 'de Visme',
#    'scores': {'Irek': 83, 'de Visme': 84}},
#   {'completed_at': '2023-11-14T19:27:46.536-06:00',
#    'winner': 'erikaloveducks',
#    'scores': {'Rampichino': 70, 'erikaloveducks': 71}},
#   {'completed_at': '2023-11-14T19:27:46.536-06:00',
#    'winner': 'erikaloveducks',
#    'scores': {'Rampichino': 76, 'erikaloveducks': 73}},
#   {'completed_at': '2023-11-14T19:27:46.536-06:00',
#    'winner': 'erikaloveducks',
#    'scores': {'Rampichino': 74, 'erikaloveducks': 86}},
#   {'completed_at': '2023-11-14T19:39:30.442-06:00',
#    'winner': 'Embrifox',
#    'scores': {'Embrifox': 88, 'sable_knight': 85}},
#   {'completed_at': '2023-11-14T19:39:30.442-06:00',
#    'winner': 'Embrifox',
#    'scores': {'Embrifox': 76, 'sable_knight': 95}},
#   {'completed_at': '2023-11-14T19:39:30.442-06:00',
#    'winner': 'Embrifox',
#    'scores': {'Embrifox': 79, 'sable_knight': 75}},
#   {'completed_at': '2023-11-14T20:48:43.323-06:00',
#    'winner': 'BeakMajik',
#    'scores': {'BeakMajik': 78, 'AWingandaPrayer': 55}},
#   {'completed_at': '2023-11-14T20:48:43.323-06:00',
#    'winner': 'BeakMajik',
#    'scores': {'BeakMajik': 69, 'AWingandaPrayer': 89}},
#   {'completed_at': '2023-11-14T20:48:43.323-06:00',
#    'winner': 'BeakMajik',
#    'scores': {'BeakMajik': 80, 'AWingandaPrayer': 62}},
#   {'completed_at': '2023-11-19T12:05:49.783-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'jbc999': 90, 'IGN GokuMatos': 108}},
#   {'completed_at': '2023-11-19T12:05:49.783-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'jbc999': 98, 'IGN GokuMatos': 113}},
#   {'completed_at': '2023-11-16T21:35:42.171-06:00',
#    'winner': 'Embrifox',
#    'scores': {'erikaloveducks': 75, 'Embrifox': 76}},
#   {'completed_at': '2023-11-16T21:35:42.171-06:00',
#    'winner': 'Embrifox',
#    'scores': {'erikaloveducks': 103, 'Embrifox': 98}},
#   {'completed_at': '2023-11-16T21:35:42.171-06:00',
#    'winner': 'Embrifox',
#    'scores': {'erikaloveducks': 67, 'Embrifox': 74}},
#   {'completed_at': '2023-11-21T14:36:42.042-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'BeakMajik': 76, 'IGN GokuMatos': 86}},
#   {'completed_at': '2023-11-21T14:36:42.042-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'BeakMajik': 100, 'IGN GokuMatos': 108}},
#   {'completed_at': '2023-11-24T12:22:41.412-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'Embrifox': 88, 'IGN GokuMatos': 99}},
#   {'completed_at': '2023-11-24T12:22:41.412-06:00',
#    'winner': 'IGN GokuMatos',
#    'scores': {'Embrifox': 86, 'IGN GokuMatos': 99}},
#   {'completed_at': '2023-11-16T21:36:09.721-06:00',
#    'winner': 'JuliusDiamond',
#    'scores': {'JuliusDiamond': 90, 'DuchessOfClifton': 80}},
#   {'completed_at': '2023-11-16T21:36:09.721-06:00',
#    'winner': 'JuliusDiamond',
#    'scores': {'JuliusDiamond': 96, 'DuchessOfClifton': 81}},
#   {'completed_at': '2023-11-19T20:13:09.897-06:00',
#    'winner': 'Mortal_Wings',
#    'scores': {'IV1738': 80, 'Mortal_Wings': 78}},
#   {'completed_at': '2023-11-19T20:13:09.897-06:00',
#    'winner': 'Mortal_Wings',
#    'scores': {'IV1738': 72, 'Mortal_Wings': 98}},
#   {'completed_at': '2023-11-19T20:13:09.897-06:00',
#    'winner': 'Mortal_Wings',
#    'scores': {'IV1738': 96, 'Mortal_Wings': 118}},
#   {'completed_at': '2023-11-13T07:26:27.845-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'slejo': 80, 'Arceusisgood': 100}},
#   {'completed_at': '2023-11-13T07:26:27.845-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'slejo': 76, 'Arceusisgood': 113}},
#   {'completed_at': '2023-11-14T19:20:11.074-06:00',
#    'winner': 'TheGreenClarinet',
#    'scores': {'Taykay (ign toznom)': 67, 'TheGreenClarinet': 94}},
#   {'completed_at': '2023-11-14T19:20:11.074-06:00',
#    'winner': 'TheGreenClarinet',
#    'scores': {'Taykay (ign toznom)': 85, 'TheGreenClarinet': 94}},
#   {'completed_at': '2023-11-21T15:14:43.335-06:00',
#    'winner': 'JuliusDiamond',
#    'scores': {'JuliusDiamond': 86, 'Mortal_Wings': 81}},
#   {'completed_at': '2023-11-21T15:14:43.335-06:00',
#    'winner': 'JuliusDiamond',
#    'scores': {'JuliusDiamond': 116, 'Mortal_Wings': 94}},
#   {'completed_at': '2023-11-18T21:43:41.280-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'Arceusisgood': 104, 'TheGreenClarinet': 93}},
#   {'completed_at': '2023-11-18T21:43:41.280-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'Arceusisgood': 111, 'TheGreenClarinet': 90}},
#   {'completed_at': '2023-11-25T18:06:27.516-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'JuliusDiamond': 98, 'Arceusisgood': 95}},
#   {'completed_at': '2023-11-25T18:06:27.516-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'JuliusDiamond': 76, 'Arceusisgood': 84}},
#   {'completed_at': '2023-11-25T18:06:27.516-06:00',
#    'winner': 'Arceusisgood',
#    'scores': {'JuliusDiamond': 91, 'Arceusisgood': 99}},
#   {'completed_at': '2023-11-18T06:18:03.751-06:00',
#    'winner': 'mrtriggerhandz',
#    'scores': {'Bargoff': 87, 'mrtriggerhandz': 88}},
#   {'completed_at': '2023-11-18T06:18:03.751-06:00',
#    'winner': 'mrtriggerhandz',
#    'scores': {'Bargoff': 77, 'mrtriggerhandz': 89}},
#   {'completed_at': '2023-11-16T04:58:20.362-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'HawkLake': 109, 'FractalChess2': 122}},
#   {'completed_at': '2023-11-16T04:58:20.362-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'HawkLake': 109, 'FractalChess2': 125}},
#   {'completed_at': '2023-11-12T18:35:46.236-06:00',
#    'winner': 'MichaelTheGrackle',
#    'scores': {'MichaelTheGrackle': 94, 'corvogordo': 66}},
#   {'completed_at': '2023-11-12T18:35:46.236-06:00',
#    'winner': 'MichaelTheGrackle',
#    'scores': {'MichaelTheGrackle': 103, 'corvogordo': 86}},
#   {'completed_at': '2023-11-18T15:50:19.035-06:00',
#    'winner': 'mike316',
#    'scores': {'Ineslopes98': 84, 'mike316': 100}},
#   {'completed_at': '2023-11-18T15:50:19.035-06:00',
#    'winner': 'mike316',
#    'scores': {'Ineslopes98': 73, 'mike316': 99}},
#   {'completed_at': '2023-11-19T20:10:07.350-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'mrtriggerhandz': 83, 'FractalChess2': 100}},
#   {'completed_at': '2023-11-19T20:10:07.350-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'mrtriggerhandz': 97, 'FractalChess2': 122}},
#   {'completed_at': '2023-11-19T08:02:13.821-06:00',
#    'winner': 'mike316',
#    'scores': {'MichaelTheGrackle': 97, 'mike316': 83}},
#   {'completed_at': '2023-11-19T08:02:13.821-06:00',
#    'winner': 'mike316',
#    'scores': {'MichaelTheGrackle': 78, 'mike316': 93}},
#   {'completed_at': '2023-11-19T08:02:13.821-06:00',
#    'winner': 'mike316',
#    'scores': {'MichaelTheGrackle': 88, 'mike316': 93}},
#   {'completed_at': '2023-11-26T09:24:33.070-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'FractalChess2': 91, 'mike316': 81}},
#   {'completed_at': '2023-11-26T09:24:33.070-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'FractalChess2': 89, 'mike316': 100}},
#   {'completed_at': '2023-11-26T09:24:33.070-06:00',
#    'winner': 'FractalChess2',
#    'scores': {'FractalChess2': 111, 'mike316': 84}},
#   {'completed_at': '2023-11-12T21:54:44.369-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 73, 'bigben1248 (Dashua)': 74}},
#   {'completed_at': '2023-11-12T21:54:44.369-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 107, 'bigben1248 (Dashua)': 89}},
#   {'completed_at': '2023-11-12T21:54:44.369-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 98, 'bigben1248 (Dashua)': 96}},
#   {'completed_at': '2023-11-12T12:43:00.440-06:00',
#    'winner': 'goldfinchy',
#    'scores': {'ramtek': 77, 'Goldfinchy': 95}},
#   {'completed_at': '2023-11-12T12:43:00.440-06:00',
#    'winner': 'goldfinchy',
#    'scores': {'ramtek': 96, 'Goldfinchy': 104}},
#   {'completed_at': '2023-11-19T20:15:36.050-06:00',
#    'winner': 'StyloPlume',
#    'scores': {'StyloPlume': 93, 'iwinatlife42': 101}},
#   {'completed_at': '2023-11-18T14:48:27.406-06:00',
#    'winner': 'Salmonskinroll12',
#    'scores': {'Salmonskinroll12': 97, 'Lowfat': 89}},
#   {'completed_at': '2023-11-18T14:48:27.406-06:00',
#    'winner': 'Salmonskinroll12',
#    'scores': {'Salmonskinroll12': 129, 'Lowfat': 115}},
#   {'completed_at': '2023-11-13T17:55:16.648-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 121, 'Goldfinchy': 97}},
#   {'completed_at': '2023-11-13T17:55:16.648-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 103, 'Goldfinchy': 77}},
#   {'completed_at': '2023-11-22T12:34:27.791-06:00',
#    'winner': 'Salmonskinroll12',
#    'scores': {'StyloPlume': 87, 'Salmonskinroll12': 102}},
#   {'completed_at': '2023-11-22T12:34:27.791-06:00',
#    'winner': 'Salmonskinroll12',
#    'scores': {'StyloPlume': 83, 'Salmonskinroll12': 98}},
#   {'completed_at': '2023-11-25T18:07:48.873-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 98, 'Salmonskinroll12': 79}},
#   {'completed_at': '2023-11-25T18:07:48.873-06:00',
#    'winner': 'DrGrainslove',
#    'scores': {'DrGrainslove': 103, 'Salmonskinroll12': 79}},
#   {'completed_at': '2023-11-14T19:37:46.588-06:00',
#    'winner': 'Beammeup (elekTrick)',
#    'scores': {'Theflash04': 109, 'Beammeup (elekTrick)': 124}},
#   {'completed_at': '2023-11-14T19:37:46.588-06:00',
#    'winner': 'Beammeup (elekTrick)',
#    'scores': {'Theflash04': 101, 'Beammeup (elekTrick)': 132}},
#   {'completed_at': '2023-11-16T17:09:57.602-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'ravenousanna': 96, 'ZoopZoop': 98}},
#   {'completed_at': '2023-11-16T17:09:57.602-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'ravenousanna': 84, 'ZoopZoop': 108}},
#   {'completed_at': '2023-11-12T21:56:56.654-06:00',
#    'winner': 'Rube23',
#    'scores': {'Cuppa': 70, 'Rube23': 86}},
#   {'completed_at': '2023-11-12T21:56:56.654-06:00',
#    'winner': 'Rube23',
#    'scores': {'Cuppa': 82, 'Rube23': 77}},
#   {'completed_at': '2023-11-12T21:56:56.654-06:00',
#    'winner': 'Rube23',
#    'scores': {'Cuppa': 72, 'Rube23': 82}},
#   {'completed_at': '2023-11-14T21:35:29.087-06:00',
#    'winner': 'Groovenstein',
#    'scores': {'Groovenstein': 104, 'Crowvid99': 92}},
#   {'completed_at': '2023-11-14T21:35:29.087-06:00',
#    'winner': 'Groovenstein',
#    'scores': {'Groovenstein': 106, 'Crowvid99': 98}},
#   {'completed_at': '2023-11-17T22:13:59.918-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'Beammeup (elekTrick)': 89, 'ZoopZoop': 96}},
#   {'completed_at': '2023-11-17T22:13:59.918-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'Beammeup (elekTrick)': 85, 'ZoopZoop': 104}},
#   {'completed_at': '2023-11-16T04:58:29.471-06:00',
#    'winner': 'Groovenstein',
#    'scores': {'Rube23': 99, 'Groovenstein': 115}},
#   {'completed_at': '2023-11-16T04:58:29.471-06:00',
#    'winner': 'Groovenstein',
#    'scores': {'Rube23': 92, 'Groovenstein': 85}},
#   {'completed_at': '2023-11-16T04:58:29.471-06:00',
#    'winner': 'Groovenstein',
#    'scores': {'Rube23': 93, 'Groovenstein': 106}},
#   {'completed_at': '2023-11-19T20:06:13.133-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'ZoopZoop': 92, 'Groovenstein': 85}},
#   {'completed_at': '2023-11-19T20:06:13.133-06:00',
#    'winner': 'ZoopZoop',
#    'scores': {'ZoopZoop': 92, 'Groovenstein': 88}},
#   {'completed_at': '2023-11-18T14:54:11.978-06:00',
#    'winner': 'otsukuuyan',
#    'scores': {'Copewithit': 95, 'otsukuuyan': 89}},
#   {'completed_at': '2023-11-18T14:54:11.978-06:00',
#    'winner': 'otsukuuyan',
#    'scores': {'Copewithit': 88, 'otsukuuyan': 106}},
#   {'completed_at': '2023-11-18T14:54:11.978-06:00',
#    'winner': 'otsukuuyan',
#    'scores': {'Copewithit': 76, 'otsukuuyan': 110}},
#   {'completed_at': '2023-11-16T04:56:04.854-06:00',
#    'winner': 'MonkeyWren',
#    'scores': {'MonkeyWren': 85, 'Stormchaser': 89}},
#   {'completed_at': '2023-11-16T04:56:04.854-06:00',
#    'winner': 'MonkeyWren',
#    'scores': {'MonkeyWren': 108, 'Stormchaser': 85}},
#   {'completed_at': '2023-11-16T04:56:04.854-06:00',
#    'winner': 'MonkeyWren',
#    'scores': {'MonkeyWren': 101, 'Stormchaser': 80}},
#   {'completed_at': '2023-11-18T21:43:09.518-06:00',
#    'winner': 'kopdog',
#    'scores': {'Herc': 115, 'Kopdog': 124}},
#   {'completed_at': '2023-11-18T21:43:09.518-06:00',
#    'winner': 'kopdog',
#    'scores': {'Herc': 112, 'Kopdog': 108}},
#   {'completed_at': '2023-11-18T21:43:09.518-06:00',
#    'winner': 'kopdog',
#    'scores': {'Herc': 84, 'Kopdog': 103}},
#   {'completed_at': '2023-11-16T17:04:47.342-06:00',
#    'winner': 'dilfina',
#    'scores': {'dilfina': 115, 'Daniel Naumovas (Daniel)': 91}},
#   {'completed_at': '2023-11-16T17:04:47.342-06:00',
#    'winner': 'dilfina',
#    'scores': {'dilfina': 105, 'Daniel Naumovas (Daniel)': 99}},
#   {'completed_at': '2023-11-26T20:33:06.151-06:00',
#    'winner': 'MonkeyWren',
#    'scores': {'otsukuuyan': 82, 'MonkeyWren': 84}},
#   {'completed_at': '2023-11-26T20:33:06.151-06:00',
#    'winner': 'MonkeyWren',
#    'scores': {'otsukuuyan': 82, 'MonkeyWren': 91}},
#   {'completed_at': '2023-11-21T14:32:46.441-06:00',
#    'winner': 'dilfina',
#    'scores': {'Kopdog': 82, 'dilfina': 95}},
#   {'completed_at': '2023-11-21T14:32:46.441-06:00',
#    'winner': 'dilfina',
#    'scores': {'Kopdog': 105, 'dilfina': 82}},
#   {'completed_at': '2023-11-21T14:32:46.441-06:00',
#    'winner': 'dilfina',
#    'scores': {'Kopdog': 86, 'dilfina': 91}},
#   {'completed_at': '2023-11-19T07:57:19.857-06:00',
#    'winner': 'ethmah',
#    'scores': {'thebestdaysofmyflerm': 82, 'ethmah': 106}},
#   {'completed_at': '2023-11-19T07:57:19.857-06:00',
#    'winner': 'ethmah',
#    'scores': {'thebestdaysofmyflerm': 100, 'ethmah': 102}},
#   {'completed_at': '2023-11-19T08:01:35.290-06:00',
#    'winner': 'queenfisher1',
#    'scores': {'queenfisher1': 80, 'Vrwizkid': 69}},
#   {'completed_at': '2023-11-19T08:01:35.290-06:00',
#    'winner': 'queenfisher1',
#    'scores': {'queenfisher1': 99, 'Vrwizkid': 88}},
#   {'completed_at': '2023-11-12T18:35:49.260-06:00',
#    'winner': 'MTRooster',
#    'scores': {'MTRooster': 87, 'WhatDatFrogmoufDo': 76}},
#   {'completed_at': '2023-11-12T18:35:49.260-06:00',
#    'winner': 'MTRooster',
#    'scores': {'MTRooster': 95, 'WhatDatFrogmoufDo': 88}},
#   {'completed_at': '2023-11-17T14:36:42.088-06:00',
#    'winner': 'ZobiWanKenobi',
#    'scores': {'alexandrawuhu': 84, 'ZobiWanKenobi': 101}},
#   {'completed_at': '2023-11-17T14:36:42.088-06:00',
#    'winner': 'ZobiWanKenobi',
#    'scores': {'alexandrawuhu': 87, 'ZobiWanKenobi': 85}},
#   {'completed_at': '2023-11-17T14:36:42.088-06:00',
#    'winner': 'ZobiWanKenobi',
#    'scores': {'alexandrawuhu': 81, 'ZobiWanKenobi': 101}},
#   {'completed_at': '2023-11-22T06:08:46.305-06:00',
#    'winner': 'queenfisher1',
#    'scores': {'ethmah': 90, 'queenfisher1': 79}},
#   {'completed_at': '2023-11-22T06:08:46.305-06:00',
#    'winner': 'queenfisher1',
#    'scores': {'ethmah': 77, 'queenfisher1': 103}},
#   {'completed_at': '2023-11-22T06:08:46.305-06:00',
#    'winner': 'queenfisher1',
#    'scores': {'ethmah': 67, 'queenfisher1': 95}},
#   {'completed_at': '2023-11-19T07:59:05.180-06:00',
#    'winner': 'ZobiWanKenobi',
#    'scores': {'MTRooster': 82, 'ZobiWanKenobi': 80}},
#   {'completed_at': '2023-11-19T07:59:05.180-06:00',
#    'winner': 'ZobiWanKenobi',
#    'scores': {'MTRooster': 80, 'ZobiWanKenobi': 96}},
#   {'completed_at': '2023-11-19T07:59:05.180-06:00',
#    'winner': 'ZobiWanKenobi',
#    'scores': {'MTRooster': 87, 'ZobiWanKenobi': 103}},
#   {'completed_at': '2023-11-14T19:25:57.679-06:00',
#    'winner': 'ronster',
#    'scores': {'Ronster7': 94, 'Kestrelly': 69}},
#   {'completed_at': '2023-11-14T19:25:57.679-06:00',
#    'winner': 'ronster',
#    'scores': {'Ronster7': 105, 'Kestrelly': 92}},
#   {'completed_at': '2023-11-12T18:36:03.005-06:00',
#    'winner': 'clloud8',
#    'scores': {'Clloud8': 82, 'ElSapoGuapo': 77}},
#   {'completed_at': '2023-11-12T18:36:03.005-06:00',
#    'winner': 'clloud8',
#    'scores': {'Clloud8': 94, 'ElSapoGuapo': 98}},
#   {'completed_at': '2023-11-12T18:36:03.005-06:00',
#    'winner': 'clloud8',
#    'scores': {'Clloud8': 97, 'ElSapoGuapo': 87}},
#   {'completed_at': '2023-11-13T16:36:11.411-06:00',
#    'winner': 'ooievaar',
#    'scores': {'KingPleb': 88, 'ooievaar': 89}},
#   {'completed_at': '2023-11-13T16:36:11.411-06:00',
#    'winner': 'ooievaar',
#    'scores': {'KingPleb': 72, 'ooievaar': 87}},
#   {'completed_at': '2023-11-16T17:06:42.940-06:00',
#    'winner': 'ronster',
#    'scores': {'blind squirrel (fnjphone)': 98, 'Ronster7': 113}},
#   {'completed_at': '2023-11-16T17:06:42.940-06:00',
#    'winner': 'ronster',
#    'scores': {'blind squirrel (fnjphone)': 102, 'Ronster7': 119}},
#   {'completed_at': '2023-11-14T19:32:20.910-06:00',
#    'winner': 'ooievaar',
#    'scores': {'Clloud8': 72, 'ooievaar': 77}},
#   {'completed_at': '2023-11-14T19:32:20.910-06:00',
#    'winner': 'ooievaar',
#    'scores': {'Clloud8': 87, 'ooievaar': 91}},
#   {'completed_at': '2023-11-22T12:33:40.504-06:00',
#    'winner': 'ooievaar',
#    'scores': {'Ronster7': 92, 'ooievaar': 110}},
#   {'completed_at': '2023-11-22T12:33:40.504-06:00',
#    'winner': 'ooievaar',
#    'scores': {'Ronster7': 103, 'ooievaar': 83}},
#   {'completed_at': '2023-11-22T12:33:40.504-06:00',
#    'winner': 'ooievaar',
#    'scores': {'Ronster7': 98, 'ooievaar': 100}}]}
